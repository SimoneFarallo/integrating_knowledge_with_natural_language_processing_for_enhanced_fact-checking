# %% [markdown]
# <a href="https://colab.research.google.com/github/SimoneFarallo/Thesis/blob/main/REBEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #REBEL
#
# https://medium.com/nlplanet/building-a-knowledge-base-from-texts-a-full-practical-example-8dbbffb912fa
#
# https://huggingface.co/Babelscape/rebel-large
#
# https://github.com/Babelscape/rebel/blob/main/docs/EMNLP_2021_REBEL__Camera_Ready_.pdf

# %%
# !pip install transformers wikipedia newspaper3k GoogleNews pyvis
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 4.0 MB/s eta 0:00:00
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.10-py3-none-any.whl (8.2 kB)
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from wikipedia) (4.11.2)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (9.4.0)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (3.8.1)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.10-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 10.7 MB/s eta 0:00:00
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 13.2 MB/s eta 0:00:00
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 21.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dateparser (from GoogleNews)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.9 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from pyvis) (7.34.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.0.2)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.10/dist-packages (from pyvis) (3.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->wikipedia) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (3.0.41)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9.6->pyvis) (2.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.1->newspaper3k) (1.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (2023.3.post1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser->GoogleNews) (5.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.10)
# Building wheels for collected packages: wikipedia, tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=62193061c11b6694bc294516b6ce4ccc41fad02fbde59dab0cfc10f5a9b319c6
#   Stored in directory: /root/.cache/pip/wheels/5e/b6/c5/93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=11e2ff7f1a0d69f3018f0c41464a5d301cad8473f8f00a9fae8593eed472032c
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3339 sha256=6c95f84c805476e6c19187cc1f2753a216dce48410f1f5b72e6fd86f5fa8090b
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398381 sha256=3d007dbc4f75d261a27af7009bc371f649cac3942c5c7a53837ced2621a42caf
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=7a54a3d66e76a82de79637c6c621414dd0fbacb9d34dbf4e1a8b98fabc933881
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built wikipedia tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, jedi, feedparser, cssselect, wikipedia, requests-file, feedfinder2, dateparser, tldextract, pyvis, GoogleNews, newspaper3k
# Successfully installed GoogleNews-1.6.10 cssselect-1.2.0 dateparser-1.2.0 feedfinder2-0.0.4 feedparser-6.0.10 jedi-0.19.1 jieba3k-0.35.1 newspaper3k-0.2.8 pyvis-0.3.2 requests-file-1.5.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.1 wikipedia-1.4.0

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import math
import torch
import wikipedia
from newspaper import Article, ArticleException
from GoogleNews import GoogleNews
import IPython
from pyvis.network import Network
import pandas as pd
import numpy as np
from transformers import pipeline

# %%
triplet_extractor = pipeline('text2text-generation', model='Babelscape/rebel-large', tokenizer='Babelscape/rebel-large')
# We need to use the tokenizer manually since we need special tokens.
extracted_text = triplet_extractor.tokenizer.batch_decode([triplet_extractor("The coronavirus is “simply the common cold", return_tensors=True, return_text=False)[0]["generated_token_ids"]])
print(extracted_text[0])
# Function to parse the generated text and extract the triplets
def extract_triplets(text):
    triplets = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    for token in text.replace("<s>", "").replace("<pad>", "").replace("</s>", "").split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
    return triplets
extracted_triplets = extract_triplets(extracted_text[0])
print(extracted_triplets)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# <s><triplet> coronavirus <subj> common cold <obj> has effect <triplet> common cold <subj> coronavirus <obj> has cause</s>
# [{'head': 'coronavirus', 'type': 'has effect', 'tail': 'common cold'}, {'head': 'common cold', 'type': 'has cause', 'tail': 'coronavirus'}]

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

def extract_triplets(text):
    triplets = []
    relation, subject, relation, object_ = '', '', '', ''
    text = text.strip()
    current = 'x'
    for token in text.replace("<s>", "").replace("<pad>", "").replace("</s>", "").split():
        if token == "<triplet>":
            current = 't'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
                relation = ''
            subject = ''
        elif token == "<subj>":
            current = 's'
            if relation != '':
                triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
            object_ = ''
        elif token == "<obj>":
            current = 'o'
            relation = ''
        else:
            if current == 't':
                subject += ' ' + token
            elif current == 's':
                object_ += ' ' + token
            elif current == 'o':
                relation += ' ' + token
    if subject != '' and relation != '' and object_ != '':
        triplets.append({'head': subject.strip(), 'type': relation.strip(),'tail': object_.strip()})
    return triplets

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Babelscape/rebel-large")
model = AutoModelForSeq2SeqLM.from_pretrained("Babelscape/rebel-large")
gen_kwargs = {
    "max_length": 256,
    "length_penalty": 0,
    "num_beams": 3,
    "num_return_sequences": 3,
}

# Text to extract triplets from
text = 'The coronavirus is “simply the common cold.'

# Tokenizer text
model_inputs = tokenizer(text, max_length=256, padding=True, truncation=True, return_tensors = 'pt')

# Generate
generated_tokens = model.generate(
    model_inputs["input_ids"].to(model.device),
    attention_mask=model_inputs["attention_mask"].to(model.device),
    **gen_kwargs,
)

# Extract text
decoded_preds = tokenizer.batch_decode(generated_tokens, skip_special_tokens=False)

# Extract triplets
for idx, sentence in enumerate(decoded_preds):
    print(f'Prediction triplets sentence {idx}')
    print(extract_triplets(sentence))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Prediction triplets sentence 0
# [{'head': 'coronavirus', 'type': 'subclass of', 'tail': 'common cold'}]
# Prediction triplets sentence 1
# [{'head': 'coronavirus', 'type': 'has effect', 'tail': 'common cold'}, {'head': 'common cold', 'type': 'has cause', 'tail': 'coronavirus'}]
# Prediction triplets sentence 2
# [{'head': 'coronavirus', 'type': 'said to be the same as', 'tail': 'common cold'}, {'head': 'common cold', 'type': 'said to be the same as', 'tail': 'coronavirus'}]

# %%
df = pd.read_csv('/content/drive/MyDrive/Tesi & Stage/Code/PUBHEALTH/train.tsv', sep='\t', nrows = 500) #nrows = 500 per provare
df.head()
# Out:
#    claim_id                                              claim  \
# 0     15661  "The money the Clinton Foundation took from fr...
# 1      9893    Annual Mammograms May Have More False-Positives
# 2     11358  SBRT Offers Prostate Cancer Patients High Canc...
# 3     10166  Study: Vaccine for Breast, Ovarian Cancer Has ...
# 4     11276  Some appendicitis cases may not require ’emerg...
#
#        date_published                                        explanation  \
# 0      April 26, 2015  "Gingrich said the Clinton Foundation ""took m...
# 1    October 18, 2011  This article reports on the results of a study...
# 2  September 28, 2016  This news release describes five-year outcomes...
# 3    November 8, 2011  While the story does many things well, the ove...
# 4  September 20, 2010  We really don’t understand why only a handful ...
#
#                                        fact_checkers  \
# 0                                      Katie Sanders
# 1
# 2  Mary Chris Jaklevic,Steven J. Atlas, MD, MPH,K...
# 3
# 4
#
#                                            main_text  \
# 0  "Hillary Clinton is in the political crosshair...
# 1  While the financial costs of screening mammogr...
# 2  The news release quotes lead researcher Robert...
# 3  The story does discuss costs, but the framing ...
# 4  "Although the story didn’t cite the cost of ap...
#
#                                              sources    label  \
# 0  https://www.wsj.com/articles/clinton-foundatio...    false
# 1                                                     mixture
# 2  https://www.healthnewsreview.org/wp-content/up...  mixture
# 3  http://clinicaltrials.gov/ct2/results?term=can...     true
# 4                                                        true
#
#                                       subjects
# 0  Foreign Policy, PunditFact, Newt Gingrich,
# 1               Screening,WebMD,women's health
# 2      Association/Society news release,Cancer
# 3                  Cancer,WebMD,women's health
# 4

# %%
# Converti tutti i valori nella colonna 'claim' in stringhe
df['claim'] = df['claim'].astype(str)

# %%
# Function to apply
def apply_extraction(row):
    # Tokenize the text
    model_inputs = tokenizer(row['claim'], max_length=256, padding=True, truncation=True, return_tensors='pt')

    # Generate
    generated_tokens = model.generate(
        model_inputs["input_ids"].to(model.device),
        attention_mask=model_inputs["attention_mask"].to(model.device),
        **gen_kwargs,
    )

    # Decode
    decoded_preds = tokenizer.batch_decode(generated_tokens, skip_special_tokens=False)

    # Extract triplets
    triplets = []
    for idx, sentence in enumerate(decoded_preds):
        triplets.extend(extract_triplets(sentence))

    return triplets

# Apply the function to each row in the DataFrame
df['triplets'] = df.apply(apply_extraction, axis=1)

# Display the results
for index, row in df.iterrows():
    print(f"Claim ID: {row['claim_id']}")
    print(f"Triplets: {row['triplets']}")
    print("-" * 50)
# Out:
# Claim ID: 15661
# Triplets: [{'head': 'Hillary Clinton', 'type': 'position held', 'tail': 'secretary of state'}, {'head': 'Clinton Foundation', 'type': 'founded by', 'tail': 'Hillary Clinton'}, {'head': 'Hillary Clinton', 'type': 'position held', 'tail': 'secretary of state'}, {'head': 'Hillary Clinton', 'type': 'position held', 'tail': 'secretary of state'}, {'head': 'secretary of state', 'type': 'officeholder', 'tail': 'Hillary Clinton'}]
# --------------------------------------------------
# Claim ID: 9893
# Triplets: [{'head': 'False-Positives', 'type': 'facet of', 'tail': 'Annual Mammograms'}, {'head': 'False-Positives', 'type': 'part of', 'tail': 'Annual Mammograms'}, {'head': 'False-Positives', 'type': 'subclass of', 'tail': 'False-Positives'}]
# --------------------------------------------------
# Claim ID: 11358
# Triplets: [{'head': 'SBRT', 'type': 'medical condition treated', 'tail': 'Prostate Cancer'}, {'head': 'SBRT', 'type': 'medical condition treated', 'tail': 'Prostate Cancer'}, {'head': 'Prostate Cancer', 'type': 'drug used for treatment', 'tail': 'SBRT'}, {'head': 'SBRT', 'type': 'facet of', 'tail': 'Prostate Cancer'}]
# --------------------------------------------------
# Claim ID: 10166
# Triplets: [{'head': 'Ovarian Cancer', 'type': 'has part', 'tail': 'Breast'}, {'head': 'Breast', 'type': 'has effect', 'tail': 'Ovarian Cancer'}, {'head': 'Vaccine for Breast, Ovarian Cancer Has Potential', 'type': 'instance of', 'tail': 'Study'}]
# --------------------------------------------------
# Claim ID: 11276
# Triplets: [{'head': 'emergency', 'type': 'subclass of', 'tail': 'surgery'}, {'head': 'surgery', 'type': 'medical condition treated', 'tail': 'appendicitis'}, {'head': 'appendicitis', 'type': 'subclass of', 'tail': 'surgery'}]
# --------------------------------------------------
# Claim ID: 8713
# Triplets: [{'head': 'coronavirus', 'type': 'has effect', 'tail': 'antibody'}, {'head': 'coronavirus antibody test', 'type': 'country', 'tail': 'Britain'}, {'head': 'coronavirus antibody', 'type': 'country of origin', 'tail': 'Britain'}]
# --------------------------------------------------
# Claim ID: 9851
# Triplets: [{'head': 'new study', 'type': 'main subject', 'tail': 'Angioplasty through the wrist'}, {'head': 'Angioplasty through the wrist', 'type': 'studied by', 'tail': 'new study'}, {'head': 'new study', 'type': 'studies', 'tail': 'Angioplasty through the wrist'}, {'head': 'Angioplasty through the wrist', 'type': 'instance of', 'tail': 'new study'}]
# --------------------------------------------------
# Claim ID: 2768
# Triplets: [{'head': 'healthcare delivery reforms', 'type': 'country', 'tail': 'U.S.'}, {'head': 'healthcare delivery reform', 'type': 'country', 'tail': 'U.S.'}, {'head': 'health care reform', 'type': 'country', 'tail': 'U.S.'}]
# --------------------------------------------------
# Claim ID: 2717
# Triplets: [{'head': 'J&J', 'type': 'product or material produced', 'tail': 'talc'}, {'head': 'J&J talc litigations', 'type': 'located in the administrative territorial entity', 'tail': 'California'}, {'head': 'latest trial in J&J talc litigations', 'type': 'located in the administrative territorial entity', 'tail': 'California'}]
# --------------------------------------------------
# Claim ID: 10527
# Triplets: [{'head': 'drug', 'type': 'part of', 'tail': 'heart'}, {'head': 'heart drug', 'type': 'subclass of', 'tail': 'test results for heart drugs'}, {'head': 'Poor test results for heart drugs', 'type': 'subclass of', 'tail': 'test results'}]
# --------------------------------------------------
# Claim ID: 28215
# Triplets: [{'head': 'Lyme Disease', 'type': 'has cause', 'tail': 'tick'}, {'head': 'Lyme Disease', 'type': 'has cause', 'tail': 'ticks'}, {'head': 'ticks', 'type': 'has effect', 'tail': 'Lyme Disease'}]
# --------------------------------------------------
# Claim ID: 5793
# Triplets: [{'head': 'Trump', 'type': 'member of political party', 'tail': 'Democrats'}, {'head': 'Democrats hoping to flip House', 'type': 'opposite of', 'tail': 'Trump'}, {'head': 'Democrats', 'type': 'opposite of', 'tail': 'Trump'}, {'head': 'Trump', 'type': 'member of political party', 'tail': 'Democrats'}]
# --------------------------------------------------
# Claim ID: 36179
# Triplets: [{'head': 'Columbine', 'type': 'instance of', 'tail': 'massacres'}, {'head': 'Columbine', 'type': 'instance of', 'tail': 'massacres'}, {'head': 'Sandy Hook', 'type': 'instance of', 'tail': 'massacres'}, {'head': 'Marjory Stoneman Douglas', 'type': 'instance of', 'tail': 'massacres'}, {'head': 'Columbine', 'type': 'instance of', 'tail': 'massacres'}, {'head': 'Sandy Hook', 'type': 'instance of', 'tail': 'massacres'}]
# --------------------------------------------------
# Claim ID: 11433
# Triplets: [{'head': 'Early Testing', 'type': 'uses', 'tail': 'Genetic Marker'}, {'head': 'Genetic Marker', 'type': 'use', 'tail': 'Early Testing'}, {'head': 'Early Testing', 'type': 'uses', 'tail': 'Genetic Marker'}, {'head': 'Genetic Marker', 'type': 'used by', 'tail': 'Early Testing'}]
# --------------------------------------------------
# Claim ID: 12216
# Triplets: [{'head': '2011', 'type': 'point in time', 'tail': '2011'}, {'head': '2016', 'type': 'point in time', 'tail': '2016'}, {'head': 'opioid deaths', 'type': 'point in time', 'tail': '2011'}]
# --------------------------------------------------
# Claim ID: 30635
# Triplets: [{'head': 'crashed', 'type': 'located in the administrative territorial entity', 'tail': 'West Virginia'}, {'head': 'crashed due to a Deep State plot', 'type': 'located in the administrative territorial entity', 'tail': 'West Virginia'}, {'head': 'crashed due to a Deep State plot', 'type': 'location', 'tail': 'West Virginia'}]
# --------------------------------------------------
# Claim ID: 2981
# Triplets: [{'head': 'CES', 'type': 'instance of', 'tail': 'gadget show'}, {'head': 'Sex tech', 'type': 'subclass of', 'tail': 'startups'}, {'head': 'Sex tech from women-led startups', 'type': 'part of', 'tail': 'CES'}]
# --------------------------------------------------
# Claim ID: 29528
# Triplets: [{'head': 'Waxed apple', 'type': 'has effect', 'tail': 'cancer'}, {'head': 'Waxed apples', 'type': 'has effect', 'tail': 'cancer'}, {'head': 'Waxed apple', 'type': 'has effect', 'tail': 'cancer'}, {'head': 'cancer', 'type': 'has cause', 'tail': 'Waxed apple'}]
# --------------------------------------------------
# Claim ID: 26007
# Triplets: [{'head': 'Ghislaine Maxwell', 'type': 'has cause', 'tail': 'coronavirus'}, {'head': 'Ghislaine Maxwell', 'type': 'has effect', 'tail': 'coronavirus'}, {'head': 'Ghislaine Maxwell', 'type': 'employer', 'tail': 'BBC'}]
# --------------------------------------------------
# Claim ID: 13871
# Triplets: [{'head': 'fracked gas', 'type': 'subclass of', 'tail': 'fossil fuel'}, {'head': 'fracked', 'type': 'subclass of', 'tail': 'fossil fuel'}, {'head': 'fracked gas pipeline', 'type': 'product or material produced', 'tail': 'fossil fuel'}]
# --------------------------------------------------
# Claim ID: 3077
# Triplets: [{'head': 'health care providers', 'type': 'facet of', 'tail': 'HIV'}, {'head': 'HIV', 'type': 'studied by', 'tail': 'health care providers'}, {'head': 'HIV surge', 'type': 'facet of', 'tail': 'health care providers'}]
# --------------------------------------------------
# Claim ID: 30992
# Triplets: [{'head': 'President', 'type': 'officeholder', 'tail': 'Donald Trump'}, {'head': 'Donald Trump', 'type': 'position held', 'tail': 'President'}, {'head': '2017 Emmy Awards', 'type': 'point in time', 'tail': '2017'}, {'head': 'Donald Trump', 'type': 'position held', 'tail': 'President'}]
# --------------------------------------------------
# Claim ID: 32993
# Triplets: [{'head': 'Hillary Clinton', 'type': 'employer', 'tail': 'Monsanto'}, {'head': 'Monsanto', 'type': 'chairperson', 'tail': 'Hillary Clinton'}, {'head': 'Monsanto', 'type': 'subsidiary', 'tail': 'board of directors'}]
# --------------------------------------------------
# Claim ID: 15232
# Triplets: [{'head': 'Rhode Island', 'type': 'instance of', 'tail': 'state'}, {'head': 'mandate', 'type': 'subclass of', 'tail': 'regulatory fiat'}, {'head': 'mandate', 'type': 'applies to jurisdiction', 'tail': 'Rhode Island'}]
# --------------------------------------------------
# Claim ID: 9605
# Triplets: [{'head': '2008 Summer Olympics', 'type': 'point in time', 'tail': '2008'}, {'head': '2012 NFL Draft', 'type': 'point in time', 'tail': '2012'}, {'head': '2012 NFL season', 'type': 'point in time', 'tail': '2012'}]
# --------------------------------------------------
# Claim ID: 37873
# Triplets: [{'head': 'mask', 'type': 'manufacturer', 'tail': 'CostCo'}, {'head': 'mask', 'type': 'used by', 'tail': 'CostCo'}, {'head': 'mask', 'type': 'owned by', 'tail': 'CostCo'}]
# --------------------------------------------------
# Claim ID: 7453
# Triplets: [{'head': 'virus crisis red flags', 'type': 'country', 'tail': 'Brazil'}, {'head': 'virus crisis', 'type': 'country', 'tail': 'Brazil'}, {'head': 'virus crisis', 'type': 'location', 'tail': 'Brazil'}]
# --------------------------------------------------
# Claim ID: 10931
# Triplets: [{'head': 'Irregular Heartbeat', 'type': 'has cause', 'tail': 'Laser Used to Blast Away Cells Causing Irregular Heartbeat'}, {'head': 'Irregular Heartbeat', 'type': 'has cause', 'tail': 'Laser'}, {'head': 'Irregular Heartbeat', 'type': 'has cause', 'tail': 'Laser Used to Blast Away Cells Causing Laser Used to Blast Away Cells Causing Irregular Heartbeat'}]
# --------------------------------------------------
# Claim ID: 8069
# Triplets: [{'head': 'new government', 'type': 'country', 'tail': 'Slovakia'}, {'head': "Slovakia's new government", 'type': 'country', 'tail': 'Slovakia'}, {'head': "Slovakia's new government", 'type': 'field of work', 'tail': 'coronavirus testing'}]
# --------------------------------------------------
# Claim ID: 26723
# Triplets: [{'head': 'coronavirus', 'type': 'subclass of', 'tail': 'common cold'}, {'head': 'coronavirus', 'type': 'said to be the same as', 'tail': 'common cold'}, {'head': 'common cold', 'type': 'said to be the same as', 'tail': 'coronavirus'}, {'head': 'coronavirus', 'type': 'has effect', 'tail': 'common cold'}, {'head': 'common cold', 'type': 'has cause', 'tail': 'coronavirus'}]
# --------------------------------------------------
# Claim ID: 10307
# Triplets: [{'head': 'heart disease', 'type': 'has effect', 'tail': 'reversing'}, {'head': 'Heart disease', 'type': 'has effect', 'tail': 'reversing'}, {'head': 'heart disease', 'type': 'has cause', 'tail': 'reversing'}]
# --------------------------------------------------
# Claim ID: 31799
# Triplets: [{'head': 'Microwave oven', 'type': 'country', 'tail': 'USSR'}, {'head': 'Microwave oven', 'type': 'country of origin', 'tail': 'USSR'}, {'head': 'Microwave ovens were banned in the USSR', 'type': 'point in time', 'tail': '1976'}]
# --------------------------------------------------
# Claim ID: 31852
# Triplets: [{'head': 'Jimi Hendrix', 'type': 'influenced by', 'tail': 'Jim Morrison'}, {'head': 'Jimi Hendrix', 'type': 'uses', 'tail': 'Bic lighter'}, {'head': 'Jim Morrison', 'type': 'uses', 'tail': 'Bic lighter'}, {'head': 'Janis Joplin', 'type': 'uses', 'tail': 'Bic lighter'}, {'head': 'Kurt Cobain', 'type': 'uses', 'tail': 'Bic lighter'}, {'head': 'Jimi Hendrix', 'type': 'uses', 'tail': 'Bic lighters'}, {'head': 'Jim Morrison', 'type': 'uses', 'tail': 'Bic lighters'}, {'head': 'Janis Joplin', 'type': 'uses', 'tail': 'Bic lighters'}, {'head': 'Kurt Cobain', 'type': 'uses', 'tail': 'Bic lighters'}]
# --------------------------------------------------
# Claim ID: 12123
# Triplets: [{'head': 'boy', 'type': 'different from', 'tail': 'girl'}, {'head': 'girl', 'type': 'different from', 'tail': 'boy'}, {'head': 'gender is fluid', 'type': 'facet of', 'tail': 'gender'}, {'head': 'boy', 'type': 'opposite of', 'tail': 'girl'}]
# --------------------------------------------------
# Claim ID: 10149
# Triplets: [{'head': 'Spiriva', 'type': 'medical condition treated', 'tail': 'asthma'}, {'head': 'asthma', 'type': 'drug used for treatment', 'tail': 'Spiriva'}, {'head': 'Spiriva', 'type': 'medical condition treated', 'tail': 'asthma'}, {'head': 'Serevent', 'type': 'medical condition treated', 'tail': 'asthma'}, {'head': 'asthma', 'type': 'drug used for treatment', 'tail': 'Serevent'}]
# --------------------------------------------------
# Claim ID: 5243
# Triplets: [{'head': 'rating system', 'type': 'facet of', 'tail': 'addiction treatment'}, {'head': 'rating system', 'type': 'use', 'tail': 'addiction treatment'}, {'head': 'addiction treatment rating system', 'type': 'located in the administrative territorial entity', 'tail': 'Massachusetts'}]
# --------------------------------------------------
# Claim ID: 36991
# Triplets: [{'head': 'John Kerry', 'type': 'position held', 'tail': 'Secretary of State'}, {'head': 'John Kerry’s', 'type': 'position held', 'tail': 'Secretary of State'}, {'head': 'Secretary of State', 'type': 'officeholder', 'tail': 'John Kerry'}, {'head': 'John Kerry', 'type': 'position held', 'tail': 'Secretary of State'}]
# --------------------------------------------------
# Claim ID: 702
# Triplets: [{'head': 'climate footprint', 'type': 'facet of', 'tail': 'U.N.'}, {'head': 'Paris Agreement', 'type': 'main subject', 'tail': 'climate change'}, {'head': 'climate footprint', 'type': 'creator', 'tail': 'U.N.'}]
# --------------------------------------------------
# Claim ID: 4639
# Triplets: [{'head': 'ice bucket challenge', 'type': 'main subject', 'tail': 'ALS'}, {'head': 'ice bucket challenge', 'type': 'facet of', 'tail': 'ALS'}, {'head': 'ice bucket challenge', 'type': 'main subject', 'tail': 'ALS patient'}]
# --------------------------------------------------
# Claim ID: 3801
# Triplets: [{'head': 'Legislature', 'type': 'has part', 'tail': 'State Senate'}, {'head': 'State Senate leader', 'type': 'part of', 'tail': 'Legislature'}, {'head': 'Legislature', 'type': 'has part', 'tail': 'State Senate leader'}, {'head': 'State Senate', 'type': 'office held by head of the organization', 'tail': 'Senate leader'}]
# --------------------------------------------------
# Claim ID: 10018
# Triplets: [{'head': 'Menopause', 'type': 'has effect', 'tail': 'A flash of concern'}, {'head': 'Menopause', 'type': 'has effect', 'tail': 'flash of concern'}, {'head': 'Menopause', 'type': 'has effect', 'tail': 'A flash of concern'}, {'head': 'A flash of concern', 'type': 'facet of', 'tail': 'Menopause'}]
# --------------------------------------------------
# Claim ID: 29931
# Triplets: [{'head': 'Elizabeth Warren', 'type': 'significant event', 'tail': 'having their tonsils removed'}, {'head': 'Elizabeth Warren', 'type': 'significant event', 'tail': 'Having an abortion'}, {'head': 'Elizabeth Warren', 'type': 'significant event', 'tail': 'having their tonsils removed'}, {'head': 'having their tonsils removed', 'type': 'participant', 'tail': 'Elizabeth Warren'}]
# --------------------------------------------------
# Claim ID: 26761
# Triplets: [{'head': 'coronavirus', 'type': 'country of origin', 'tail': 'United States'}, {'head': 'coronavirus in the United States', 'type': 'distributed by', 'tail': 'Instagram'}, {'head': 'coronavirus in the United States', 'type': 'has effect', 'tail': 'no one has died from the coronavirus in the United States'}]
# --------------------------------------------------
# Claim ID: 14336
# Triplets: [{'head': "Rick Scott's Starbucks heckler", 'type': 'facet of', 'tail': 'Rick Scott'}, {'head': "Rick Scott's Starbucks heckler Says Rick Scott", 'type': 'facet of', 'tail': 'Rick Scott'}, {'head': "Rick Scott's Starbucks heckler Says Rick Scott", 'type': 'named after', 'tail': 'Rick Scott'}]
# --------------------------------------------------
# Claim ID: 41009
# Triplets: [{'head': 'Italy', 'type': 'continent', 'tail': 'Europe'}, {'head': 'Italy', 'type': 'part of', 'tail': 'Europe'}, {'head': 'oldest population in Europe', 'type': 'country', 'tail': 'Italy'}]
# --------------------------------------------------
# Claim ID: 8737
# Triplets: [{'head': 'Coronavirus', 'type': 'has effect', 'tail': 'SARS'}, {'head': 'SARS', 'type': 'has cause', 'tail': 'Coronavirus'}]
# --------------------------------------------------
# Claim ID: 12494
# Triplets: [{'head': 'border', 'type': 'country', 'tail': 'United States'}, {'head': 'United States', 'type': 'shares border with', 'tail': 'Mexico'}, {'head': 'Mexico', 'type': 'shares border with', 'tail': 'United States'}, {'head': 'the border', 'type': 'country', 'tail': 'United States'}]
# --------------------------------------------------
# Claim ID: 2572
# Triplets: [{'head': 'basic', 'type': 'opposite of', 'tail': 'high-tech'}, {'head': 'basic', 'type': 'subclass of', 'tail': 'high-tech'}, {'head': 'Holiday fitness gifts', 'type': 'subclass of', 'tail': 'gifts'}]
# --------------------------------------------------
# Claim ID: 40739
# Triplets: [{'head': 'Shakira', 'type': 'employer', 'tail': 'MTV'}, {'head': 'The eRumor', 'type': 'main subject', 'tail': 'Shakira'}, {'head': 'The eRumor', 'type': 'instance of', 'tail': 'boycott'}]
# --------------------------------------------------
# Claim ID: 34499
# Triplets: [{'head': 'John Kerry', 'type': 'position held', 'tail': 'Secretary of State'}, {'head': 'John Kerry', 'type': 'position held', 'tail': 'Secretary of State'}, {'head': 'John Kerry', 'type': 'child', 'tail': "his daughter's"}, {'head': "his daughter's", 'type': 'father', 'tail': 'John Kerry'}, {'head': 'John Kerry', 'type': 'position held', 'tail': 'Secretary of State'}, {'head': 'John Kerry', 'type': 'child', 'tail': 'his daughter'}, {'head': 'his daughter', 'type': 'father', 'tail': 'John Kerry'}]
# --------------------------------------------------
# Claim ID: 26595
# Triplets: [{'head': 'five ways people can prevent the novel coronavirus', 'type': 'instance of', 'tail': 'An audio message'}, {'head': 'five ways people can prevent the novel coronavirus', 'type': 'instance of', 'tail': 'audio message'}, {'head': 'five ways people can prevent', 'type': 'facet of', 'tail': 'coronavirus'}]
# --------------------------------------------------
# Claim ID: 7606
# Triplets: [{'head': 'Mass virus test in nursing home', 'type': 'main subject', 'tail': 'loneliness'}, {'head': 'Mass virus test in nursing home', 'type': 'facet of', 'tail': 'loneliness'}, {'head': 'Mass virus test', 'type': 'main subject', 'tail': 'loneliness'}]
# --------------------------------------------------
# Claim ID: 23166
# Triplets: [{'head': "Annie's List", 'type': 'founded by', 'tail': 'Dwayne Bohac'}, {'head': 'Dwayne Bohac', 'type': 'member of political party', 'tail': "Annie's List"}, {'head': "Annie's List", 'type': 'political ideology', 'tail': 'abortion on demand'}]
# --------------------------------------------------
# Claim ID: 10101
# Triplets: [{'head': 'implant', 'type': 'medical condition treated', 'tail': 'sleep apnea'}, {'head': 'implant', 'type': 'medical condition treated', 'tail': 'sleep apnea'}, {'head': 'sleep apnea', 'type': 'drug used for treatment', 'tail': 'implant'}, {'head': 'implant can block sleep apnea', 'type': 'instance of', 'tail': 'implant'}]
# --------------------------------------------------
# Claim ID: 8628
# Triplets: [{'head': 'Tokyo', 'type': 'office held by head of government', 'tail': 'governor'}, {'head': 'governor', 'type': 'applies to jurisdiction', 'tail': 'Tokyo'}, {'head': 'Tokyo', 'type': 'office held by head of government', 'tail': 'governor'}, {'head': 'coronavirus', 'type': 'location', 'tail': 'Tokyo'}]
# --------------------------------------------------
# Claim ID: 15032
# Triplets: [{'head': 'gun industry', 'type': 'country', 'tail': 'America'}, {'head': 'gun industry', 'type': 'instance of', 'tail': 'business'}, {'head': 'Gun industry', 'type': 'country', 'tail': 'America'}]
# --------------------------------------------------
# Claim ID: 35637
# Triplets: [{'head': 'deliberately faked symptoms of pregnancy', 'type': 'facet of', 'tail': 'captive panda'}, {'head': 'faked symptoms of pregnancy', 'type': 'facet of', 'tail': 'captive panda'}, {'head': 'faked symptoms of pregnancy', 'type': 'used by', 'tail': 'captive panda'}]
# --------------------------------------------------
# Claim ID: 6818
# Triplets: [{'head': 'cleanup', 'type': 'facet of', 'tail': 'Everglades'}, {'head': 'cleanup', 'type': 'location', 'tail': 'Everglades'}, {'head': 'Everglades', 'type': 'significant event', 'tail': 'cleanup'}]
# --------------------------------------------------
# Claim ID: 37568
# Triplets: [{'head': 'clergyman', 'type': 'located in the administrative territorial entity', 'tail': 'Washington, DC'}, {'head': 'clergyman tested positive', 'type': 'has cause', 'tail': 'COVID-19'}, {'head': 'clergyman tested positive', 'type': 'facet of', 'tail': 'COVID-19'}]
# --------------------------------------------------
# Claim ID: 12479
# Triplets: [{'head': 'Dan Patrick', 'type': 'work location', 'tail': 'Texas'}, {'head': 'Dan Patrick', 'type': 'employer', 'tail': 'Texas'}, {'head': 'Dan Patrick', 'type': 'residence', 'tail': 'Texas'}]
# --------------------------------------------------
# Claim ID: 3775
# Triplets: [{'head': 'vape', 'type': 'has part', 'tail': 'tobacco'}, {'head': 'menthol cigarettes', 'type': 'subclass of', 'tail': 'tobacco'}, {'head': 'menthol cigarette', 'type': 'subclass of', 'tail': 'tobacco'}]
# --------------------------------------------------
# Claim ID: 31187
# Triplets: [{'head': 'villagers', 'type': 'country', 'tail': 'Indonesia'}, {'head': 'village', 'type': 'country', 'tail': 'Indonesia'}, {'head': 'villagers performed a dead woman back to life', 'type': 'country', 'tail': 'Indonesia'}]
# --------------------------------------------------
# Claim ID: 14753
# Triplets: [{'head': 'Medicaid expansion', 'type': 'applies to jurisdiction', 'tail': 'Commonwealth of Virginia'}, {'head': 'Medicaid', 'type': 'located in the administrative territorial entity', 'tail': 'Commonwealth of Virginia'}, {'head': 'Medicaid expansion', 'type': 'located in the administrative territorial entity', 'tail': 'Commonwealth of Virginia'}]
# --------------------------------------------------
# Claim ID: 7171
# Triplets: [{'head': 'wildfires grow deadlier', 'type': 'subclass of', 'tail': 'wildfire'}, {'head': 'wildfire', 'type': 'studied by', 'tail': 'officials'}, {'head': 'wildfire', 'type': 'studied by', 'tail': 'officials'}, {'head': 'officials', 'type': 'studies', 'tail': 'wildfire'}]
# --------------------------------------------------
# Claim ID: 16297
# Triplets: [{'head': 'sneeze', 'type': 'has effect', 'tail': 'cough'}, {'head': 'cough', 'type': 'has effect', 'tail': 'sneeze'}, {'head': 'cough', 'type': 'has cause', 'tail': 'sneeze'}]
# --------------------------------------------------
# Claim ID: 14848
# Triplets: [{'head': 'HIV', 'type': 'has effect', 'tail': 'AIDS'}, {'head': 'HIV', 'type': 'has effect', 'tail': 'AIDS'}, {'head': 'AIDS', 'type': 'has cause', 'tail': 'HIV'}, {'head': 'AIDS', 'type': 'has cause', 'tail': 'HIV'}]
# --------------------------------------------------
# Claim ID: 28785
# Triplets: [{'head': 'stem cell bank', 'type': 'product or material produced', 'tail': 'Stem cell'}, {'head': 'stem cell bank', 'type': 'field of work', 'tail': 'Stem cell'}, {'head': 'stem cell banks', 'type': 'product or material produced', 'tail': 'Stem cell'}]
# --------------------------------------------------
# Claim ID: 14624
# Triplets: [{'head': 'mosquitos', 'type': 'subclass of', 'tail': 'mosquitos'}, {'head': 'Zika virus', 'type': 'has effect', 'tail': 'Bioweapon!'}, {'head': 'mosquitos', 'type': 'has parts of the class', 'tail': 'mosquitos'}]
# --------------------------------------------------
# Claim ID: 17148
# Triplets: [{'head': 'Bruce Braley', 'type': 'member of political party', 'tail': 'Freedom Partners'}, {'head': 'Bruce Braley', 'type': 'member of political party', 'tail': 'Freedom Partners Says Bruce Braley'}, {'head': 'Bruce Braley', 'type': 'employer', 'tail': 'Freedom Partners Says Bruce Braley'}]
# --------------------------------------------------
# Claim ID: 33670
# Triplets: [{'head': 'Shaving', 'type': 'has effect', 'tail': 'hair grow back in thicker, faster, and fuller'}, {'head': 'hair grow back in thicker, faster, and fuller', 'type': 'has cause', 'tail': 'Shaving'}, {'head': 'Shaving', 'type': 'has effect', 'tail': 'hair grow back in thicker, faster, and fuller.'}, {'head': 'hair grow back in thicker, faster, and fuller.', 'type': 'has cause', 'tail': 'Shaving'}, {'head': 'Shaving', 'type': 'has effect', 'tail': 'hair grow back'}]
# --------------------------------------------------
# Claim ID: 3165
# Triplets: [{'head': 'election office', 'type': 'applies to jurisdiction', 'tail': 'Arkansas'}, {'head': 'Arkansas election office', 'type': 'applies to jurisdiction', 'tail': 'Arkansas'}, {'head': 'election office', 'type': 'located in the administrative territorial entity', 'tail': 'Arkansas'}]
# --------------------------------------------------
# Claim ID: 1391
# Triplets: [{'head': 'Lancashire', 'type': 'country', 'tail': 'Britain'}, {'head': 'bird flu case in Lancashire', 'type': 'country', 'tail': 'Britain'}, {'head': 'Britain', 'type': 'contains administrative territorial entity', 'tail': 'Lancashire'}, {'head': 'Lancashire', 'type': 'country', 'tail': 'Britain'}]
# --------------------------------------------------
# Claim ID: 16316
# Triplets: [{'head': 'Medicaid', 'type': 'located in the administrative territorial entity', 'tail': 'Florida'}, {'head': 'expanded Medicaid', 'type': 'applies to jurisdiction', 'tail': 'Florida'}, {'head': 'Medicaid', 'type': 'applies to jurisdiction', 'tail': 'Florida'}]
# --------------------------------------------------
# Claim ID: 41639
# Triplets: [{'head': 'NHS', 'type': 'located in the administrative territorial entity', 'tail': 'England'}, {'head': 'new money', 'type': 'facet of', 'tail': 'NHS'}, {'head': 'new money', 'type': 'part of', 'tail': 'NHS'}]
# --------------------------------------------------
# Claim ID: 40835
# Triplets: [{'head': 'Brexit', 'type': 'participant', 'tail': 'EU'}, {'head': 'Brexit', 'type': 'facet of', 'tail': 'EU migrants'}, {'head': 'Brexit', 'type': 'has cause', 'tail': 'EU migrants'}]
# --------------------------------------------------
# Claim ID: 2258
# Triplets: [{'head': 'air pollution plan', 'type': 'country', 'tail': 'Britain'}, {'head': 'Britain loses case to delay submission of air pollution plan', 'type': 'main subject', 'tail': 'air pollution'}, {'head': 'Britain', 'type': 'has part', 'tail': 'air pollution'}]
# --------------------------------------------------
# Claim ID: 21809
# Triplets: [{'head': 'Korean cars', 'type': 'country', 'tail': 'United States'}, {'head': 'Korea', 'type': 'diplomatic relation', 'tail': 'United States'}, {'head': 'United States', 'type': 'diplomatic relation', 'tail': 'Korea'}, {'head': 'Korea', 'type': 'shares border with', 'tail': 'United States'}]
# --------------------------------------------------
# Claim ID: 11447
# Triplets: [{'head': 'Tai Chi', 'type': 'medical condition treated', 'tail': 'Fibromyalgia'}, {'head': 'Fibromyalgia', 'type': 'drug used for treatment', 'tail': 'Tai Chi'}, {'head': 'Tai Chi', 'type': 'medical condition treated', 'tail': 'Fibromyalgia'}, {'head': 'Fibromyalgia', 'type': 'drug used for treatment', 'tail': 'Tai Chi'}]
# --------------------------------------------------
# Claim ID: 10042
# Triplets: [{'head': 'AbioCor', 'type': 'manufacturer', 'tail': 'FDA'}, {'head': 'AbioCor', 'type': 'author', 'tail': 'FDA'}, {'head': 'AbioCor', 'type': 'developer', 'tail': 'FDA'}]
# --------------------------------------------------
# Claim ID: 9578
# Triplets: [{'head': 'Unshakable tremor', 'type': 'subclass of', 'tail': 'tremor'}, {'head': 'New treatment', 'type': 'medical condition treated', 'tail': 'tremor'}, {'head': 'New treatment', 'type': 'medical condition treated', 'tail': 'tremor'}, {'head': 'tremor', 'type': 'drug used for treatment', 'tail': 'New treatment'}]
# --------------------------------------------------
# Claim ID: 9710
# Triplets: [{'head': 'Cotellic', 'type': 'medical condition treated', 'tail': 'Melanoma'}, {'head': 'Melanoma', 'type': 'drug used for treatment', 'tail': 'Cotellic'}, {'head': 'Cotellic', 'type': 'medical condition treated', 'tail': 'Melanoma'}, {'head': 'Cotellic Treatment for Melanoma', 'type': 'manufacturer', 'tail': 'Roche'}]
# --------------------------------------------------
# Claim ID: 42183
# Triplets: [{'head': 'deaths in Illinois', 'type': 'facet of', 'tail': 'synthetic marijuana'}, {'head': '"synthetic marijuana"', 'type': 'parent organization', 'tail': 'FDA'}, {'head': '"synthetic marijuana" leads to deaths in Illinois', 'type': 'facet of', 'tail': 'synthetic marijuana'}]
# --------------------------------------------------
# Claim ID: 28199
# Triplets: [{'head': 'Road to Majority', 'type': 'point in time', 'tail': '2016'}, {'head': 'Road to Majority conference', 'type': 'point in time', 'tail': '2016'}, {'head': 'Road to Majority', 'type': 'organizer', 'tail': 'Faith & Freedom Coalition'}]
# --------------------------------------------------
# Claim ID: 26471
# Triplets: [{'head': 'COVID-19', 'type': 'different from', 'tail': 'COVID-1'}, {'head': 'COVID-1', 'type': 'different from', 'tail': 'COVID-19'}, {'head': 'COVID-1', 'type': 'followed by', 'tail': 'COVID-19'}, {'head': 'COVID-19', 'type': 'different from', 'tail': 'COVID-1'}]
# --------------------------------------------------
# Claim ID: 8947
# Triplets: [{'head': 'Fermented dairy products', 'type': 'has effect', 'tail': 'heart attack'}, {'head': 'Fermented dairy product', 'type': 'has effect', 'tail': 'heart attack'}, {'head': 'Fermented dairy products', 'type': 'has effect', 'tail': 'protect against heart attack'}]
# --------------------------------------------------
# Claim ID: 8247
# Triplets: [{'head': 'virus deaths surge', 'type': 'country', 'tail': 'UK'}, {'head': 'UK calls for 250,000 volunteers', 'type': 'main subject', 'tail': 'virus deaths surge'}, {'head': 'UK calls for 250,000 volunteers', 'type': 'facet of', 'tail': 'virus deaths surge'}]
# --------------------------------------------------
# Claim ID: 10118
# Triplets: [{'head': 'first inhalable version of insulin', 'type': 'author', 'tail': 'FDA'}, {'head': 'first inhalable version of insulin', 'type': 'manufacturer', 'tail': 'FDA'}, {'head': 'first inhalable version of insulin', 'type': 'developer', 'tail': 'FDA'}]
# --------------------------------------------------
# Claim ID: 99
# Triplets: [{'head': 'thirsty energy industry', 'type': 'country', 'tail': 'Iran'}, {'head': 'water shortage', 'type': 'country', 'tail': 'Iran'}, {'head': 'thirsty energy industry', 'type': 'country', 'tail': "Iran's"}]
# --------------------------------------------------
# Claim ID: 30597
# Triplets: [{'head': 'Tamiflu', 'type': 'has effect', 'tail': 'this flu season'}, {'head': 'this flu season', 'type': 'has cause', 'tail': 'Tamiflu'}, {'head': 'Tamiflu', 'type': 'has effect', 'tail': 'increased number of deaths this flu season'}, {'head': 'increased number of deaths this flu season', 'type': 'has cause', 'tail': 'Tamiflu'}, {'head': 'Tamiflu', 'type': 'has effect', 'tail': 'this flu season'}]
# --------------------------------------------------
# Claim ID: 12926
# Triplets: [{'head': 'Planned Parenthood', 'type': 'field of work', 'tail': 'family planning'}, {'head': 'Planned Parenthood', 'type': 'industry', 'tail': 'family planning'}, {'head': 'Obama administration', 'type': 'instance of', 'tail': 'federal family planning funding'}]
# --------------------------------------------------
# Claim ID: 6671
# Triplets: [{'head': 'Plague confirmed in prairie dogs', 'type': 'location', 'tail': 'Commerce City'}, {'head': 'Plague confirmed in prairie dogs', 'type': 'located in the administrative territorial entity', 'tail': 'Commerce City'}, {'head': 'Plague confirmed in prairie dogs in Commerce City', 'type': 'location', 'tail': 'Commerce City'}]
# --------------------------------------------------
# Claim ID: 8556
# Triplets: [{'head': 'Indonesia', 'type': 'shares border with', 'tail': 'Malaysia'}, {'head': 'Malaysia', 'type': 'shares border with', 'tail': 'Indonesia'}, {'head': 'Indonesia', 'type': 'shares border with', 'tail': 'Malaysia'}, {'head': 'Malaysia', 'type': 'shares border with', 'tail': 'Indonesia'}]
# --------------------------------------------------
# Claim ID: 26473
# Triplets: [{'head': 'COVID-19 order', 'type': 'applies to jurisdiction', 'tail': 'Michigan'}, {'head': 'COVID-19', 'type': 'location', 'tail': 'Michigan'}, {'head': 'COVID-19', 'type': 'applies to jurisdiction', 'tail': 'Michigan'}]
# --------------------------------------------------
# Claim ID: 21026
# Triplets: [{'head': 'federal stimulus program', 'type': 'end time', 'tail': 'July 2011'}, {'head': 'federal stimulus program', 'type': 'point in time', 'tail': 'July 2011'}, {'head': 'stimulus program', 'type': 'country', 'tail': 'federal'}]
# --------------------------------------------------
# Claim ID: 7454
# Triplets: [{'head': 'hotel', 'type': 'subclass of', 'tail': 'attractions'}, {'head': 'gym', 'type': 'subclass of', 'tail': 'attractions'}, {'head': 'gym', 'type': 'subclass of', 'tail': 'attraction'}]
# --------------------------------------------------
# Claim ID: 22806
# Triplets: [{'head': 'Greenest County in America', 'type': 'country', 'tail': 'America'}, {'head': 'Greenest County', 'type': 'country', 'tail': 'America'}, {'head': 'The Greenest County in America', 'type': 'country', 'tail': 'America'}]
# --------------------------------------------------
# Claim ID: 6183
# Triplets: [{'head': 'New California laws', 'type': 'applies to jurisdiction', 'tail': 'California'}, {'head': 'new California laws', 'type': 'applies to jurisdiction', 'tail': 'California'}, {'head': 'California laws', 'type': 'applies to jurisdiction', 'tail': 'California'}]
# --------------------------------------------------
# Claim ID: 21950
# Triplets: [{'head': 'strangulation', 'type': 'subclass of', 'tail': 'violent deaths'}, {'head': 'strangulation', 'type': 'subclass of', 'tail': 'violent death'}, {'head': 'strangulation', 'type': 'subclass of', 'tail': 'violent deaths in the U.S.'}]
# --------------------------------------------------
# Claim ID: 37880
# Triplets: [{'head': 'Quarantine', 'type': 'subclass of', 'tail': 'movement'}, {'head': 'Quarantine', 'type': 'subclass of', 'tail': 'restrict the movement'}, {'head': 'Quarantine', 'type': 'subclass of', 'tail': 'movement of sick people'}]
# --------------------------------------------------
# Claim ID: 37893
# Triplets: [{'head': 'vaccine', 'type': 'facet of', 'tail': 'coronavirus'}, {'head': 'vaccine', 'type': 'has cause', 'tail': 'coronavirus'}, {'head': 'coronavirus', 'type': 'drug used for treatment', 'tail': 'vaccine'}, {'head': 'vaccine', 'type': 'medical condition treated', 'tail': 'coronavirus'}]
# --------------------------------------------------
# Claim ID: 18292
# Triplets: [{'head': 'Affordable Care Act', 'type': 'has effect', 'tail': 'Chain email'}, {'head': 'Affordable Care Act', 'type': 'has part', 'tail': 'Chain email'}, {'head': 'Affordable Care Act', 'type': 'has part', 'tail': 'chain email'}]
# --------------------------------------------------
# Claim ID: 26523
# Triplets: [{'head': 'Daniel Kelly', 'type': 'position held', 'tail': 'Supreme Court Justice'}, {'head': 'Daniel Kelly', 'type': 'member of political party', 'tail': 'Wisconsin Democrats'}, {'head': 'Daniel Kelly', 'type': 'employer', 'tail': 'Supreme Court'}]
# --------------------------------------------------
# Claim ID: 9491
# Triplets: [{'head': 'Heart Attack', 'type': 'studied by', 'tail': 'Heart Imaging'}, {'head': 'New Heart Imaging Method', 'type': 'medical condition treated', 'tail': 'Heart Attack'}, {'head': 'Heart Attack', 'type': 'studied by', 'tail': 'Heart Imaging Method'}]
# --------------------------------------------------
# Claim ID: 2974
# Triplets: [{'head': 'medical marijuana', 'type': 'located in the administrative territorial entity', 'tail': 'New Mexico'}, {'head': 'medical marijuana', 'type': 'applies to jurisdiction', 'tail': 'New Mexico'}, {'head': 'medical marijuana', 'type': 'location', 'tail': 'New Mexico'}]
# --------------------------------------------------
# Claim ID: 18022
# Triplets: [{'head': 'forced home inspections', 'type': 'part of', 'tail': 'Obamacare'}, {'head': '"forced home inspections"', 'type': 'part of', 'tail': 'Obamacare'}, {'head': '"forced home inspections" by government agents', 'type': 'part of', 'tail': 'Obamacare'}]
# --------------------------------------------------
# Claim ID: 8920
# Triplets: [{'head': 'San Francisco', 'type': 'instance of', 'tail': 'cruise ship'}, {'head': 'cruise ship', 'type': 'has part', 'tail': 'passengers'}, {'head': 'passengers', 'type': 'part of', 'tail': 'cruise ship'}, {'head': "cruise ship passengers 'in limbo' off San Francisco", 'type': 'facet of', 'tail': 'coronavirus'}]
# --------------------------------------------------
# Claim ID: 2304
# Triplets: [{'head': 'blood test', 'type': 'facet of', 'tail': "Alzheimer's"}, {'head': 'test', 'type': 'facet of', 'tail': "Alzheimer's"}, {'head': 'blood test', 'type': 'medical condition treated', 'tail': "Alzheimer's"}]
# --------------------------------------------------
# Claim ID: 37788
# Triplets: [{'head': 'professional hairstyles for men', 'type': 'different from', 'tail': 'professional hairstyles for women'}, {'head': 'professional hairstyles for women', 'type': 'different from', 'tail': 'professional hairstyles for men'}, {'head': 'Unprofessional hairstyles for men', 'type': 'different from', 'tail': 'Unprofessional hairstyles for women'}, {'head': 'Unprofessional hairstyles for women', 'type': 'different from', 'tail': 'Unprofessional hairstyles for men'}, {'head': 'professional hairstyles for men', 'type': 'different from', 'tail': 'professional hairstyles for women'}]
# --------------------------------------------------
# Claim ID: 33085
# Triplets: [{'head': 'Barack Obama', 'type': 'position held', 'tail': 'President'}, {'head': 'body language', 'type': 'facet of', 'tail': 'psychopath'}, {'head': 'body language expert', 'type': 'studies', 'tail': 'psychopath'}, {'head': 'psychopath', 'type': 'studied by', 'tail': 'body language expert'}]
# --------------------------------------------------
# Claim ID: 28379
# Triplets: [{'head': "Brett Kavanaugh's Supreme Court nomination", 'type': 'has effect', 'tail': 'withdrawal'}, {'head': 'Brett Kavanaugh', 'type': 'participant in', 'tail': 'Supreme Court nomination'}, {'head': 'Supreme Court nomination', 'type': 'participant', 'tail': 'Brett Kavanaugh'}, {'head': "Brett Kavanaugh's Supreme Court nomination", 'type': 'instance of', 'tail': 'withdrawal'}]
# --------------------------------------------------
# Claim ID: 31932
# Triplets: [{'head': '911', 'type': 'uses', 'tail': 'landline'}, {'head': 'self-dial 911', 'type': 'subclass of', 'tail': 'landline'}, {'head': '911', 'type': 'uses', 'tail': 'self-dial'}]
# --------------------------------------------------
# Claim ID: 34447
# Triplets: [{'head': 'Massaging', 'type': 'uses', 'tail': 'olive oil'}, {'head': 'breast', 'type': 'has part', 'tail': 'tissue'}, {'head': 'breast', 'type': 'has part', 'tail': 'tissue'}, {'head': 'tissue', 'type': 'part of', 'tail': 'breast'}]
# --------------------------------------------------
# Claim ID: 26777
# Triplets: [{'head': 'influenza', 'type': 'has cause', 'tail': 'coronavirus'}, {'head': 'coronavirus', 'type': 'has effect', 'tail': 'influenza'}, {'head': 'flu', 'type': 'has cause', 'tail': 'coronavirus'}, {'head': 'coronavirus', 'type': 'has effect', 'tail': 'flu'}, {'head': 'coronavirus', 'type': 'has effect', 'tail': 'flu'}]
# --------------------------------------------------
# Claim ID: 8865
# Triplets: [{'head': 'Clot-busting drug', 'type': 'medical condition treated', 'tail': 'frostbite'}, {'head': 'Clot-busting drug', 'type': 'medical condition treated', 'tail': 'frostbite'}, {'head': 'frostbite', 'type': 'drug used for treatment', 'tail': 'Clot-busting drug'}, {'head': 'Clot-busting drugs', 'type': 'medical condition treated', 'tail': 'frostbite'}]
# --------------------------------------------------
# Claim ID: 26324
# Triplets: [{'head': 'Mitch McConnell', 'type': 'member of political party', 'tail': 'Thom Tillis'}, {'head': 'Mitch McConnell', 'type': 'employer', 'tail': 'Thom Tillis'}, {'head': 'Mitch McConnell', 'type': 'different from', 'tail': 'Thom Tillis'}, {'head': 'Thom Tillis', 'type': 'different from', 'tail': 'Mitch McConnell'}]
# --------------------------------------------------
# Claim ID: 25645
# Triplets: [{'head': 'preexisting conditions', 'type': 'subclass of', 'tail': 'health insurance'}, {'head': 'preexisting conditions', 'type': 'facet of', 'tail': 'health insurance'}, {'head': 'preexisting condition', 'type': 'subclass of', 'tail': 'health insurance'}]
# --------------------------------------------------
# Claim ID: 26845
# Triplets: [{'head': 'Amy', 'type': 'field of work', 'tail': 'health care'}, {'head': 'health care', 'type': 'main subject', 'tail': 'Amy'}, {'head': 'Amy', 'type': 'notable work', 'tail': '(health care) plan'}, {'head': '(health care) plan', 'type': 'author', 'tail': 'Amy'}]
# --------------------------------------------------
# Claim ID: 10982
# Triplets: [{'head': 'Vitamin B', 'type': 'subject has role', 'tail': 'improving memory'}, {'head': 'Vitamin B', 'type': 'has effect', 'tail': 'improving memory'}, {'head': 'improving memory', 'type': 'has cause', 'tail': 'Vitamin B'}, {'head': 'Vitamin B', 'type': 'has effect', 'tail': 'improving memory'}]
# --------------------------------------------------
# Claim ID: 8012
# Triplets: [{'head': 'coronavirus toll rises', 'type': 'country', 'tail': 'Iran'}, {'head': 'coronavirus', 'type': 'country', 'tail': 'Iran'}, {'head': 'coronavirus', 'type': 'country of origin', 'tail': 'Iran'}]
# --------------------------------------------------
# Claim ID: 29128
# Triplets: [{'head': 'Red Bull', 'type': 'instance of', 'tail': 'energy drink'}, {'head': 'Bang', 'type': 'instance of', 'tail': 'energy drink'}, {'head': 'Red Bull', 'type': 'instance of', 'tail': 'energy drink'}, {'head': 'Red Bull', 'type': 'subclass of', 'tail': 'energy drink'}, {'head': 'Bang', 'type': 'subclass of', 'tail': 'energy drink'}]
# --------------------------------------------------
# Claim ID: 11214
# Triplets: [{'head': 'benefit for risk', 'type': 'facet of', 'tail': 'Blood drug trade'}, {'head': 'benefit for risk', 'type': 'facet of', 'tail': 'Blood drug trades'}, {'head': 'Blood drug trade', 'type': 'instance of', 'tail': 'benefit for risk'}]
# --------------------------------------------------
# Claim ID: 26131
# Triplets: [{'head': 'mask', 'type': 'use', 'tail': 'oxygen intake'}, {'head': 'toxin inhalation', 'type': 'subclass of', 'tail': 'oxygen intake'}, {'head': 'masks', 'type': 'use', 'tail': 'oxygen intake'}]
# --------------------------------------------------
# Claim ID: 6801
# Triplets: [{'head': 'vaping', 'type': 'has part', 'tail': 'THC'}, {'head': 'vaping', 'type': 'uses', 'tail': 'THC'}, {'head': 'vaping cartridge', 'type': 'has part', 'tail': 'THC'}]
# --------------------------------------------------
# Claim ID: 10789
# Triplets: [{'head': 'Yoga shows some benefit', 'type': 'medical condition treated', 'tail': 'diabetes'}, {'head': 'Yoga', 'type': 'medical condition treated', 'tail': 'diabetes'}, {'head': 'Yoga', 'type': 'medical condition treated', 'tail': 'diabetes'}, {'head': 'diabetes', 'type': 'drug used for treatment', 'tail': 'Yoga'}]
# --------------------------------------------------
# Claim ID: 9131
# Triplets: [{'head': 'acupuncture', 'type': 'part of', 'tail': 'KKI'}, {'head': 'KKI', 'type': 'field of work', 'tail': 'acupuncture'}, {'head': 'KKI', 'type': 'field of work', 'tail': 'ASD'}]
# --------------------------------------------------
# Claim ID: 3718
# Triplets: [{'head': 'rebel-turned-candidate OK', 'type': 'country', 'tail': 'Colombia'}, {'head': 'rebel-turned-candidate', 'type': 'country', 'tail': 'Colombia'}, {'head': 'Colombian rebel-turned-candidate OK', 'type': 'medical condition treated', 'tail': 'heart surgery'}]
# --------------------------------------------------
# Claim ID: 40952
# Triplets: [{'head': 'clots', 'type': 'has effect', 'tail': 'thrombosis'}, {'head': 'thrombosis', 'type': 'has cause', 'tail': 'clots'}, {'head': 'thrombosis', 'type': 'has cause', 'tail': 'blood clots'}, {'head': 'thrombosis', 'type': 'has cause', 'tail': 'clots'}]
# --------------------------------------------------
# Claim ID: 19716
# Triplets: [{'head': 'George Flinn', 'type': 'field of work', 'tail': 'ultrasound'}, {'head': 'ultrasound', 'type': 'part of', 'tail': 'modern medicine'}, {'head': 'George Flinn', 'type': 'field of work', 'tail': 'patents'}]
# --------------------------------------------------
# Claim ID: 3675
# Triplets: [{'head': 'Kansas', 'type': 'instance of', 'tail': 'state'}, {'head': 'mental health coverage', 'type': 'applies to jurisdiction', 'tail': 'Kansas'}, {'head': 'mental health coverage', 'type': 'located in the administrative territorial entity', 'tail': 'Kansas'}]
# --------------------------------------------------
# Claim ID: 35062
# Triplets: [{'head': 'pandemic response team', 'type': 'point in time', 'tail': '2018'}, {'head': 'pandemic', 'type': 'point in time', 'tail': '2018'}, {'head': 'U.S. pandemic response team', 'type': 'dissolved, abolished or demolished date', 'tail': '2018'}]
# --------------------------------------------------
# Claim ID: 4868
# Triplets: [{'head': 'Ryan Leaf', 'type': 'league', 'tail': 'NFL'}, {'head': 'Ryan Leaf', 'type': 'member of sports team', 'tail': 'NFL'}, {'head': 'Ryan Leaf', 'type': 'sport', 'tail': 'NFL'}]
# --------------------------------------------------
# Claim ID: 12046
# Triplets: [{'head': 'opioid deaths', 'type': 'facet of', 'tail': 'opioid'}, {'head': 'opioid deaths', 'type': 'subclass of', 'tail': 'deaths'}, {'head': 'opioid deaths', 'type': 'subclass of', 'tail': 'opioid deaths'}]
# --------------------------------------------------
# Claim ID: 2079
# Triplets: [{'head': 'Ipanema', 'type': 'country', 'tail': 'Brazil'}, {'head': 'The chubby girl from Ipanema', 'type': 'country of citizenship', 'tail': 'Brazil'}, {'head': 'chubby girl from Ipanema', 'type': 'country of citizenship', 'tail': 'Brazil'}]
# --------------------------------------------------
# Claim ID: 38268
# Triplets: [{'head': 'released from prison', 'type': 'subclass of', 'tail': 'parole'}, {'head': 'granted parole', 'type': 'participant', 'tail': 'Charles Manson'}, {'head': 'released from prison', 'type': 'instance of', 'tail': 'parole'}]
# --------------------------------------------------
# Claim ID: 18569
# Triplets: [{'head': 'Medicaid', 'type': 'located in the administrative territorial entity', 'tail': 'Texas'}, {'head': 'Medicaid', 'type': 'applies to jurisdiction', 'tail': 'Texas'}, {'head': 'Texas', 'type': 'instance of', 'tail': 'Medicaid'}]
# --------------------------------------------------
# Claim ID: 2712
# Triplets: [{'head': 'Herceptin', 'type': 'developer', 'tail': 'Roche'}, {'head': 'Roche', 'type': 'product or material produced', 'tail': 'Herceptin'}, {'head': 'Roche', 'type': 'product or material produced', 'tail': 'Herceptin'}, {'head': 'Herceptin', 'type': 'developer', 'tail': 'Roche'}]
# --------------------------------------------------
# Claim ID: 34178
# Triplets: [{'head': 'pico jackfruit', 'type': 'subclass of', 'tail': 'snake'}, {'head': 'pico jackfruit', 'type': 'parent taxon', 'tail': 'snake'}, {'head': 'pico jackfruit', 'type': 'instance of', 'tail': 'snake'}]
# --------------------------------------------------
# Claim ID: 8644
# Triplets: [{'head': 'coronavirus antibody test', 'type': 'country', 'tail': 'Italy'}, {'head': 'coronavirus antibody test', 'type': 'country of origin', 'tail': 'Italy'}, {'head': 'coronavirus', 'type': 'has effect', 'tail': 'antibody'}]
# --------------------------------------------------
# Claim ID: 10514
# Triplets: [{'head': 'breast cancer', 'type': 'drug used for treatment', 'tail': 'Drug’s benefit to younger breast cancer patients in question'}, {'head': 'breast cancer', 'type': 'drug used for treatment', 'tail': 'Drug’s benefit to younger breast cancer patients'}, {'head': 'breast cancer', 'type': 'drug used for treatment', 'tail': 'Drug’s benefit'}]
# --------------------------------------------------
# Claim ID: 33540
# ...
# --------------------------------------------------
# Claim ID: 8190
# Triplets: [{'head': 'coronavirus boomerang wave', 'type': 'continent', 'tail': 'Asia'}, {'head': 'coronavirus boomerang wave', 'type': 'location', 'tail': 'Asia'}, {'head': 'coronavirus boomerang', 'type': 'instance of', 'tail': 'wave'}]
# --------------------------------------------------
# Claim ID: 41801
# Triplets: [{'head': '2018 plan', 'type': 'point in time', 'tail': '2018'}, {'head': 'Trump’s 2018 plan', 'type': 'point in time', 'tail': '2018'}, {'head': '2018 plan', 'type': 'author', 'tail': 'Trump'}]
# --------------------------------------------------
# Claim ID: 10547
# Triplets: [{'head': 'New Breast Cancer Test', 'type': 'facet of', 'tail': 'Breast Cancer'}, {'head': 'New Breast Cancer Test', 'type': 'main subject', 'tail': 'Breast Cancer'}, {'head': 'Breast Cancer Test', 'type': 'facet of', 'tail': 'Breast Cancer'}]
# --------------------------------------------------
# Claim ID: 30927
# Triplets: [{'head': 'Kansas', 'type': 'instance of', 'tail': 'state'}, {'head': 'epidemic of child abduction', 'type': 'located in the administrative territorial entity', 'tail': 'Kansas'}, {'head': '"epidemic of child abduction"', 'type': 'located in the administrative territorial entity', 'tail': 'Kansas'}]
# --------------------------------------------------
# Claim ID: 8696
# Triplets: [{'head': 'Italy coronavirus deaths', 'type': 'number of participants', 'tail': '52'}, {'head': 'Italy coronavirus deaths jump to 52', 'type': 'has effect', 'tail': '2,000'}, {'head': 'Italy coronavirus deaths jump to 52', 'type': 'instance of', 'tail': 'cases'}]
# --------------------------------------------------
# Claim ID: 33614
# Triplets: [{'head': 'Barack Obama', 'type': 'conflict', 'tail': 'World War II'}, {'head': 'Barack Obama', 'type': 'father', 'tail': "his father's"}, {'head': "his father's", 'type': 'conflict', 'tail': 'World War II'}, {'head': 'Barack Obama', 'type': 'father', 'tail': 'his father'}, {'head': 'his father', 'type': 'conflict', 'tail': 'World War II'}]
# --------------------------------------------------
# Claim ID: 3065
# Triplets: [{'head': 'water standards', 'type': 'facet of', 'tail': 'drinking water'}, {'head': 'national drinking water standards', 'type': 'creator', 'tail': 'Sanders'}, {'head': 'national drinking water standards', 'type': 'named after', 'tail': 'Sanders'}]
# --------------------------------------------------
# Claim ID: 16922
# Triplets: [{'head': 'recent vote', 'type': 'participant', 'tail': 'Debbie Wasserman Schultz'}, {'head': 'Debbie Wasserman Schultz', 'type': 'position held', 'tail': 'Rep.'}, {'head': 'medical marijuana', 'type': 'instance of', 'tail': 'federal prison'}]
# --------------------------------------------------
# Claim ID: 32743
# Triplets: [{'head': 'pedophilia', 'type': 'subclass of', 'tail': 'sexually attracted to children'}, {'head': 'pedophilia', 'type': 'said to be the same as', 'tail': 'sexually attracted to children'}, {'head': 'sexually attracted to children', 'type': 'said to be the same as', 'tail': 'pedophilia'}, {'head': 'pedophilia', 'type': 'subclass of', 'tail': 'sexually attracted'}]
# --------------------------------------------------
# Claim ID: 14297
# Triplets: [{'head': 'federal law', 'type': 'has part', 'tail': 'Senate Bill 1070'}, {'head': 'Senate Bill 1070', 'type': 'based on', 'tail': 'federal law'}, {'head': 'Senate Bill 1070', 'type': 'main subject', 'tail': 'federal law'}]
# --------------------------------------------------
# Claim ID: 15243
# Triplets: [{'head': 'Peachtree and Pine', 'type': 'facet of', 'tail': 'tuberculosis'}, {'head': 'Peachtree and Pine', 'type': 'significant event', 'tail': 'tuberculosis'}, {'head': 'tuberculosis', 'type': 'location', 'tail': 'sites'}]
# --------------------------------------------------
# Claim ID: 944
# Triplets: [{'head': 'Bayer', 'type': 'product or material produced', 'tail': 'Roundup weed killer'}, {'head': 'Roundup weed killer', 'type': 'manufacturer', 'tail': 'Bayer'}, {'head': 'Bayer', 'type': 'product or material produced', 'tail': 'Roundup weed killer'}, {'head': 'Bayer', 'type': 'product or material produced', 'tail': 'weed killer'}, {'head': 'Roundup', 'type': 'manufacturer', 'tail': 'Bayer'}, {'head': 'Roundup', 'type': 'instance of', 'tail': 'weed killer'}]
# --------------------------------------------------
# Claim ID: 10933
# Triplets: [{'head': 'Drugs Show Promise Slowing Advanced Melanoma', 'type': 'facet of', 'tail': 'Melanoma'}, {'head': 'Advanced Melanoma', 'type': 'drug used for treatment', 'tail': 'Drug'}, {'head': 'Drugs Show Promise Slowing Advanced Melanoma', 'type': 'facet of', 'tail': 'Advanced Melanoma'}]
# --------------------------------------------------
# Claim ID: 9949
# Triplets: [{'head': 'major depression', 'type': 'drug used for treatment', 'tail': 'magnetic-pulse treatment'}, {'head': 'magnetic-pulse treatment', 'type': 'medical condition treated', 'tail': 'major depression'}, {'head': 'magnetic-pulse treatment', 'type': 'medical condition treated', 'tail': 'depression'}]
# --------------------------------------------------
# Claim ID: 3536
# Triplets: [{'head': 'vaping', 'type': 'has effect', 'tail': 'lung injury'}, {'head': 'vaping', 'type': 'located in the administrative territorial entity', 'tail': 'Tennessee'}, {'head': 'vaping', 'type': 'instance of', 'tail': 'lung injury'}]
# --------------------------------------------------
# Claim ID: 9929
# Triplets: [{'head': "Parkinson's", 'type': 'subclass of', 'tail': 'dementia'}, {'head': "Parkinson's symptoms", 'type': 'subclass of', 'tail': 'dementia'}, {'head': "Parkinson's", 'type': 'drug used for treatment', 'tail': 'drug'}]
# --------------------------------------------------
# Claim ID: 34665
# Triplets: [{'head': 'intentionally kill pedestrians', 'type': 'subclass of', 'tail': 'hit-and-run accidents'}, {'head': 'intentionally kill pedestrians', 'type': 'subclass of', 'tail': 'hit-and-run accident'}, {'head': 'intentionally kill pedestrians', 'type': 'subclass of', 'tail': 'hit-and-run'}]
# --------------------------------------------------
# Claim ID: 37585
# Triplets: [{'head': 'Akira', 'type': 'publication date', 'tail': '1988'}, {'head': 'Akira', 'type': 'publication date', 'tail': '1988'}, {'head': '2020 Olympics', 'type': 'point in time', 'tail': '2020'}, {'head': 'Akira', 'type': 'publication date', 'tail': '1988'}, {'head': '2020 Olympics', 'type': 'location', 'tail': 'Tokyo'}]
# --------------------------------------------------
# Claim ID: 13676
# Triplets: [{'head': 'only multilateral trade deal', 'type': 'legislated by', 'tail': 'Senate'}, {'head': 'only multilateral trade deal', 'type': 'participant', 'tail': 'Senate'}, {'head': 'trade deal', 'type': 'instance of', 'tail': 'multilateral'}]
# --------------------------------------------------
# Claim ID: 26008
# Triplets: [{'head': 'North Carolina', 'type': 'country', 'tail': 'United States'}, {'head': 'United States', 'type': 'contains administrative territorial entity', 'tail': 'North Carolina'}, {'head': 'University of North Carolina at Chapel Hill', 'type': 'located in the administrative territorial entity', 'tail': 'Chapel Hill'}, {'head': 'University of North Carolina at Chapel Hill', 'type': 'located in the administrative territorial entity', 'tail': 'North Carolina'}]
# --------------------------------------------------
# Claim ID: 29454
# Triplets: [{'head': 'ingredients that cause cancer', 'type': 'subclass of', 'tail': 'Snacks'}, {'head': 'carcinogen', 'type': 'has effect', 'tail': 'cause cancer'}, {'head': 'ingredients that cause cancer', 'type': 'facet of', 'tail': 'Snacks'}]
# --------------------------------------------------
# Claim ID: 2755
# Triplets: [{'head': 'unusually severe season', 'type': 'located in the administrative territorial entity', 'tail': 'California'}, {'head': 'unusually severe season', 'type': 'location', 'tail': 'California'}, {'head': 'unusually severe season', 'type': 'has cause', 'tail': 'flu'}]
# --------------------------------------------------
# Claim ID: 27934
# Triplets: [{'head': 'Kurt Warner', 'type': 'member of sports team', 'tail': 'NFL'}, {'head': 'Kurt Warner', 'type': 'league', 'tail': 'NFL'}, {'head': 'Kurt Warner', 'type': 'position played on team / speciality', 'tail': 'quarterback'}]
# --------------------------------------------------
# Claim ID: 3400
# Triplets: [{'head': 'Kemp', 'type': 'located in the administrative territorial entity', 'tail': 'Georgia'}, {'head': 'Kemp', 'type': 'located in the administrative territorial entity', 'tail': 'Georgia’s'}, {'head': 'Georgia', 'type': 'contains administrative territorial entity', 'tail': 'Kemp'}, {'head': 'Kemp', 'type': 'located in the administrative territorial entity', 'tail': 'Georgia'}]
# --------------------------------------------------
# Claim ID: 378
# Triplets: [{'head': 'pigs fly', 'type': 'subclass of', 'tail': 'swine disease'}, {'head': 'Pigs fly', 'type': 'has cause', 'tail': 'swine disease'}, {'head': 'pigs fly', 'type': 'has cause', 'tail': 'swine disease'}]
# --------------------------------------------------
# Claim ID: 2781
# Triplets: [{'head': 'health exchange', 'type': 'operator', 'tail': 'WellPoint'}, {'head': 'WellPoint', 'type': 'instance of', 'tail': 'health exchange'}, {'head': 'health exchange', 'type': 'parent organization', 'tail': 'WellPoint'}]
# --------------------------------------------------
# Claim ID: 24444
# Triplets: [{'head': 'pre-existing medical condition', 'type': 'subclass of', 'tail': 'unfair and discriminatory practices'}, {'head': 'pre-existing medical condition', 'type': 'subclass of', 'tail': 'discrimination'}, {'head': 'denying coverage to people because of a pre-existing medical condition', 'type': 'subclass of', 'tail': 'health insurance companies'}]
# --------------------------------------------------
# Claim ID: 8604
# Triplets: [{'head': 'Passover', 'type': 'instance of', 'tail': 'holiday'}, {'head': 'coronavirus lockdown', 'type': 'country', 'tail': 'Israel'}, {'head': 'Passover', 'type': 'country', 'tail': 'Israel'}]
# --------------------------------------------------
# Claim ID: 21954
# Triplets: [{'head': 'Medicare Advantage', 'type': 'part of', 'tail': 'Medicare'}, {'head': 'Medicare', 'type': 'has part', 'tail': 'Medicare Advantage'}, {'head': 'Medicare Advantage', 'type': 'part of', 'tail': 'Medicare'}, {'head': 'Medicare Advantage', 'type': 'parent organization', 'tail': 'Medicare'}]
# --------------------------------------------------
# Claim ID: 35215
# Triplets: [{'head': 'Kelowna', 'type': 'located in the administrative territorial entity', 'tail': 'British Columbia'}, {'head': 'Kelowna', 'type': 'located in the administrative territorial entity', 'tail': 'British Columbia'}, {'head': 'British Columbia', 'type': 'capital', 'tail': 'Kelowna'}, {'head': 'Spanish Influenza', 'type': 'start time', 'tail': '1918'}]
# --------------------------------------------------
# Claim ID: 38675
# Triplets: [{'head': 'Mecca', 'type': 'country', 'tail': 'Saudi'}, {'head': 'Buford', 'type': 'located in the administrative territorial entity', 'tail': 'Wyoming'}, {'head': 'Mecca', 'type': 'owned by', 'tail': 'Saudi billionaire'}]
# --------------------------------------------------
# Claim ID: 32868
# Triplets: [{'head': 'Barack Obama', 'type': 'position held', 'tail': 'President'}, {'head': 'Barack Obama', 'type': 'position held', 'tail': 'President'}, {'head': 'Donald Trump', 'type': 'position held', 'tail': 'President'}, {'head': 'President Obama', 'type': 'different from', 'tail': 'Donald Trump'}, {'head': 'Donald Trump', 'type': 'different from', 'tail': 'President Obama'}]
# --------------------------------------------------
# Claim ID: 6565
# Triplets: [{'head': 'Colorado', 'type': 'member of', 'tail': 'EPA'}, {'head': 'Colorado', 'type': 'instance of', 'tail': 'state'}, {'head': 'air rating', 'type': 'maintained by', 'tail': 'EPA'}]
# --------------------------------------------------
# Claim ID: 7360
# Triplets: [{'head': 'Georgia', 'type': 'ethnic group', 'tail': 'Hispanic'}, {'head': 'Hispanic', 'type': 'country', 'tail': 'Georgia'}, {'head': 'Georgia', 'type': 'ethnic group', 'tail': 'Hispanic residents'}]
# --------------------------------------------------
# Claim ID: 28411
# Triplets: [{'head': 'Democrat', 'type': 'opposite of', 'tail': 'Republican'}, {'head': '"liberal Democrat"', 'type': 'located in the administrative territorial entity', 'tail': 'New Mexico'}, {'head': '"liberal Democrat"', 'type': 'applies to jurisdiction', 'tail': 'New Mexico'}]
# --------------------------------------------------
# Claim ID: 23311
# Triplets: [{'head': 'wives should submit to their husbands', 'type': 'author', 'tail': 'Daniel Webster'}, {'head': 'wives', 'type': 'spouse', 'tail': 'husbands'}, {'head': 'husbands', 'type': 'spouse', 'tail': 'wives'}, {'head': 'wives should submit to their husbands', 'type': 'creator', 'tail': 'Daniel Webster'}]
# --------------------------------------------------
# Claim ID: 1273
# Triplets: [{'head': 'Novartis', 'type': 'country', 'tail': 'UK'}, {'head': "Novartis's cancer therapy", 'type': 'medical condition treated', 'tail': 'lymphoma'}, {'head': "Novartis's cancer therapy", 'type': 'medical condition treated', 'tail': 'lymphoma'}, {'head': 'lymphoma', 'type': 'drug used for treatment', 'tail': "Novartis's cancer therapy"}]
# --------------------------------------------------
# Claim ID: 27007
# Triplets: [{'head': 'needle', 'type': 'subclass of', 'tail': 'drug paraphernalia'}, {'head': 'drug paraphernalia', 'type': 'subclass of', 'tail': 'human waste'}, {'head': 'drug paraphernalia', 'type': 'has part', 'tail': 'needle'}]
# --------------------------------------------------
# Claim ID: 7315
# Triplets: [{'head': 'Chinese communities rattled by virus', 'type': 'significant event', 'tail': 'new year'}, {'head': 'virus', 'type': 'country of origin', 'tail': 'Chinese'}, {'head': 'Chinese communities rattled by virus', 'type': 'facet of', 'tail': 'new year'}]
# --------------------------------------------------
# Claim ID: 32512
# Triplets: [{'head': 'Seth Rich', 'type': 'employer', 'tail': 'DNC'}, {'head': 'Seth Rich', 'type': 'member of', 'tail': 'DNC'}, {'head': 'Seth Rich', 'type': 'employer', 'tail': 'DNC'}, {'head': 'Seth Rich', 'type': 'significant event', 'tail': 'gunned down'}]
# --------------------------------------------------
# Claim ID: 7322
# Triplets: [{'head': 'coronavirus', 'type': 'endemic to', 'tail': 'Nevada'}, {'head': 'coronavirus', 'type': 'has effect', 'tail': 'Nevada'}, {'head': 'coronavirus cases', 'type': 'located in the administrative territorial entity', 'tail': 'Nevada'}]
# --------------------------------------------------
# Claim ID: 19408
# Triplets: [{'head': 'Barack Obama', 'type': 'opposite of', 'tail': 'Mitt Romney'}, {'head': 'Mitt Romney', 'type': 'opposite of', 'tail': 'Barack Obama'}, {'head': 'Barack Obama', 'type': 'opposite of', 'tail': 'Mitt Romney'}, {'head': 'Barack Obama', 'type': 'different from', 'tail': 'Mitt Romney'}, {'head': 'Mitt Romney', 'type': 'different from', 'tail': 'Barack Obama'}]
# --------------------------------------------------
# Claim ID: 10077
# Triplets: [{'head': 'Vitamin C', 'type': 'medical condition treated', 'tail': 'Cataract'}, {'head': 'Cataract', 'type': 'drug used for treatment', 'tail': 'Vitamin C'}, {'head': 'Vitamin C', 'type': 'subject has role', 'tail': 'Cuts'}, {'head': 'Vitamin C', 'type': 'has effect', 'tail': 'Cataract'}]
# --------------------------------------------------
# Claim ID: 5465
# Triplets: [{'head': '2nd Legionnaires’ disease hearing', 'type': 'applies to jurisdiction', 'tail': 'Illinois'}, {'head': '2nd Legionnaires’ disease hearing', 'type': 'located in the administrative territorial entity', 'tail': 'Illinois'}, {'head': 'Legionnaires’ disease', 'type': 'country of origin', 'tail': 'Illinois'}]
# --------------------------------------------------
