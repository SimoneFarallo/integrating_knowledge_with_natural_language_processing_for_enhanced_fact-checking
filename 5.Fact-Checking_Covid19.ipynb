# %% [markdown]
# # Fact - Checking Covid
#
# https://mediafutures.eu/datasets-on-coronavirus-and-misinformation-available-for-the-1st-open-call/

# %% [markdown]
# ## Preliminary Operations

# %%
import pandas as pd
import numpy as np

# %%
#pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Pubhealth

# %%
df_pubbhealth  = pd.read_csv(r'C:\Users\c.farallo\OneDrive - BE THINK, SOLVE, EXECUTE S.P.A\Desktop\Thesis\triple_health.csv')
df_pubbhealth.head()
# Out:
#    Unnamed: 0 claim_id                                              claim  \
# 0           1     9893    Annual Mammograms May Have More False-Positives
# 1           2    11358  SBRT Offers Prostate Cancer Patients High Canc...
# 2           3    10166  Study: Vaccine for Breast, Ovarian Cancer Has ...
# 3           5     8713  Britain to reveal trial criteria for coronavir...
# 4           7     2768  U.S. says results encouraging for healthcare d...
#
#        date_published                                        explanation  \
# 0    October 18, 2011  This article reports on the results of a study...
# 1  September 28, 2016  This news release describes five-year outcomes...
# 2    November 8, 2011  While the story does many things well, the ove...
# 3       April 7, 2020  British regulators will this week reveal appro...
# 4    January 30, 2014  The Obama administration on Thursday reported ...
#
#                                        fact_checkers  \
# 0
# ...

# %%
with pd.option_context('max_colwidth', None,):
    print(df_pubbhealth[['claim']])
# Out:
#                                                                                               claim
# 0                                                   Annual Mammograms May Have More False-Positives
# 1     SBRT Offers Prostate Cancer Patients High Cancer Control and Low Toxicity in Fewer Treatments
# 2                                           Study: Vaccine for Breast, Ovarian Cancer Has Potential
# 3                                  Britain to reveal trial criteria for coronavirus antibody tests.
# 4                                    U.S. says results encouraging for healthcare delivery reforms.
# ...                                                                                             ...
# 6014                      Venezuela expands quarantine as number of coronavirus cases climbs to 33.
# 6015           The Sturgis motorcycle rally in 2020 resulted in 250,000 COVID-19 coronavirus cases.
# ...

# %% [markdown]
# ## CoAID claim
#
# https://github.com/cuilimeng/CoAID

# %%
pd.set_option('display.max_rows', None)

# %%
df_real_claim = pd.read_csv(r'C:\Users\c.farallo\OneDrive - BE THINK, SOLVE, EXECUTE S.P.A\Desktop\Thesis\ClaimRealCOVID-19_7.csv')
df_real_claim
# Out:
#      Unnamed: 0 fact_check_url  \
# 0        100166        who.int
# 1        100167        who.int
# 2        100168        who.int
# 3        100169        who.int
# 4        100170        who.int
# ..          ...            ...
# 167      100333        who.int
# 168      100334        who.int
# 169      100335        who.int
# 170      100336        who.int
# 171      100337        who.int
#
#                                               news_url  \
# 0    https://www.who.int/emergencies/diseases/novel...
# 1    https://www.who.int/emergencies/diseases/novel...
# 2    https://www.who.int/emergencies/diseases/novel...
# 3    https://www.who.int/emergencies/diseases/novel...
# 4    https://www.who.int/emergencies/diseases/novel...
# ..                                                 ...
# 167  https://www.who.int/emergencies/diseases/novel...
# 168  https://www.who.int/emergencies/diseases/novel...
# 169  https://www.who.int/emergencies/diseases/novel...
# ...

# %%
with pd.option_context('max_colwidth', None,):
    print(df_real_claim[['title']])
# Out:
#                                                                                                                                                                                                                                            title
# 0                                                                                                                                                                                                  People should NOT wear masks while exercising
# 1                                                                                                                                                                                         The likelihood of shoes spreading COVID-19 is very low
# 2                                                                                                                                                                        The coronavirus disease (COVID-19) is caused by a virus NOT by bacteria
# ...

# %% [markdown]
# ## CoAID news

# %%
df_real_news = pd.read_csv(r'C:\Users\c.farallo\OneDrive - BE THINK, SOLVE, EXECUTE S.P.A\Desktop\Thesis\NewsRealCOVID-19_5.csv')
df_real_news.head()
# Out:
#    Unnamed: 0     type  fact_check_url  \
# 0           0  article  healthline.com
# 1           1  article  healthline.com
# 2           2  article  healthline.com
# 3           3  article  healthline.com
# 4           4  article  healthline.com
#
#                                             news_url  \
# 0  https://www.healthline.com/health-news/coronav...
# 1  https://www.healthline.com/health-news/screen-...
# 2  https://www.healthline.com/health-news/heres-e...
# 3  https://www.healthline.com/health-news/heres-w...
# 4  https://www.healthline.com/health-news/why-you...
#
#                                                title  \
# 0                 Coronavirus Outbreak: Live Updates
# 1  Screen Time Doesn’t Hurt Kids’ Social Skills, ...
# 2  Here’s Exactly Where We Are with Vaccines and ...
# 3  Here’s What Happens to the Body After Contract...
# 4  Why You Should Be Skeptical of Early Results o...
#
#                                            newstitle  \
# ...

# %%
with pd.option_context('max_colwidth', None,):
    print(df_real_news[['title']])
# Out:
#                                                                                                                                                                                                                                title
# 0                                                                                                                                                                                                 Coronavirus Outbreak: Live Updates
# 1                                                                                                                                                                          Screen Time Doesn’t Hurt Kids’ Social Skills, Study Finds
# 2                                                                                                                                                              Here’s Exactly Where We Are with Vaccines and Treatments for COVID-19
# ...

# %%
with pd.option_context('max_colwidth', None,):
    print(df_real_news[['content']])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      content
# ...

# %% [markdown]
# ## CMU MisCovid19
#
# https://zenodo.org/records/4024154

# %%
df_CMU = pd.read_csv(r'C:\Users\c.farallo\OneDrive - BE THINK, SOLVE, EXECUTE S.P.A\Desktop\Thesis\CMU_MisCov19_dataset.csv')
df_CMU.head()
# Out:
#              status_id               status_created_at annotation1 annotation2
# 0  1237387231779840000  Tue Mar 10 14:38:00 +0000 2020  irrelevant         NaN
# 1  1240175235304960000  Wed Mar 18 07:16:32 +0000 2020  irrelevant         NaN
# 2  1241324844920320000  Sat Mar 21 11:24:40 +0000 2020  irrelevant         NaN
# 3  1241872361743360000  Sun Mar 22 23:40:18 +0000 2020  irrelevant         NaN
# 4  1243024442621440000  Thu Mar 26 03:58:16 +0000 2020  irrelevant         NaN
