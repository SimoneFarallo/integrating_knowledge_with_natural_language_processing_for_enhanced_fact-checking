# %% [markdown]
# # Matching

# %% [markdown]
# ### Preliminary Operations

# %%
import pandas as pd
import numpy as np

# %%
#pd.set_option('display.max_rows', None)

# %%
df_triple_kb = pd.read_csv(r'df_triple_KB.csv')
df_triple_kb
# Out:
#       Unnamed: 0  claim_id                                              claim  \
# 0              3     10166  Study: Vaccine for Breast, Ovarian Cancer Has ...
# 1              4     11276  Some appendicitis cases may not require ’emerg...
# 2              5      8713  Britain to reveal trial criteria for coronavir...
# 3              6      9851  Angioplasty through the wrist backed by new study
# 4              7      2768  U.S. says results encouraging for healthcare d...
# ...          ...       ...                                                ...
# 5073        9822      5551  Justice Ginsburg reports she’s on way to ‘well...
# 5074        9824     12958  Miami-Dade is "the first community in the worl...
# 5075        9826      8197  Venezuela expands quarantine as number of coro...
# 5076        9828       401  AstraZeneca's infant respiratory drug prioriti...
# 5077        9829      2023  Testicular cancer deaths double with after 40 ...
#
# ...

# %%
df_triple_test = pd.read_csv(r'df_triple_TEST.csv')
df_triple_test
# Out:
#       Unnamed: 0  claim_id                                              claim  \
# 0              0     33456  A mother revealed to her child in a letter aft...
# 1              1      2542  Study says too many Americans still drink too ...
# 2              2     26678  Viral image Says 80% of novel coronavirus case...
# 3              3     40705  An email says that 9-year old Craig Shergold o...
# 4              4     35718  Employees at a Five Guys restaurant in Daphne,...
# ...          ...       ...                                                ...
# 1230        1230      3295  Christmas miracle for Florida dog whose heart ...
# 1231        1231      6904  Another dolphin dies at Arizona aquatic facility.
# 1232        1232     13874  What the facts say" is ... "the best scenario ...
# 1233        1233      2847  FDA advisory panel rejects J&J drug for acute ...
# 1234        1234      7394  Gene-editing Chinese scientist kept much of hi...
#
# ...

# %% [markdown]
# ## Matching Triple
