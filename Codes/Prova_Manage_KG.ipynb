# %% [markdown]
# Manage and analyzing Knowlede Graph
#
# * https://networkx.org/documentation/stable/reference/introduction.html

# %% [markdown]
# # OBO file
#
# * https://notebook.community/dhimmel/obo/examples/go-obonet

# %%
#pip install obonet
# Out:
# "pip" non � riconosciuto come comando interno o esterno,
#  un programma eseguibile o un file batch.

# %%
import networkx
import obonet

# %%
cd C:\Users\Simone\Documents\Desktop\Tesi_Magistrale\Codes\KB
# Out:
# C:\Users\Simone\Documents\Desktop\Tesi_Magistrale\Codes\KB

# %%
graph = obonet.read_obo('BrendaTissueOBO')

# %%
# Number of nodes
len(graph)
# Out:
# 6511

# %%
# Number of edges
graph.number_of_edges()
# Out:
# 7646

# %%
# Check if the ontology is a DAG
networkx.is_directed_acyclic_graph(graph)
# Out:
# True

# %%
G = graph
G.graph
# Out:
# {'typedefs': [{'id': 'bearer_of', 'name': 'bearer of', 'xref': ['RO:0000053']},
#   {'id': 'causually_influences',
#    'name': 'causually influences',
#    'xref': ['RO:0002566']},
#   {'id': 'contained_in', 'name': 'contained in', 'xref': ['RO:0001018']},
#   {'id': 'develops_from',
#    'name': 'derives from/develops from',
#    'xref': ['RO:0002202']},
#   {'id': 'disease_arises_from_structure',
#    'name': 'disease arises from structure',
#    'xref': ['RO:0004030']},
#   {'id': 'disease_causes_dysfunction_of',
#    'name': 'disease causes dysfunction of',
#    'xref': ['RO:0004025']},
#   {'id': 'part_of', 'name': 'part of', 'xref': ['BFO:0000050']},
#   {'id': 'produced_by', 'name': 'produced by', 'xref': ['RO:0003001']},
#   {'id': 'realized_in', 'name': 'realized in', 'xref': ['BFO:0000054']},
#   {'id': 'related_to', 'name': 'related to'}],
#  'instances': [],
#  'format-version': '1.2',
#  'data-version': 'releases/2021-10-26',
#  'date': '23:10:2021 16:56',
#  'saved-by': 'Marion',
#  'auto-generated-by': 'OBO-Edit 2.3.1',
#  'synonymtypedef': ['FR "LANGUAGE FRENCH"',
#   'GE "LANGUAGE GERMAN"',
#   'MS "MISSPELLING"',
#   'SCI "SCIENTIFIC NAME"'],
#  'default-namespace': ['BrendaTissueOBO'],
#  'ontology': 'bto',
#  'property_value': ['http://purl.org/dc/elements/1.1/description "A structured controlled vocabulary for the source of an enzyme comprising tissues, cell lines, cell types and cell cultures." xsd:string',
#   'http://purl.org/dc/elements/1.1/title "The BRENDA Tissue Ontology (BTO)" xsd:string',
#   'http://purl.org/dc/terms/license https://creativecommons.org/licenses/by/4.0/ xsd:string'],
#  'name': 'bto'}

# %%
G.nodes
# Out:
# NodeView(('BTO:0000000', 'BTO:0000001', 'BTO:0000002', 'BTO:0000003', 'BTO:0000004', 'BTO:0000005', 'BTO:0000006', 'BTO:0000007', 'BTO:0000008', 'BTO:0000009', 'BTO:0000010', 'BTO:0000011', 'BTO:0000012', 'BTO:0000013', 'BTO:0000014', 'BTO:0000015', 'BTO:0000016', 'BTO:0000017', 'BTO:0000018', 'BTO:0000019', 'BTO:0000020', 'BTO:0000021', 'BTO:0000022', 'BTO:0000023', 'BTO:0000024', 'BTO:0000025', 'BTO:0000026', 'BTO:0000027', 'BTO:0000028', 'BTO:0000029', 'BTO:0000030', 'BTO:0000031', 'BTO:0000032', 'BTO:0000033', 'BTO:0000034', 'BTO:0000035', 'BTO:0000036', 'BTO:0000037', 'BTO:0000038', 'BTO:0000039', 'BTO:0000040', 'BTO:0000041', 'BTO:0000042', 'BTO:0000043', 'BTO:0000044', 'BTO:0000045', 'BTO:0000046', 'BTO:0000047', 'BTO:0000048', 'BTO:0000049', 'BTO:0000050', 'BTO:0000051', 'BTO:0000052', 'BTO:0000053', 'BTO:0000054', 'BTO:0000055', 'BTO:0000056', 'BTO:0000057', 'BTO:0000058', 'BTO:0000059', 'BTO:0000060', 'BTO:0000061', 'BTO:0000062', 'BTO:0000063', 'BTO:0000064', 'BTO:0000065', 'BTO:0000066', 'BTO:0000067', 'BTO:0000068', 'BTO:0000069', 'BTO:0000070', 'BTO:0000071', 'BTO:0000072', 'BTO:0000073', 'BTO:0000074', 'BTO:0000075', 'BTO:0000076', 'BTO:0000077', 'BTO:0000078', 'BTO:0000079', 'BTO:0000080', 'BTO:0000081', 'BTO:0000082', 'BTO:0000083', 'BTO:0000084', 'BTO:0000085', 'BTO:0000086', 'BTO:0000087', 'BTO:0000088', 'BTO:0000089', 'BTO:0000090', 'BTO:0000091', 'BTO:0000092', 'BTO:0000093', 'BTO:0000094', 'BTO:0000095', 'BTO:0000096', 'BTO:0000097', 'BTO:0000098', 'BTO:0000099', 'BTO:0000100', 'BTO:0000101', 'BTO:0000102', 'BTO:0000103', 'BTO:0000104', 'BTO:0000105', 'BTO:0000106', 'BTO:0000107', 'BTO:0000108', 'BTO:0000109', 'BTO:0000110', 'BTO:0000111', 'BTO:0000112', 'BTO:0000113', 'BTO:0000114', 'BTO:0000115', 'BTO:0000116', 'BTO:0000117', 'BTO:0000118', 'BTO:0000119', 'BTO:0000120', 'BTO:0000121', 'BTO:0000122', 'BTO:0000123', 'BTO:0000124', 'BTO:0000125', 'BTO:0000126', 'BTO:0000127', 'BTO:0000128', 'BTO:0000129', 'BTO:0000130', 'BTO:0000131', 'BTO:0000132', 'BTO:0000133', 'BTO:0000134', 'BTO:0000135', 'BTO:0000136', 'BTO:0000137', 'BTO:0000138', 'BTO:0000139', 'BTO:0000140', 'BTO:0000141', 'BTO:0000142', 'BTO:0000143', 'BTO:0000144', 'BTO:0000145', 'BTO:0000146', 'BTO:0000147', 'BTO:0000148', 'BTO:0000149', 'BTO:0000150', 'BTO:0000151', 'BTO:0000152', 'BTO:0000153', 'BTO:0000154', 'BTO:0000155', 'BTO:0000156', 'BTO:0000157', 'BTO:0000158', 'BTO:0000159', 'BTO:0000160', 'BTO:0000161', 'BTO:0000162', 'BTO:0000163', 'BTO:0000164', 'BTO:0000165', 'BTO:0000166', 'BTO:0000167', 'BTO:0000168', 'BTO:0000169', 'BTO:0000170', 'BTO:0000171', 'BTO:0000172', 'BTO:0000173', 'BTO:0000174', 'BTO:0000175', 'BTO:0000176', 'BTO:0000177', 'BTO:0000178', 'BTO:0000179', 'BTO:0000180', 'BTO:0000181', 'BTO:0000182', 'BTO:0000183', 'BTO:0000184', 'BTO:0000185', 'BTO:0000186', 'BTO:0000187', 'BTO:0000188', 'BTO:0000189', 'BTO:0000190', 'BTO:0000191', 'BTO:0000192', 'BTO:0000193', 'BTO:0000194', 'BTO:0000195', 'BTO:0000196', 'BTO:0000197', 'BTO:0000198', 'BTO:0000199', 'BTO:0000200', 'BTO:0000201', 'BTO:0000202', 'BTO:0000203', 'BTO:0000204', 'BTO:0000205', 'BTO:0000206', 'BTO:0000207', 'BTO:0000208', 'BTO:0000209', 'BTO:0000210', 'BTO:0000211', 'BTO:0000212', 'BTO:0000213', 'BTO:0000214', 'BTO:0000215', 'BTO:0000216', 'BTO:0000217', 'BTO:0000218', 'BTO:0000219', 'BTO:0000220', 'BTO:0000221', 'BTO:0000222', 'BTO:0000223', 'BTO:0000224', 'BTO:0000225', 'BTO:0000226', 'BTO:0000227', 'BTO:0000228', 'BTO:0000229', 'BTO:0000230', 'BTO:0000231', 'BTO:0000232', 'BTO:0000233', 'BTO:0000234', 'BTO:0000235', 'BTO:0000236', 'BTO:0000237', 'BTO:0000238', 'BTO:0000239', 'BTO:0000240', 'BTO:0000241', 'BTO:0000242', 'BTO:0000243', 'BTO:0000244', 'BTO:0000245', 'BTO:0000246', 'BTO:0000247', 'BTO:0000248', 'BTO:0000249', 'BTO:0000250', 'BTO:0000251', 'BTO:0000252', 'BTO:0000253', 'BTO:0000254', 'BTO:0000255', 'BTO:0000256', 'BTO:0000257', 'BTO:0000258', 'BTO:0000259', 'BTO:0000260', 'BTO:0000261', 'BTO:0000262', 'BTO:0000263', 'BTO:0000264', 'BTO:0000265',  ...

# %%
print(G.nodes['BTO:0000100'])
print(type(G.nodes['BTO:0000100']))
# Out:
# {'name': 'astrocytoma cell', 'def': '"A tumor cell composed of astrocytes; it is the most common type of primary brain tumor and is also found throughout the central nervous system. One classification groups astrocytomas according to their histologic appearance and distinguishes pilocytic, protoplasmic, gemistocytic, and fibrillary types. Another classification groups them in order of increasing malignancy as Grade I, Grade II, Grade III, and Grade IV types." [Dorlands_Medical_Dictionary:MerckSource]', 'synonym': ['"astrocytic glioma cell" RELATED []', '"astroglial neoplasm cell" RELATED []', '"astroglial tumor cell" RELATED []', '"astroglioma cell" RELATED []'], 'is_a': ['BTO:0000526'], 'relationship': ['develops_from BTO:0000099']}
# <class 'dict'>

# %%
node_id = 'BTO:0000199'  # Sostituisci questo con l'ID del nodo che vuoi stampare
node_data = G.nodes[node_id]
print(node_data['relationship'])
# Out:
# ['part_of BTO:0000562', 'part_of BTO:0001369']

# %%
node_id = 'BTO:0000199'  # Sostituisci questo con l'ID del nodo che vuoi stampare
node_data = G.nodes[node_id]
relationship = node_data.get('relationship', None)
name = node_data.get('name', None)

if relationship is not None:
    print(f"Relationship: {relationship}")

if name is not None:
    print(f"Name: {name}")
else:
    print("Nome del nodo non trovato.")
# Out:
# Relationship: ['part_of BTO:0000562', 'part_of BTO:0001369']
# Name: cardiac muscle

# %%
#nx.draw(G) printare grafico intero

# %%
import networkx as nx
import matplotlib.pyplot as plt

start_node = 'BTO:0000400'
end_node = 'BTO:0000450'

# Estrai i nodi dal grafo tra start_node e end_node inclusi
nodes_to_draw = [node for node in G.nodes() if start_node <= node <= end_node]
# Crea un sottografo contenente solo i primi 20 nodi
subgraph = G.subgraph(nodes_to_draw)

# Disegna il sottografoù
pos = nx.spring_layout(subgraph)  # Posizionamento dei nodi nel grafico
labels = nx.get_node_attributes(subgraph, 'name')  # Etichette dei nodi
edge_labels = nx.get_edge_attributes(subgraph, 'relation_type')
nx.draw(subgraph, with_labels=labels, node_color='skyblue', node_size=100, font_size=5, font_weight='bold')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels) 
plt.show()

# %%
nx.get_node_attributes(G, 'name')
# Out:
# {'BTO:0000000': 'tissues, cell types and enzyme sources',
#  'BTO:0000001': 'culture condition:-induced cell',
#  'BTO:0000002': 'culture condition:1,4-dichlorobenzene-grown cell',
#  'BTO:0000003': 'intestinal cell line',
#  'BTO:0000004': 'culture condition:2,5-dihydroxybenzoate-grown cell',
#  'BTO:0000005': 'culture condition:2-aminobenzenesulfonate-grown cell',
#  'BTO:0000006': 'osteoblastoma cell',
#  'BTO:0000007': 'HEK-293 cell',
#  'BTO:0000008': 'culture condition:3-chlorobenzoate-grown cell',
#  'BTO:0000009': 'culture condition:3-hydroxybenzoate-grown cell',
#  'BTO:0000010': 'culture condition:3-methylcrotonoyl-CoA-grown cell',
#  'BTO:0000011': '3T3-L1 cell',
#  'BTO:0000012': 'culture condition:4-(methoxymethyl)phenol-grown cell',
#  'BTO:0000013': 'culture condition:4-chlorophenol-grown cell',
#  'BTO:0000014': 'culture condition:4-hydroxybenzoate-grown cell',
#  'BTO:0000015': 'culture condition:4-methylmuconolactone-grown cell',
#  'BTO:0000016': 'A-172 cell',
#  'BTO:0000017': 'A-431 cell',
#  'BTO:0000018': 'A-549 cell',
#  'BTO:0000019': 'A7r5 cell',
#  'BTO:0000020': 'abdomen',
#  'BTO:0000021': 'head muscle',
#  'BTO:0000022': 'abdominal ganglion',
#  'BTO:0000023': 'pectoral muscle',
#  'BTO:0000024': 'abomasum',
#  'BTO:0000025': 'amniotic cavity',
#  'BTO:0000026': 'culture condition:galactose-grown cell',
#  'BTO:0000027': 'achene',
#  'BTO:0000028': 'pancreatic acinar cell',
#  'BTO:0000029': 'adductor longus',
#  'BTO:0000030': 'adductor',
#  'BTO:0000031': 'fruit peduncle',
#  'BTO:0000032': 'colonic adenocarcinoma cell',
#  'BTO:0000033': 'SW-403 cell',
#  'BTO:0000034': 'apical meristem',
#  'BTO:0000035': 'colorectal adenocarcinoma cell',
#  'BTO:0000036': 'gastric adenocarcinoma cell',
#  'BTO:0000037': 'renal cell carcinoma cell',
#  'BTO:0000038': 'SW-480 cell',
#  'BTO:0000039': 'root cap',
#  'BTO:0000040': 'adenohypophysis',
#  'BTO:0000041': 'medulla oblongata',
#  'BTO:0000042': 'animal',
#  'BTO:0000043': 'cerebellar cortex',
#  'BTO:0000044': 'tear gland',
#  'BTO:0000045': 'adrenal cortex',
#  'BTO:0000046': 'Y-1 cell',
#  'BTO:0000047': 'adrenal gland',
#  'BTO:0000048': 'zona glomerulosa',
#  'BTO:0000049': 'adrenal medulla',
#  'BTO:0000050': 'zona fasciculata',
#  'BTO:0000051': 'tendon sheath',
#  'BTO:0000052': 'stoma',
#  'BTO:0000053': 'albedo',
#  'BTO:0000054': 'albumen gland',
#  'BTO:0000055': 'pars recta',
#  'BTO:0000056': 'zona reticulata',
#  'BTO:0000057': 'aleurone layer',
#  'BTO:0000058': 'alimentary canal',
#  'BTO:0000059': 'renal epithelium',
#  'BTO:0000060': 'alveolus',
#  'BTO:0000061': 'alveolar sac',
#  'BTO:0000062': 'amastigote',
#  'BTO:0000063': 'culture condition:ammonium malate-grown cell',
#  'BTO:0000064': 'amniochorion',
#  'BTO:0000065': 'amnion',
#  'BTO:0000066': 'amniocyte',
#  'BTO:0000067': 'kidney cell line',
#  'BTO:0000068': 'amniotic fluid',
#  'BTO:0000069': 'WISH cell',
#  'BTO:0000070': 'fungal cell line',
#  'BTO:0000071': 'amoebocyte',
#  'BTO:0000072': 'carpel',
#  'BTO:0000073': 'culture condition:aniline-grown cell',
#  'BTO:0000074': 'antenna',
#  'BTO:0000075': 'antennal gland',
#  'BTO:0000076': 'anterior midgut',
#  'BTO:0000077': 'posterior midgut',
#  'BTO:0000078': 'microglia',
#  'BTO:0000079': 'anther',
#  'BTO:0000080': 'male reproductive gland',
#  'BTO:0000081': 'reproductive system',
#  'BTO:0000082': 'male reproductive system',
#  'BTO:0000083': 'female reproductive system',
#  'BTO:0000084': 'vermiform appendix',
#  'BTO:0000085': 'appressorium',
#  'BTO:0000086': 'culture condition:arabinose-grown cell',
#  'BTO:0000087': 'arterial smooth muscle',
#  'BTO:0000088': 'cardiovascular system',
#  'BTO:0000089': 'blood',
#  'BTO:0000090': 'ascidian',
#  'BTO:0000091': 'ascites',
#  'BTO:0000092': 'trypanosomoid form',
#  'BTO:0000093': 'MCF-7 cell',
#  'BTO:0000094': 'ascites tumor cell',
#  'BTO:0000095': 'F-9 cell',
#  'BTO:0000096': 'urinary bladder cell line',
#  'BTO:0000097': 'ascospore',
#  'BTO:0000098': 'astroblast',
#  'BTO:0000099': 'astrocyte',
#  'BTO:0000100': 'astrocytoma cell',
#  'BTO:0000101': 'astrocytoma cell line',
#  'BTO:0000102': 'blood clot',
#  'BTO:0000103': 'Colon 26-L5 cell',
#  'BTO:0000104': 'lymphoma cell line',
#  'BTO:0000105': 'upper epidermis',
#  'BTO:0000106': 'cranial ganglion',
#  'BTO:0000107': 'B95-8 cell',
#  'BTO:0000108': 'olfactory epithelium',
#  'BTO:0000109': 'bacteroid',
#  'BTO:0000110': 'amniotic cell line',
#  'BTO:0000111': 'BALB/3T12-3 cell',
#  'BTO:0000112': 'sieve cell',
#  'BTO:0000113': 'cervical ganglion',
#  'BTO:0000114': 'basidiocarp',
#  'BTO:0000115': 'BC3H1 cell',
#  'BTO:0000116': 'plant epidermis',
#  'BTO:0000117': 'culture condition:benzoate-grown cell',
#  'BTO:0000118': 'culture condition:benzoylformate-grown cell',
#  'BTO:0000119': 'berry',
#  'BTO:0000120': 'BHK-21 cell',
#  'BTO:0000121': 'bile',
#  'BTO:0000122': 'bile duct',
#  'BTO:0000123': 'bladder',
#  'BTO:0000124': 'microspore',
#  'BTO:0000125': 'blast cell',
#  'BTO:0000126': 'blastoderm',
#  'BTO:0000127': 'blastospore',
#  'BTO:0000128': 'blastula',
#  'BTO:0000129': 'basophil',
#  'BTO:0000130': 'neutrophil',
#  'BTO:0000131': 'blood plasma',
#  'BTO:0000132': 'blood platelet',
#  'BTO:0000133': 'blood serum',
#  'BTO:0000134': 'bloodstream form',
#  'BTO:0000135': 'aorta',
#  'BTO:0000136': 'bronchoalveolar system',
#  'BTO:0000137': 'pulmonary artery endothelium',
#  'BTO:0000138': 'midbrain',
#  'BTO:0000139': 'body wall',
#  'BTO:0000140': 'bone',
#  'BTO:0000141': 'bone marrow',
#  'BTO:0000142': 'brain',
#  'BTO:0000143': 'substantia nigra',
#  'BTO:0000144': 'meninx',
#  'BTO:0000145': 'brain myelin',
#  'BTO:0000146': 'brain stem',
#  'BTO:0000147': 'microgametophyte',
#  'BTO:0000148': 'branch',
#  'BTO:0000149': 'breast',
#  'BTO:0000150': 'breast cancer cell',
#  'BTO:0000151': 'extensor',
#  'BTO:0000152': 'infected cell',
#  'BTO:0000153': 'Walker carcinoma 256 cell',
#  'BTO:0000154': 'BRL-3A cell',
#  'BTO:0000155': 'bronchoalveolar lavage fluid',
#  'BTO:0000156': 'brown adipose tissue',
#  'BTO:0000157': 'aorta thoracica',
#  'BTO:0000158': 'plant bud',
#  'BTO:0000159': 'bulb',
#  'BTO:0000160': 'bundle sheath',
#  'BTO:0000161': 'lung fibroblast cell line',
#  'BTO:0000162': 'culture condition:butyrate-grown cell',
#  'BTO:0000163': 'corolla',
#  'BTO:0000164': 'Burkitt lymphoma cell',
#  'BTO:0000165': 'C2C12 cell',
#  'BTO:0000166': 'cecum',
#  'BTO:0000167': 'adenocarcinoma cell line',
#  'BTO:0000168': 'carotid artery',
#  'BTO:0000169': 'calyx',
#  'BTO:0000170': 'cambium',
#  'BTO:0000171': 'NCI-H226Br cell',
#  'BTO:0000172': 'pileus',
#  'BTO:0000173': 'fruit capsule',
#  'BTO:0000174': 'embryonic structure',
#  'BTO:0000175': 'epithalamus',
#  'BTO:0000176': 'carcinoma cell',
#  'BTO:0000177': 'BG-1 cell',
#  'BTO:0000178': 'adenoma cell',
#  'BTO:0000179': 'Colo-205 cell',
#  'BTO:0000180': 'cervical carcinoma cell',
#  'BTO:0000181': 'Lewis lung carcinoma cell line',
#  'BTO:0000182': 'HT-29 cell',
#  'BTO:0000183': 'pancreatic cell line',
#  'BTO:0000184': 'medullary thyroid carcinoma cell',
#  'BTO:0000185': 'medullary breast carcinoma cell',
#  'BTO:0000186': 'lobular carcinoma cell',
#  'BTO:0000187': 'myeloblast',
#  'BTO:0000188': 'colonic cell line',
#  'BTO:0000189': 'small cell lung cancer cell',
#  'BTO:0000190': 'Ehrlich tumor carcinoma cell',
#  'BTO:0000191': 'medullary carcinoma cell',
#  'BTO:0000192': 'nasopharyngeal carcinoma cell',
#  'BTO:0000193': 'rectal cancer cell',
#  'BTO:0000194': 'endometrioid carcinoma cell',
#  'BTO:0000195': 'CACO-2 cell',
#  'BTO:0000196': 'thyroid cancer cell',
#  'BTO:0000197': 'carcinosarcoma cell',
#  'BTO:0000198': 'cardia',
#  'BTO:0000199': 'cardiac muscle',
#  'BTO:0000200': 'culture condition:2-chloropropionate-grown cell',
#  'BTO:0000201': 'pheochromocytoma cell line',
#  'BTO:0000202': 'sense organ',
#  'BTO:0000203': 'respiratory system',
#  'BTO:0000204': 'carotid body',
#  'BTO:0000205': 'nerve plexus',
#  'BTO:0000206': 'cartilage',
#  'BTO:0000207': 'tibial cartilage',
#  'BTO:0000208': 'caryopsis',
#  'BTO:0000209': 'corpus epididymis',
#  'BTO:0000210': 'cauda epididymis',
#  'BTO:0000211': 'caudate nucleus',
#  'BTO:0000212': 'caudate putamen',
#  'BTO:0000213': 'cecum mucosa',
#  'BTO:0000214': 'cell culture',
#  'BTO:0000215': 'culture condition:galactonate-grown cell',
#  'BTO:0000216': 'culture condition',
#  'BTO:0000217': 'MH-7777A cell',
#  'BTO:0000218': 'BALB/3T3 cell',
#  'BTO:0000219': 'plastron',
#  'BTO:0000220': 'MH1C1 cell',
#  'BTO:0000221': 'cell suspension culture',
#  'BTO:0000222': 'myoblast',
#  'BTO:0000223': 'teratocarcinoma cell',
#  'BTO:0000224': 'liver cell line',
#  'BTO:0000225': 'CEM-C1 cell',
#  'BTO:0000226': 'gitter cell',
#  'BTO:0000227': 'central nervous system',
#  'BTO:0000228': 'C-1300 cell',
#  'BTO:0000229': 'centrum semiovale',
#  'BTO:0000230': 'subarachnoid space',
#  'BTO:0000231': 'cerebral hemisphere',
#  'BTO:0000232': 'cerebellum',
#  'BTO:0000233': 'cerebral cortex',
#  'BTO:0000234': 'vein',
#  'BTO:0000235': 'basal ganglion',
#  'BTO:0000236': 'cerebral white matter',
#  'BTO:0000237': 'cerebrospinal fluid',
#  'BTO:0000238': 'cerebrovascular endothelial cell',
#  'BTO:0000239': 'telencephalon',
#  'BTO:0000240': 'inferior cervical ganglion',
#  'BTO:0000241': 'cervical epithelium',
#  'BTO:0000242': 'cervical mucus',
#  'BTO:0000243': 'vagina',
#  'BTO:0000244': 'culture condition:chlorobenzene-induced cell',
#  'BTO:0000245': 'culture condition:chlorobenzoate-grown cell',
#  'BTO:0000246': 'CHO cell',
#  'BTO:0000247': 'shoot tip',
#  'BTO:0000248': 'chondroclast',
#  'BTO:0000249': 'chondrocyte',
#  'BTO:0000250': 'chondrosarcoma cell',
#  'BTO:0000251': 'chorioallantois',
#  'BTO:0000252': 'chorion',
#  'BTO:0000253': 'BEN cell',
#  'BTO:0000254': 'female reproductive gland',
#  'BTO:0000255': 'brain cell line',
#  'BTO:0000256': 'myoblast cell line',
#  'BTO:0000257': 'uterine cancer cell',
#  'BTO:0000258': 'choroid plexus',
#  'BTO:0000259': 'chromaffin cell',
#  'BTO:0000260': 'ciliary body',
#  'BTO:0000261': 'culture condition:mannitol-grown cell',
#  'BTO:0000262': 'clove',
#  'BTO:0000263': 'P-388D1(IL-1) cell',
#  'BTO:0000264': 'bone marrow cell line',
#  'BTO:0000265': 'coagulating gland',
#  'BTO:0000266': 'cob',
#  'BTO:0000267': 'cochlea',
#  'BTO:0000268': 'coleoptile',
#  'BTO:0000269': 'colon',
#  'BTO:0000270': 'colon ascendens',
#  'BTO:0000271': 'colonic mucosa',
#  'BTO:0000272': 'colon transversum',
#  'BTO:0000273': 'ink gland',
#  'BTO:0000274': 'apical bud',
#  'BTO:0000275': 'colonocyte',
#  'BTO:0000276': 'colostrum',
#  'BTO:0000277': 'columnella muscle',
#  'BTO:0000278': 'commercial preparation',
#  'BTO:0000279': 'testicular cancer cell',
#  'BTO:0000280': 'cone',
#  'BTO:0000281': 'conidiophore',
#  'BTO:0000282': 'head',
#  'BTO:0000283': 'conidium',
#  'BTO:0000284': 'organism form',
#  'BTO:0000285': 'corm',
#  'BTO:0000286': 'cornea',
#  'BTO:0000287': 'corneal epithelium',
#  'BTO:0000288': 'corona',
#  'BTO:0000289': 'cytotoxic T-lymphocyte',
#  'BTO:0000290': 'coronary artery',
#  'BTO:0000291': 'corpus allatum',
#  'BTO:0000292': 'corpus luteum',
#  'BTO:0000293': 'occipital lobe',
#  'BTO:0000294': 'dermis',
#  'BTO:0000295': 'WEHI-3 cell',
#  'BTO:0000296': 'SW-1088 cell',
#  'BTO:0000297': 'carcinoma cell line',
#  'BTO:0000298': 'COS-7 cell',
#  'BTO:0000299': 'cotton fibre',
#  'BTO:0000300': 'cotyledon',
#  'BTO:0000301': 'crop',
#  'BTO:0000302': 'ring gland',
#  'BTO:0000303': 'crown gall',
#  'BTO:0000304': 'PANC-1 cell',
#  'BTO:0000305': 'crypt',
#  'BTO:0000306': 'teratocarcinoma cell line',
#  'BTO:0000307': 'crystalline style',
#  'BTO:0000308': 'cytotoxic T-lymphocyte cell line',
#  'BTO:0000309': 'bundle sheath cell',
#  'BTO:0000310': 'protophloem',
#  'BTO:0000312': 'motoneuron',
#  'BTO:0000313': 'hypodermis',
#  'BTO:0000314': 'neuroepithelium',
#  'BTO:0000315': 'ectoderm',
#  'BTO:0000317': 'caulonema',
#  'BTO:0000318': 'CV-1 cell',
#  'BTO:0000319': 'culture condition:cyclohexanol-grown cell',
#  'BTO:0000320': 'cyst',
#  'BTO:0000321': 'plant cuticle',
#  'BTO:0000322': 'cytotrophoblast',
#  'BTO:0000323': 'culture condition:D-mandelate-grown cell',
#  'BTO:0000324': 'culture condition:D-arabinose-induced cell',
#  'BTO:0000325': 'culture condition:D-galactose-grown cell',
#  'BTO:0000326': 'culture condition:D-lyxose-grown cell',
#  'BTO:0000327': 'culture condition:D-mannose-grown cell',
#  'BTO:0000328': 'culture condition:D-phenylglycine-grown cell',
#  'BTO:0000329': 'culture condition:D-ribose-grown cell',
#  'BTO:0000330': 'culture condition:D-ribose-induced cell',
#  'BTO:0000331': 'L-929 cell',
#  'BTO:0000332': 'culture condition:dark-grown cell',
#  'BTO:0000333': 'renal corpuscle',
#  'BTO:0000334': 'decidua parietalis',
#  'BTO:0000335': 'deciduoma cell',
#  'BTO:0000336': 'caput epididymis',
#  'BTO:0000337': 'dental follicle',
#  'BTO:0000338': 'dental plaque',
#  'BTO:0000339': 'dental pulp',
#  'BTO:0000340': 'culture condition:deoxyribonucleoside-induced cell',
#  'BTO:0000341': 'diaphragm',
#  'BTO:0000342': 'diencephalon',
#  'BTO:0000343': 'renal tubule',
#  'BTO:0000344': 'stratum corneum',
#  'BTO:0000345': 'digestive gland',
#  'BTO:0000346': 'digestive juice',
#  'BTO:0000347': 'reticulum',
#  'BTO:0000348': 'omasum',
#  'BTO:0000349': 'gut cavity',
#  'BTO:0000350': 'culture condition:dimethylamine-grown cell',
#  'BTO:0000351': 'disc',
#  'BTO:0000352': 'culture condition:DL-mandelate-grown cell',
#  'BTO:0000353': 'lung cell line',
#  'BTO:0000354': 'DON cell',
#  'BTO:0000355': 'dormant eye',
#  'BTO:0000356': 'breast cancer cell line',
#  'BTO:0000357': 'nectary',
#  'BTO:0000358': 'McA-RH7777 cell',
#  'BTO:0000359': 'middle cervical ganglion',
#  'BTO:0000360': 'posterior spinal root',
#  'BTO:0000361': 'stratum granulosum',
#  'BTO:0000362': 'urinary bladder cancer cell',
#  'BTO:0000363': 'culture condition:dulcitol-grown cell',
#  'BTO:0000364': 'stratum lucidum',
#  'BTO:0000365': 'duodenum',
#  'BTO:0000366': 'duodenal juice',
#  'BTO:0000367': 'duodenal mucosa',
#  'BTO:0000368': 'ear',
#  'BTO:0000369': 'egg',
#  'BTO:0000370': 'egg white',
#  'BTO:0000371': 'egg yolk',
#  'BTO:0000372': 'bone cancer cell',
#  'BTO:0000373': 'Ehrlich ascites carcinoma cell',
#  'BTO:0000374': 'bone cell line',
#  'BTO:0000375': 'keratinocyte cell line',
#  'BTO:0000376': 'electric organ',
#  'BTO:0000377': 'elementary body',
#  'BTO:0000378': 'elytron',
#  'BTO:0000379': 'embryo',
#  'BTO:0000380': 'embryonic axis',
#  'BTO:0000381': 'embryonic blood',
#  'BTO:0000382': 'Kc cell',
#  'BTO:0000383': 'renal cell carcinoma cell line',
#  'BTO:0000384': 'emulsin',
#  'BTO:0000385': 'bone cancer cell line',
#  'BTO:0000386': 'culture condition:(NH4)2SO4-grown cell',
#  'BTO:0000387': 'endocardium',
#  'BTO:0000388': 'endodermis',
#  'BTO:0000389': 'mature ovarian follicle',
#  'BTO:0000390': 'endosperm',
#  'BTO:0000391': 'DLD-1 cell',
#  'BTO:0000392': 'plasma cell',
#  'BTO:0000393': 'endothelium',
#  'BTO:0000394': 'aorta endothelium',
#  'BTO:0000395': 'alveolar cell',
#  'BTO:0000396': 'EAhy 926 cell',
#  'BTO:0000397': 'tooth',
#  'BTO:0000398': 'enterocyte',
#  'BTO:0000399': 'eosinophil',
#  'BTO:0000400': 'sarcoma cell line',
#  'BTO:0000401': 'ependymal epithelium',
#  'BTO:0000402': 'epicotyl',
#  'BTO:0000403': 'mastocytoma cell line',
#  'BTO:0000404': 'epidermis',
#  'BTO:0000405': 'penis',
#  'BTO:0000406': 'L-428 cell',
#  'BTO:0000407': 'osteosarcoma cell line',
#  'BTO:0000408': 'epididymis',
#  'BTO:0000409': 'epimastigote',
#  'BTO:0000410': 'immature ovarian follicle',
#  'BTO:0000411': 'cervical mucosa',
#  'BTO:0000412': 'epiphyseal growth plate',
#  'BTO:0000413': 'epiphysis',
#  'BTO:0000414': 'epithelial cell',
#  'BTO:0000415': 'epithelioma cell',
#  'BTO:0000416': 'epithelium',
#  'BTO:0000417': 'bile duct epithelium',
#  'BTO:0000418': 'neostriatum',
#  'BTO:0000419': 'respiratory epithelium',
#  'BTO:0000420': 'neck',
#  'BTO:0000421': 'connective tissue',
#  'BTO:0000422': 'vaginal epithelium',
#  'BTO:0000423': 'epitrochlearis',
#  'BTO:0000424': 'erythrocyte',
#  'BTO:0000425': 'erythrocytic stage',
#  'BTO:0000426': 'erythroleukemia cell',
#  'BTO:0000427': 'pituitary gland cell line',
#  'BTO:0000428': 'culture condition:ethanol-grown cell',
#  'BTO:0000430': 'EUE cell',
#  'BTO:0000431': 'excretory gland',
#  'BTO:0000432': 'corpus cardiacum',
#  'BTO:0000433': 'exocrine acinar cell',
#  'BTO:0000434': 'exocrine pancreas',
#  'BTO:0000435': 'stratum spinosum',
#  'BTO:0000436': 'extensor digitorum longus',
#  'BTO:0000437': 'culture condition:glycerol-grown cell',
#  'BTO:0000438': 'stratum germinativum',
#  'BTO:0000439': 'eye',
#  'BTO:0000440': 'feces',
#  'BTO:0000442': 'fat body',
#  'BTO:0000443': 'adipocyte',
#  'BTO:0000444': 'fat pad',
#  'BTO:0000445': 'cerebral lobe',
#  'BTO:0000446': 'FDCP-Mix cl.A4 cell',
#  'BTO:0000447': 'feather',
#  'BTO:0000448': 'fetal serum',
#  'BTO:0000449': 'fetus',
#  'BTO:0000450': 'fiber',
#  'BTO:0000451': 'fibrillar flight muscle',
#  'BTO:0000452': 'fibroblast',
#  'BTO:0000453': 'fibroblast cell line',
#  'BTO:0000454': '3T6-Swiss albino cell',
#  'BTO:0000455': 'JTC-15 cell',
#  'BTO:0000456': 'plasmacytoma cell line',
#  'BTO:0000457': 'CHO-K1 cell',
#  'BTO:0000458': 'WI-38 cell',
#  'BTO:0000459': 'fibrosarcoma cell',
#  'BTO:0000460': 'fibrosarcoma cell line',
#  'BTO:0000461': 'HSDM1C1 cell',
#  'BTO:0000462': 'fiddlehead',
#  'BTO:0000463': 'filament',
#  'BTO:0000464': 'flagellate',
#  'BTO:0000465': 'flavedo',
#  'BTO:0000466': 'flexor digitorum longus',
#  'BTO:0000467': 'flight muscle',
#  'BTO:0000468': 'floret',
#  'BTO:0000469': 'flower',
#  'BTO:0000470': 'flower bud',
#  'BTO:0000471': 'culture condition:fluorene-grown cell',
#  'BTO:0000472': 'FM3A cell',
#  'BTO:0000473': 'fetal membrane',
#  'BTO:0000474': 'allantois',
#  'BTO:0000475': 'ovarian follicle',
#  'BTO:0000476': 'foot',
#  'BTO:0000477': 'foot muscle',
#  'BTO:0000478': 'forebrain',
#  'BTO:0000479': 'forelimb muscle',
#  'BTO:0000480': 'forestomach',
#  'BTO:0000481': 'culture condition:formate-grown cell',
#  'BTO:0000482': 'renal distal tubule',
#  'BTO:0000483': 'frond',
#  'BTO:0000484': 'frontal lobe',
#  'BTO:0000485': 'culture condition:fructose-grown cell',
#  'BTO:0000486': 'fruit',
#  'BTO:0000487': 'fruit body',
#  'BTO:0000488': 'lower epidermis',
#  'BTO:0000489': 'intestinal cancer cell',
#  'BTO:0000490': 'prostate gland ventral lobe',
#  'BTO:0000491': 'excretion',
#  'BTO:0000492': 'MST cell',
#  'BTO:0000493': 'gall bladder',
#  'BTO:0000494': 'germinal disc',
#  'BTO:0000495': 'gametophyte',
#  'BTO:0000496': 'anterior lobe',
#  'BTO:0000497': 'ganglion',
#  'BTO:0000498': 'gastric cancer cell',
#  'BTO:0000499': 'gastric corpus mucosa',
#  'BTO:0000500': 'gastric epithelium',
#  'BTO:0000501': 'gastric juice',
#  'BTO:0000502': 'gastric fundus',
#  'BTO:0000503': 'gastric gland',
#  'BTO:0000504': 'pancreatic juice',
#  'BTO:0000505': 'gastric corpus',
#  'BTO:0000506': 'gastrocnemius',
#  'BTO:0000507': 'foregut',
#  'BTO:0000508': 'thorax muscle',
#  'BTO:0000509': 'gastrodermis',
#  'BTO:0000510': 'hindgut',
#  'BTO:0000511': 'gastrointestinal tract',
#  'BTO:0000512': 'primary oocyte',
#  'BTO:0000513': 'culture condition:geranoic acid-induced cell',
#  'BTO:0000514': 'germ',
#  'BTO:0000515': 'haustorium',
#  'BTO:0000516': 'ghost',
#  'BTO:0000517': 'culture condition:5-methylcytosine-grown cell',
#  'BTO:0000518': 'gill',
#  'BTO:0000519': 'gingiva',
#  'BTO:0000520': 'gizzard',
#  'BTO:0000521': 'gizzard smooth muscle',
#  'BTO:0000522': 'gland',
#  'BTO:0000523': 'gleba',
#  'BTO:0000524': 'glia',
#  'BTO:0000525': 'A-875 cell',
#  'BTO:0000526': 'glioma cell',
#  'BTO:0000527': 'glioblastoma cell',
#  'BTO:0000528': 'JTC-27 cell',
#  'BTO:0000529': 'C6 glioma cell',
#  'BTO:0000530': 'renal glomerulus',
#  'BTO:0000531': 'gluteal muscle',
#  'BTO:0000532': 'culture condition:glycine-grown cell',
#  'BTO:0000533': 'culture condition:dihydroxyacetone-grown cell',
#  'BTO:0000534': 'gonad',
#  'BTO:0000535': 'germ cell',
#  'BTO:0000536': 'gracilis muscle',
#  'BTO:0000537': 'nectar',
#  'BTO:0000538': 'alveolar cell type II',
#  'BTO:0000539': 'granulocyte',
#  'BTO:0000540': 'pollen mother cell',
#  'BTO:0000541': 'prostate gland dorsolateral lobe',
#  'BTO:0000542': 'granulosa cell',
#  'BTO:0000543': 'ground meristem',
#  'BTO:0000544': 'guard cell',
#  'BTO:0000545': 'gut',
#  'BTO:0000546': 'gut mucosa',
#  'BTO:0000547': 'gut wall',
#  'BTO:0000548': 'prostate gland lobe',
#  'BTO:0000549': 'culture condition:H2/CO2-grown cell',
#  'BTO:0000550': 'anal plate',
#  'BTO:0000551': 'lung cancer cell',
#  'BTO:0000552': 'HaCaT cell',
#  'BTO:0000553': 'peripheral blood',
#  'BTO:0000554': 'hair follicle',
#  'BTO:0000555': 'hair root',
#  'BTO:0000556': 'germ layer',
#  'BTO:0000557': 'harderian gland',
#  'BTO:0000558': 'hatching gland',
#  'BTO:0000559': 'hatching liquid',
#  'BTO:0000560': 'haustorial mother cell',
#  'BTO:0000561': 'posterior lobe',
#  'BTO:0000562': 'heart',
#  'BTO:0000563': 'culture condition:aerobically-grown cell',
#  'BTO:0000564': 'heart valve',
#  'BTO:0000565': 'HEL cell',
#  'BTO:0000566': 'pancreatic islet cancer cell',
#  'BTO:0000567': 'HeLa cell',
#  'BTO:0000568': 'HeLa-S3 cell',
#  'BTO:0000569': 'exoerythrocytic stage',
#  'BTO:0000570': 'hematopoietic system',
#  'BTO:0000571': 'hemocyte',
#  'BTO:0000572': 'hemolymph',
#  'BTO:0000573': 'artery',
#  'BTO:0000574': 'hematopoietic cell',
#  'BTO:0000575': 'hepatocyte',
#  'BTO:0000576': 'B-16 cell',
#  'BTO:0000577': 'Morris hepatoma 3924A cell',
#  'BTO:0000578': 'hepatoma cell line',
#  'BTO:0000579': 'eye cancer cell',
#  'BTO:0000580': 'blood cancer cell',
#  'BTO:0000581': 'MOPC-315 cell',
#  'BTO:0000582': 'hepatoma ascites cell line',
#  'BTO:0000583': 'bone marrow cancer cell',
#  'BTO:0000584': 'pancreatic cancer cell',
#  'BTO:0000585': 'intraocular melanoma cell',
#  'BTO:0000586': 'colonic cancer cell',
#  'BTO:0000587': 'C 108 cell',
#  'BTO:0000589': 'primary meristem',
#  'BTO:0000590': 'Alzheimer disease specific cell type',
#  'BTO:0000591': 'N1-S1 cell',
#  'BTO:0000592': 'adrenal gland cancer cell',
#  'BTO:0000593': 'Yoshida AH-130 cell',
#  'BTO:0000594': 'liver cancer cell',
#  'BTO:0000595': 'FDCP-1 cell',
#  'BTO:0000596': 'P-19 cell',
#  'BTO:0000597': 'hepatopancreas',
#  'BTO:0000599': 'Hep-G2 cell',
#  'BTO:0000600': 'heterocyst',
#  'BTO:0000601': 'hippocampus',
#  'BTO:0000602': 'histiocyte',
#  'BTO:0000603': 'pre-B acute lymphoblastic leukemia cell line',
#  'BTO:0000604': 'adenocarcinoma cell',
#  'BTO:0000605': 'honey',
#  'BTO:0000606': 'LK-63 cell',
#  'BTO:0000607': 'HTC cell',
#  'BTO:0000608': 'hepatoma cell',
#  'BTO:0000609': 'husk',
#  'BTO:0000610': 'hybridoma cell',
#  'BTO:0000611': 'culture condition:hydroxyproline-induced cell',
#  'BTO:0000612': 'hypha',
#  'BTO:0000613': 'hypocotyl',
#  'BTO:0000614': 'hypothalamus',
#  'BTO:0000615': 'corpus callosum',
#  'BTO:0000616': 'I-cell',
#  'BTO:0000617': 'ileal carcinoid cell',
#  'BTO:0000618': 'ileal lavage fluid',
#  'BTO:0000619': 'ileal mucosa',
#  'BTO:0000620': 'ileum',
#  'BTO:0000621': 'iliopsoas muscle',
#  'BTO:0000622': 'culture condition:cyclopentanol-grown cell',
#  'BTO:0000623': 'culture condition:2-butyne-1,4-diol-grown cell',
#  'BTO:0000624': 'culture condition:cyclohexane-1,2-diol-induced cell',
#  'BTO:0000625': 'culture condition:D-xylose-grown cell',
#  'BTO:0000626': 'culture condition:DL-5-methyltryptophan-grown cell',
#  'BTO:0000627': 'HIT-T15 cell',
#  'BTO:0000628': 'inflorescence',
#  'BTO:0000629': 'ink',
#  'BTO:0000630': 'inner ear',
#  'BTO:0000631': 'culture condition:inositol-deficient-grown cell',
#  'BTO:0000632': 'insulinoma cell',
#  'BTO:0000633': 'Intestine-407 cell',
#  'BTO:0000634': 'integument',
#  'BTO:0000635': 'yellow bone marrow',
#  'BTO:0000636': 'internode',
#  'BTO:0000637': 'interphotoreceptor matrix',
#  'BTO:0000638': 'interrenal cell',
#  'BTO:0000639': 'intersegmental muscle',
#  'BTO:0000640': 'intestinal gland',
#  'BTO:0000641': 'colon descendens',
#  'BTO:0000642': 'intestinal mucosa',
#  'BTO:0000643': 'intestinal muscle',
#  'BTO:0000644': 'intestinal juice',
#  'BTO:0000645': 'colon sigmoideum',
#  'BTO:0000646': 'left colon',
#  'BTO:0000647': 'intestinal wall',
#  'BTO:0000648': 'intestine',
#  'BTO:0000649': 'right colon',
#  'BTO:0000650': 'endocrine pancreas',
#  'BTO:0000651': 'small intestine',
#  'BTO:0000652': 'culture condition:mannuronate-grown cell',
#  'BTO:0000653': 'iris',
#  'BTO:0000654': 'ciliary muscle',
#  'BTO:0000655': 'iris smooth muscle',
#  'BTO:0000656': 'iris sphincter muscle',
#  'BTO:0000657': 'jejunum',
#  'BTO:0000658': 'uterine adenocarcinoma cell',
#  'BTO:0000659': 'juice',
#  'BTO:0000660': 'mycelial cord',
#  'BTO:0000661': 'JURKAT cell',
#  'BTO:0000662': 'nasopharynx',
#  'BTO:0000663': 'juxtaglomerular tumor cell',
#  'BTO:0000664': 'K-562 cell',
#  'BTO:0000665': 'KB cell',
#  'BTO:0000666': 'LoVo cell',
#  'BTO:0000667': 'keratinocyte',
#  'BTO:0000668': 'kernel',
#  'BTO:0000669': 'embryonic cell line',
#  'BTO:0000670': 'KG-1 cell',
#  'BTO:0000671': 'kidney',
#  'BTO:0000672': 'hindbrain',
#  'BTO:0000673': 'metencephalon',
#  'BTO:0000674': 'BHK 165-23 cell',
#  'BTO:0000675': 'SW-620 cell',
#  'BTO:0000676': 'fibroadenoma cell',
#  'BTO:0000677': 'plant tumor tissue',
#  'BTO:0000678': 'G-402 cell',
#  'BTO:0000679': 'blood-lymph',
#  'BTO:0000680': 'kidney cancer cell',
#  'BTO:0000681': 'KM-3 cell',
#  'BTO:0000682': 'Koji culture',
#  'BTO:0000683': 'Krebs ascites cell',
#  'BTO:0000684': 'Krebs II ascites cell',
#  'BTO:0000685': 'Kupffer cell',
#  'BTO:0000686': 'Kurloff cell',
#  'BTO:0000687': 'culture condition:L-mandelate-grown cell',
#  'BTO:0000688': 'culture condition:acetate-grown cell',
#  'BTO:0000689': 'culture condition:L-allo-threonine-grown cell',
#  'BTO:0000690': 'brain cancer cell line',
#  'BTO:0000691': 'culture condition:L-fucose-induced cell',
#  'BTO:0000692': 'culture condition:L-glucose-grown cell',
#  'BTO:0000693': 'culture condition:L-lyxose-induced cell',
#  'BTO:0000694': 'culture condition:L-phenylalanine-grown cell',
#  'BTO:0000695': 'culture condition:L-phenylglycine-grown cell',
#  'BTO:0000696': 'culture condition:L-rhamnose-grown cell',
#  'BTO:0000697': 'culture condition:L-rhamnose-induced cell',
#  'BTO:0000698': 'culture condition:L-ribose-grown cell',
#  'BTO:0000699': 'culture condition:L-serine-grown cell',
#  'BTO:0000700': 'culture condition:L-threonine-grown cell',
#  'BTO:0000701': 'culture condition:L-tyrosine-grown cell',
#  'BTO:0000702': 'L-1210 cell',
#  'BTO:0000703': 'lacquer',
#  'BTO:0000704': 'culture condition:D-lactate-grown cell',
#  'BTO:0000705': 'Langerhans cell',
#  'BTO:0000706': 'large intestine',
#  'BTO:0000707': 'larva',
#  'BTO:0000708': 'larval integument',
#  'BTO:0000709': 'secondary spermatocyte',
#  'BTO:0000710': 'latex',
#  'BTO:0000711': 'glioma cell line',
#  'BTO:0000712': 'laticifer',
#  'BTO:0000713': 'leaf',
#  'BTO:0000714': 'leaf axil',
#  'BTO:0000715': 'leaf base',
#  'BTO:0000716': 'pancreatic beta cell line',
#  'BTO:0000717': 'pericardium',
#  'BTO:0000718': 'leaf epidermis',
#  'BTO:0000719': 'leaf lamina',
#  'BTO:0000720': 'plant form',
#  'BTO:0000721': 'leg',
#  'BTO:0000722': 'leg muscle',
#  'BTO:0000723': 'lens',
#  'BTO:0000724': 'lens fiber',
#  'BTO:0000725': 'hematopoietic stem cell',
#  'BTO:0000726': 'RPMI-8226 cell',
#  'BTO:0000727': 'multiple myeloma cell line',
#  'BTO:0000728': 'Brown Pearce carcinoma cell',
#  'BTO:0000729': 'carcinoid cell',
#  'BTO:0000730': 'endocarp',
#  'BTO:0000731': 'acute lymphoblastic leukemia cell',
#  'BTO:0000732': 'KU-812 cell',
#  'BTO:0000733': 'exocarp',
#  'BTO:0000734': 'myelocyte',
#  'BTO:0000735': 'sporophyte',
#  'BTO:0000736': 'CCRF-CEM cell',
#  'BTO:0000737': 'leukemia cell line',
#  'BTO:0000738': 'HL-60 cell',
#  'BTO:0000739': 'lymphoblastic leukemia cell line',
#  'BTO:0000740': 'myeloid leukemia cell line',
#  'BTO:0000741': 'lymphocytic leukemia cell line',
#  'BTO:0000742': 'myotome',
#  'BTO:0000743': 'pre-B-lymphocyte cell line',
#  'BTO:0000744': 'lymphocytic leukemia cell',
#  'BTO:0000745': 'Lewis lung carcinoma cell',
#  'BTO:0000746': 'preadipocyte cell line',
#  'BTO:0000747': 'sporangiospore',
#  'BTO:0000748': 'P-388 cell',
#  'BTO:0000749': 'sporozoan form',
#  'BTO:0000750': 'plant ovary',
#  'BTO:0000751': 'leukocyte',
#  'BTO:0000752': 'lymph vessel',
#  'BTO:0000753': 'lymphoid tissue',
#  'BTO:0000754': 'lewy body',
#  'BTO:0000755': 'Leydig cell',
#  'BTO:0000756': 'pituitary gland tumor cell line',
#  'BTO:0000757': 'plasmodium',
#  'BTO:0000758': 'myelencephalon',
#  'BTO:0000759': 'liver',
#  'BTO:0000760': 'LLC-PK1 cell',
#  'BTO:0000761': 'collecting duct',
#  'BTO:0000762': 'lung cancer cell line',
#  'BTO:0000763': 'lung',
#  'BTO:0000764': 'lung fibroblast',
#  'BTO:0000765': 'exocrine gland',
#  'BTO:0000766': 'blood vessel endothelium',
#  'BTO:0000767': 'mesenteric lymph node',
#  'BTO:0000768': 'infundibulum',
#  'BTO:0000769': 'submandibular lymph node',
#  'BTO:0000770': 'oligodendroglia',
#  'BTO:0000771': 'macroglia',
#  'BTO:0000772': 'lymphoblast',
#  'BTO:0000773': 'lymphoblastoid cell line',
#  'BTO:0000774': 'lymphoblastoma cell',
#  'BTO:0000775': 'lymphocyte',
#  'BTO:0000776': 'B-lymphocyte',
#  'BTO:0000777': 'adenoid',
#  'BTO:0000778': 'pulmonary artery',
#  'BTO:0000779': 'mesenteric artery',
#  'BTO:0000780': 'alveolar cell type I',
#  'BTO:0000781': 'intestinal epithelium',
#  'BTO:0000782': 'T-lymphocyte',
#  'BTO:0000783': 'pancreatic beta cell',
#  'BTO:0000784': 'lymph node',
#  'BTO:0000785': 'lymphoma cell',
#  'BTO:0000786': 'tongue cancer cell line',
#  'BTO:0000787': 'gastric cancer cell line',
#  'BTO:0000788': '70Z/3 cell',
#  'BTO:0000789': 'CA-46 cell',
#  'BTO:0000790': 'pharyngeal cancer cell line',
#  'BTO:0000791': 'BW-5147 cell',
#  'BTO:0000792': 'urinary bladder carcinoma cell line',
#  'BTO:0000793': 'SH-SY5Y cell',
#  'BTO:0000794': 'pancreatic cancer cell line',
#  'BTO:0000795': 'L-5178-Y cell',
#  'BTO:0000796': 'P-1798 cell',
#  'BTO:0000797': 'colonic cancer cell line',
#  'BTO:0000798': 'BeWo cell',
#  'BTO:0000799': 'lymphosarcoma cell',
#  'BTO:0000800': 'endoderm',
#  'BTO:0000801': 'macrophage',
#  'BTO:0000802': 'alveolar macrophage',
#  'BTO:0000803': 'pancreatic delta cell',
#  'BTO:0000804': 'J-774A.1 cell',
#  'BTO:0000805': 'pancreatic PP cell',
#  'BTO:0000806': 'IC-21 cell',
#  'BTO:0000807': 'chorionic cell line',
#  'BTO:0000808': 'interrenal gland',
#  'BTO:0000809': 'germ cell cancer cell',
#  'BTO:0000810': 'malpighian tubule',
#  'BTO:0000811': 'ovary cancer cell line',
#  'BTO:0000812': 'OVCAR-3 cell',
#  'BTO:0000813': 'Pt-K1 cell',
#  'BTO:0000814': 'CAOV-3 cell',
#  'BTO:0000815': 'MDA-MB-231 cell',
#  'BTO:0000816': 'breast cell line',
#  'BTO:0000817': 'mammary gland',
#  'BTO:0000818': 'spinal column',
#  'BTO:0000819': 'pharyngeal cell line',
#  'BTO:0000820': 'C127I cell',
#  'BTO:0000821': 'nipple',
#  'BTO:0000822': 'culture condition:mandelate-grown cell',
#  'BTO:0000823': 'cerebral gray matter',
#  'BTO:0000824': 'culture condition:mannose-grown cell',
#  'BTO:0000825': 'mantle',
#  'BTO:0000826': 'mantle cavity',
#  'BTO:0000827': 'mantle muscle',
#  'BTO:0000828': 'throat',
#  'BTO:0000829': 'marrow',
#  'BTO:0000830': 'mast cell',
#  'BTO:0000831': 'liver reticuloendothelial system',
#  'BTO:0000832': 'mastocytoma cell',
#  'BTO:0000833': 'RBL-2H3 cell',
#  'BTO:0000834': 'Detroit-562 cell',
#  'BTO:0000835': 'culture condition:L-idonate-grown cell',
#  'BTO:0000836': 'MDBK cell',
#  'BTO:0000837': 'MDCK cell',
#  'BTO:0000838': 'meconium',
#  'BTO:0000839': 'mesoderm',
#  'BTO:0000840': 'nose',
#  'BTO:0000841': 'umbilical artery',
#  'BTO:0000842': 'megagametophyte',
#  'BTO:0000843': 'megakaryocyte',
#  'BTO:0000844': 'megakaryotic cell line',
#  'BTO:0000845': 'meiotic cell',
#  'BTO:0000846': 'erythroleukemia cell line',
#  'BTO:0000847': 'melanocyte',
#  'BTO:0000848': 'melanoma cell',
#  'BTO:0000849': 'melanoma cell line',
#  'BTO:0000850': 'amelanotic melanoma cell',
#  'BTO:0000851': 'adrenal cortex cell line',
#  'BTO:0000852': 'meristem',
#  'BTO:0000853': 'mesangial cell',
#  'BTO:0000854': 'zygote',
#  'BTO:0000855': 'lymph',
#  'BTO:0000856': 'mesocarp',
#  'BTO:0000857': 'umbilical artery endothelium',
#  'BTO:0000858': 'mesophyll',
#  'BTO:0000859': 'metacestode',
#  'BTO:0000860': 'CHRB-30 cell',
#  'BTO:0000861': 'culture condition:methanol-grown cell',
#  'BTO:0000862': 'heart ventricle',
#  'BTO:0000863': 'midgut',
#  'BTO:0000864': 'tibialis',
#  'BTO:0000865': 'anterior spinal root',
#  'BTO:0000866': 'midgut secretion',
#  'BTO:0000867': 'tibialis posterior',
#  'BTO:0000868': 'milk',
#  'BTO:0000869': 'milk fat',
#  'BTO:0000870': 'spinal nerve',
#  'BTO:0000871': 'RAG cell',
#  'BTO:0000872': 'oligodendrocytic cell line',
#  'BTO:0000873': 'MOLT-4 cell',
#  'BTO:0000874': 'molting gland',
#  'BTO:0000875': 'N20.1 cell',
#  'BTO:0000876': 'monocyte',
#  'BTO:0000877': 'culture condition:trehalose-grown cell',
#  'BTO:0000878': 'mononuclear cell',
#  'BTO:0000879': 'lateral ventricle',
#  'BTO:0000880': 'culture condition:alkane-grown cell',
#  'BTO:0000881': 'Morris hepatoma 7777 cell',
#  'BTO:0000882': 'culture condition:p-hydroxyphenylacetic acid-grown cell',
#  'BTO:0000883': 'spinal root',
#  'BTO:0000884': 'molting fluid',
#  'BTO:0000885': 'tongue cell line',
#  'BTO:0000886': 'mucosa',
#  'BTO:0000887': 'muscle',
#  'BTO:0000888': 'muscle fibre',
#  'BTO:0000889': 'Burkitt lymphoma cell line',
#  'BTO:0000890': 'mycelial felt',
#  'BTO:0000891': 'NTERA-2 cell',
#  'BTO:0000892': 'mycobiont',
#  'BTO:0000893': 'mycorrhiza',
#  'BTO:0000894': 'myelin',
#  'BTO:0000895': 'myelin membrane',
#  'BTO:0000896': 'bag cell neuron',
#  'BTO:0000897': 'amnion epithelium',
#  'BTO:0000898': 'myeloma cell',
#  'BTO:0000899': 'myeloma cell line',
#  'BTO:0000900': 'myelin sheath',
#  'BTO:0000901': 'myocardium',
#  'BTO:0000902': 'plant vessel',
#  'BTO:0000903': 'atrium',
#  'BTO:0000904': 'culture condition:beta-aminoisobutyrate-grown cell',
#  'BTO:0000905': 'culture condition:myoinositol-grown cell',
#  'BTO:0000906': 'myeloid cell line',
#  'BTO:0000907': 'myometrium',
#  'BTO:0000908': 'myrosin cell',
#  'BTO:0000909': 'myxospore',
#  'BTO:0000910': 'culture condition:N-acetyl-D-glucosamine-grown cell',
#  'BTO:0000911': 'culture condition:N-acetyl-D-mannosamine-grown cell',
#  'BTO:0000912': 'nasal mucosa',
#  'BTO:0000913': 'nasal polyp',
#  'BTO:0000914': 'natural killer cell',
#  'BTO:0000915': 'nauplius',
#  'BTO:0000917': 'needle',
#  'BTO:0000918': 'nematocyst',
#  'BTO:0000919': '8305C cell',
#  'BTO:0000920': 'neocortex',
#  'BTO:0000921': 'CAL-27 cell',
#  'BTO:0000922': 'neostriatal neuron',
#  'BTO:0000923': 'nephridium',
#  'BTO:0000924': 'nephron',
#  'BTO:0000925': 'nerve',
#  'BTO:0000926': 'ophthalmic nerve',
#  'BTO:0000927': 'nerve trunk',
#  'BTO:0000928': 'limbic system',
#  'BTO:0000929': 'neural retina',
#  'BTO:0000930': 'neuroblast',
#  'BTO:0000931': 'neuroblastoma cell',
#  'BTO:0000932': 'neuroblastoma cell line',
#  'BTO:0000933': 'N18TG2 cell',
#  'BTO:0000934': 'IMR-32 cell',
#  'BTO:0000935': 'LAN-5 cell',
#  'BTO:0000936': 'neurofibrillary tangle',
#  'BTO:0000937': 'neurohypophysis',
#  'BTO:0000938': 'neuron',
#  'BTO:0000939': 'basal cell',
#  'BTO:0000940': 'juice vesicle',
#  'BTO:0000941': 'CAL-33 cell',
#  'BTO:0000942': 'NG-108-15 cell',
#  'BTO:0000943': 'culture condition:nicotinic acid-grown cell',
#  'BTO:0000944': 'NIH-3T3 cell',
#  'BTO:0000945': 'CAL-51 cell',
#  'BTO:0000946': 'NT2/D1 cell',
#  'BTO:0000947': 'neuronal cell line',
#  'BTO:0000948': 'SKOV-3 cell',
#  'BTO:0000949': 'Novikoff ascites tumor cell',
#  'BTO:0000950': 'Novikoff hepatoma cell',
#  'BTO:0000951': 'NRK cell',
#  'BTO:0000952': 'nuchal ligament',
#  'BTO:0000953': 'nurse cell',
#  'BTO:0000954': 'nymph',
#  'BTO:0000955': 'laryngeal cell line',
#  'BTO:0000956': 'gut epithelium',
#  'BTO:0000957': 'nape',
#  'BTO:0000958': 'spermatogonium',
#  'BTO:0000959': 'esophagus',
#  'BTO:0000960': 'UT-7 cell',
#  'BTO:0000961': 'olfactory bulb',
#  'BTO:0000962': 'oligodendrocyte',
#  'BTO:0000963': 'oligodendroglioma cell',
#  'BTO:0000964': 'oocyte',
#  'BTO:0000965': 'optic lobe',
#  'BTO:0000966': 'optic nerve',
#  'BTO:0000967': 'osseous plate',
#  'BTO:0000968': 'osteoclast',
#  'BTO:0000969': 'osteoclastoma cell',
#  'BTO:0000970': 'osteosarcoma cell',
#  'BTO:0000971': 'SAOS-2 cell',
#  'BTO:0000972': 'HEP-3B cell',
#  'BTO:0000973': 'respiratory mucosa',
#  'BTO:0000974': 'culture condition:sulfite-grown cell',
#  'BTO:0000975': 'ovary',
#  'BTO:0000976': 'HEp-2 cell',
#  'BTO:0000977': 'ovary cell line',
#  'BTO:0000978': 'CMK cell',
#  'BTO:0000979': 'PANC-3 cell',
#  'BTO:0000980': 'oviduct',
#  'BTO:0000981': 'ovotestis',
#  'BTO:0000982': 'culture condition:p-cresol-grown cell',
#  'BTO:0000983': 'culture condition:p-toluate-grown cell',
#  'BTO:0000984': 'P-388D1 cell',
#  'BTO:0000985': 'P-815 cell',
#  'BTO:0000986': 'pachytene cell',
#  'BTO:0000987': 'palisade parenchyma',
#  'BTO:0000988': 'pancreas',
#  'BTO:0000989': 'taste bud',
#  'BTO:0000990': 'pancreatic alpha cell',
#  'BTO:0000991': 'pancreatic islet',
#  'BTO:0000992': 'tongue epithelium',
#  'BTO:0000993': 'paneth cell',
#  'BTO:0000994': 'RBL-1 cell',
#  'BTO:0000995': 'paramyeloblast',
#  'BTO:0000996': 'gametocyte',
#  'BTO:0000997': 'parathyroid gland',
#  'BTO:0000998': 'paraveinal mesophyll',
#  'BTO:0000999': 'plant parenchyma',
#  'BTO:0001000': 'acute megakaryocytic leukemia cell line',
#  'BTO:0001001': 'parietal lobe',
#  'BTO:0001002': 'schizont',
#  'BTO:0001003': 'parotid acinar cell',
#  'BTO:0001004': 'parotid gland',
#  'BTO:0001005': 'amnion epithelial cell',
#  'BTO:0001006': 'pelvis',
#  ...}

# %%
#Name Mappings
id_to_name = {id_: data.get('name') for id_, data in graph.nodes(data=True)}
name_to_id = {data['name']: id_ for id_, data in graph.nodes(data=True) if 'name' in data}

# %%
# Find edges to parent terms
node = name_to_id['cardiac muscle']
for child, parent, key in graph.out_edges(node, keys=True):
    print(f'• {id_to_name[child]} ⟶ {key} ⟶ {id_to_name[parent]}')
# Out:
# • cardiac muscle ⟶ is_a ⟶ muscle
# • cardiac muscle ⟶ part_of ⟶ heart
# • cardiac muscle ⟶ part_of ⟶ vertebrate muscular system

# %% [markdown]
# ## Prova con OWL file

# %%
from rdflib import Graph
import networkx as nx

# Leggi il file OWL in un grafo RDF utilizzando rdflib
file_path = "bionutrition_cam9.owl"
g = Graph()
g.parse(file_path, format="xml")  # Assicurati di specificare il formato corretto del tuo file OWL

# Costruisci un grafo NetworkX basato sui dati RDF
import networkx as nx

# Crea un nuovo grafo NetworkX
G1 = nx.MultiDiGraph()  # Usa MultiDiGraph se il tuo grafo RDF contiene archi multipli tra gli stessi nodi

# %%
# Estrai i nodi e gli archi dal grafo RDF e aggiungili al grafo NetworkX
for subject, predicate, obj in g:
    G1.add_node(subject)
    G1.add_node(obj)
    G1.add_edge(subject, obj, key=predicate)

G1

# %%
print(G1.nodes)
# Out:
# [rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Single_Nutrient_Intake'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#PctLeanMass'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement_Waist_Circumference'), rdflib.term.Literal('Hip Waist Measurement Waist Circumference', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Anthropometrics_Height'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Anthropometrics'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement_Waist_To_Hip_Ratio'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Day_5_Inpatient'), rdflib.term.Literal('Day 5 Inpatient', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Food_Record_3_4_Day'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Underwater_Weighing_PctBodyFat'), rdflib.term.Literal('Underwater Weighing Percent Body Fat', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.BNode('Nbea0ff43cf1a4993965b87f60e18dc9c'), rdflib.term.BNode('Nd643e164c2174e37a583787d554e62e2'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Activity_Factor_or_Equation'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Bioelectric_Impedence'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#BodyComposition'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Activity_Physical_Assessment'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Harris_Benedict_Equation'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Bike'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Micronutrient'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_Dev_Carbohydrate'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_dev'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Day_1_Inpatient'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#ResearchNutritionAssessmentProcedure'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Micronutrient_Prot_dev'), rdflib.term.Literal('Micronutrient Protocol Development', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#NutritionRoles'), rdflib.term.Literal('Nutrition Roles', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Inpatient'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#DietMealsServed'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Whole_Calorimetry'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Energy_Expediture'), rdflib.term.Literal('Procedures used in the Bionutrition domain', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Parenteral'), rdflib.term.URIRef('http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_Dev_Fiber'), rdflib.term.Literal('Macronutrient Protocol Development Fiber', datatype=rdflib.term.URIRef('http://ww ...

# %%
# Itera sui triple nel grafo RDF
for predicate in G1:
    print(f"Predicate: {predicate}")
# Out:
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Single_Nutrient_Intake
# Predicate: http://www.w3.org/2002/07/owl#Class
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#PctLeanMass
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement_Waist_Circumference
# Predicate: Hip Waist Measurement Waist Circumference
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Anthropometrics_Height
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Anthropometrics
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement_Waist_To_Hip_Ratio
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Day_5_Inpatient
# Predicate: Day 5 Inpatient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Food_Record_3_4_Day
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Underwater_Weighing_PctBodyFat
# Predicate: Underwater Weighing Percent Body Fat
# Predicate: Nbea0ff43cf1a4993965b87f60e18dc9c
# Predicate: Nd643e164c2174e37a583787d554e62e2
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Activity_Factor_or_Equation
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Bioelectric_Impedence
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#BodyComposition
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Activity_Physical_Assessment
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Harris_Benedict_Equation
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Bike
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Micronutrient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_Dev_Carbohydrate
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_dev
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Day_1_Inpatient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#ResearchNutritionAssessmentProcedure
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Micronutrient_Prot_dev
# Predicate: Micronutrient Protocol Development
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#NutritionRoles
# Predicate: Nutrition Roles
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Inpatient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#DietMealsServed
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Whole_Calorimetry
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Energy_Expediture
# Predicate: Procedures used in the Bionutrition domain
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Parenteral
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_Dev_Fiber
# Predicate: Macronutrient Protocol Development Fiber
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#DEXA
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Grip_Strength
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Day_Rotation_3
# Predicate: Day Rotation 3
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Nutraceuticals_Prot_dev
# Predicate: Nc31286d9121141f9b568f397a2a83b10
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#TransFattyAcids
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#DietPlan
# Predicate: Diet Plan
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Minute_6_Walk
# Predicate: 6 Minute Walk
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Nutraceuticals_Prot_Dev_Resveratrol
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Underwater_Weighing_PctLeanMass
# Predicate: Underwater Weighing Percent Lean Mass
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#WholeFood
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#RotatingMenuCycle
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Metabolic
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Day_Rotation_1
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Diet_Review
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Screening
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Nutrient_Composition
# Predicate: N187015558ef6453cab58daae6b6f38a7
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Underwater_Weighing
# Predicate: Underwater Weighing
# Predicate: N267beba857a54073a0034f2c9a686740
# Predicate: Neb1b01dd7bd443d7806af601d2369069
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Predicted_Equation
# Predicate: Activity Factor or Equation
# Predicate: Nfc964f18889b4525af744543a428b051
# Predicate: Nc320009dec5c4e1098f5131dc4cdd88f
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Snacks
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Enteral
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Formula
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#BodPod
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Day_2_Inpatient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Adjusted_Body_Weight_Equation_for_Obesity
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Fiber
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#MacronutrientsControlled
# Predicate: Hip Waist Measurement Waist To Hip Ratio
# Predicate: Nutraceuticals Protocol Development
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#NutritionCapabilities
# Predicate: Nutraceuticals Protocol Development Omega 3 Fatty Acids
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#DesignDiet
# Predicate: Design Diet
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Skinfold
# Predicate: Rotating Menu Cycle
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_Dev_Protein
# Predicate: Macronutrient Protocol Development Protein
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Education
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Nutrition_Assessment_Care_Plan
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Theraputic
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Anthropometrics_BMI
# Predicate: Research Nutrition Assessment Procedure
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Metabolic_Monitor_Cart
# Predicate: Metabolic Monitor Cart
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Group
# Predicate: Nutrition Capabilities
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Skinfold_Subscapular
# Predicate: N8c3fb1a933fe4b779996a5d7f872a36d
# Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#nil
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Food_Frequency_Questionnaires
# Predicate: Food Frequency Questionnaires
# Predicate: Trans Fatty Acids
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Hour_24_Diet_Recall
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Nutrient_Analysis
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Day_Rotation_5
# Predicate: Day Rotation 5
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Hip_Waist_Measurement_Hip_Circumference
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#PRO
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Navigation
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#CHO
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Unsaturated
# Predicate: Predicted Equation
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#PctBodyFat
# Predicate: Percent Body Fat
# Predicate: Ndbbb03fa19e4462c92412ef10c650bc6
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Anthropometrics_Weight
# Predicate: Whole Food
# Predicate: Anthropometrics Weight
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Menu_Rotation
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Outpatient
# Predicate: Adjusted Body Weight Equation for Obesity
# Predicate: Macronutrient Protocol Development Carbohydrate
# Predicate: Percent Lean Mass
# Predicate: Anthropometrics
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Water
# Predicate: N249c2c6904e541fdacdfe6a38c0b6112
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#hasSubtype
# Predicate: http://www.w3.org/2002/07/owl#ObjectProperty
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Spirometry
# Predicate: N41bbaf6d07be41f68256f0e12439df00
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Poly
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#ProtocolDevelopment
# Predicate: Day Rotation 1
# Predicate: Energy Expediture
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Assessory_Nutrient
# Predicate: Protocol Development
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Metabolic_Diet_Protocol
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Skinfold_Suprailiac
# Predicate: N5f87f6cd5e634bbd9c52b31e1446f339
# Predicate: Diet Meals Served
# Predicate: Nf8ac2076b1e84a78b7e90eb32b2747ee
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#FAT
# Predicate: Skinfold Suprailiac
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Individual
# Predicate: Day 1 Inpatient
# Predicate: Macronutrients Controlled
# Predicate: <p style="margin-top: 0">
#       Body Composition is evaluated through multiple procedures
#     </p>
# Predicate: Nutrient Analysis
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Activity_Questionnaire
# Predicate: Activity Questionnaire
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Mono
# Predicate: Grip Strength
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#ScientificLiterature
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Macronutrient_Prot_Dev_Fat
# Predicate: Hip Waist Measurement
# Predicate: Hip Waist Measurement Hip Circumference
# Predicate: Assessory Nutrient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Food_Recall
# Predicate: Anthropometrics Height
# Predicate: Nd7c6cc106e8d43ef9e9778c79230eb10
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#MicronutrientsControlled
# Predicate: Macronutrient Protocol Development Fat
# Predicate: Single Nutrient Intake
# Predicate: Diet Review
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Food_Record_7_Day
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Saturated
# Predicate: Hour 24 Diet Recall
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Regular
# Predicate: Scientific Literature
# Predicate: Food Record 3 4 Day
# Predicate: <p style="margin-top: 0">
#       Anthropometrics evaluates ...
#     </p>
# Predicate: Activity Physical Assessment
# Predicate: Whole Calorimetry
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#hasSubsection
# Predicate: Body Composition
# Predicate: BodPod
# Predicate: Menu Rotation
# Predicate: Day 2 Inpatient
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#hasAnalyticalAssessment
# Predicate: Nutraceuticals Protocol Development Resveratrol
# Predicate: Harris Benedict Equation
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#hasComposingMeasurements
# Predicate: Anthropometrics BMI
# Predicate: Bioelectric Impedence
# Predicate: Nutrition Assessment Care Plan
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl
# Predicate: http://www.w3.org/2002/07/owl#Ontology
# Predicate: Food Recall
# Predicate: Macronutrient Protocol Development
# Predicate: Nutrient Composition
# Predicate: Micronutrients Controlled
# Predicate: Food Record 7 Day
# Predicate: http://www.owl-ontologies.com/Ontology1361987617.owl#Treadmill
# Predicate: Metabolic Diet Protocol
# Predicate: Skinfold Subscapular

# %% [markdown]
# ## OWL ->OBO
# E' più comodo gestire i file in formato OBO che OWL, per cambiare formato utilizzare Protegè

# %%
G2 = obonet.read_obo('bionut.obo')
len(G2)
# Out:
# 100

# %%
G2.nodes
# Out:
# NodeView(('Activity_Factor_or_Equation', 'Activity_Physical_Assessment', 'Activity_Questionnaire', 'Adjusted_Body_Weight_Equation_for_Obesity', 'Anthropometrics', 'Anthropometrics_BMI', 'Anthropometrics_Height', 'Anthropometrics_Weight', 'Assessory_Nutrient', 'Bike', 'Bioelectric_Impedence', 'BodPod', 'BodyComposition', 'CHO', 'DEXA', 'Day_1_Inpatient', 'Day_2_Inpatient', 'Day_5_Inpatient', 'Day_Rotation_1', 'Day_Rotation_3', 'Day_Rotation_5', 'DesignDiet', 'DietMealsServed', 'DietPlan', 'Diet_Review', 'Education', 'Energy_Expediture', 'Enteral', 'FAT', 'Fiber', 'Food_Frequency_Questionnaires', 'Food_Recall', 'Food_Record_3_4_Day', 'Food_Record_7_Day', 'Formula', 'Grip_Strength', 'Group', 'Harris_Benedict_Equation', 'Hip_Waist_Measurement', 'Hip_Waist_Measurement_Hip_Circumference', 'Hip_Waist_Measurement_Waist_Circumference', 'Hip_Waist_Measurement_Waist_To_Hip_Ratio', 'Hour_24_Diet_Recall', 'Individual', 'Inpatient', 'Macronutrient', 'Macronutrient_Prot_Dev_Carbohydrate', 'Macronutrient_Prot_Dev_Fat', 'Macronutrient_Prot_Dev_Fiber', 'Macronutrient_Prot_Dev_Protein', 'Macronutrient_Prot_dev', 'MacronutrientsControlled', 'Menu_Rotation', 'Metabolic', 'Metabolic_Diet_Protocol', 'Metabolic_Monitor_Cart', 'Micronutrient', 'Micronutrient_Prot_dev', 'MicronutrientsControlled', 'Minute_6_Walk', 'Mono', 'Navigation', 'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids', 'Nutraceuticals_Prot_Dev_Resveratrol', 'Nutraceuticals_Prot_dev', 'Nutrient_Analysis', 'Nutrient_Composition', 'NutritionCapabilities', 'NutritionRoles', 'Nutrition_Assessment_Care_Plan', 'Outpatient', 'PRO', 'Parenteral', 'PctBodyFat', 'PctLeanMass', 'Poly', 'Predicted_Equation', 'ProtocolDevelopment', 'Regular', 'ResearchNutritionAssessmentProcedure', 'RotatingMenuCycle', 'Saturated', 'ScientificLiterature', 'Screening', 'Single_Nutrient_Intake', 'Skinfold', 'Skinfold_Subscapular', 'Skinfold_Suprailiac', 'Snacks', 'Spirometry', 'Theraputic', 'TransFattyAcids', 'Treadmill', 'Underwater_Weighing', 'Underwater_Weighing_PctBodyFat', 'Underwater_Weighing_PctLeanMass', 'Unsaturated', 'Water', 'WholeFood', 'Whole_Calorimetry'))

# %%
print(G2.nodes['Activity_Factor_or_Equation'])
# Out:
# {'name': 'Activity Factor or Equation', 'is_a': ['Activity_Physical_Assessment']}

# %%
start_node = 'Activity_Factor_or_Equation'
end_node = 'Food_Record_7_Day'

# Estrai i nodi dal grafo tra start_node e end_node inclusi
nodes_to_draw = [node for node in G2.nodes() if start_node <= node <= end_node]
# Crea un sottografo contenente solo i primi 20 nodi
subgraph = G2.subgraph(nodes_to_draw)

# Disegna il sottografoù
pos = nx.spring_layout(subgraph)  # Posizionamento dei nodi nel grafico
labels = nx.get_node_attributes(subgraph, 'name')  # Etichette dei nodi
edge_labels = nx.get_edge_attributes(subgraph, 'relation_type')
nx.draw(subgraph, with_labels=labels, node_color='skyblue', node_size=100, font_size=5, font_weight='bold')
nx.draw_networkx_edge_labels(subgraph, pos, edge_labels=edge_labels) 
plt.show()

# %% [markdown]
# # Matching triples

# %%
graph = G #Prendiamo il primo grafo
subject_label = "cardiac muscle"
predicate_label = "is_a"
object_label = "ass"

# Cerca i nodi corrispondenti ai nomi specificati
subject_node = None
object_node = None

for node, data in graph.nodes(data=True):
    if data.get("name") == subject_label:
        subject_node = node
    elif data.get("name") == object_label:
        object_node = node

# Verifica se le corrispondenze sono state trovate
if subject_node is not None and object_node is not None:
    # Controlla se esiste un arco tra i nodi
    if graph.has_edge(subject_node, object_node, key=predicate_label):
        print(f"Trovata la tripla: {subject_label} {predicate_label} {object_label}")
    else:
        print("Tripla non trovata nel grafo.")
else:
    print("Uno o entrambi i nodi non trovati nel grafo.")
# Out:
# Uno o entrambi i nodi non trovati nel grafo.

# %% [markdown]
# # Algoritmi & tools grafo
# * https://networkx.org/documentation/stable/reference/algorithms/index.html

# %%
from networkx.algorithms import approximation #aggiungere nx. prima di ognmi funzionew
# from networkx.algorithms.approximation import function_name Per aggiungere algoritmi modificare function_name

# %%
#Prendiamo il grafo più piccoli per tempi computazionali
print(len(G2))
print(G2)
# Out:
# 100
# MultiDiGraph named 'http://www.owl-ontologies.com/Ontology1361987617.owl' with 100 nodes and 100 edges

# %%
G2.edges
# Out:
# OutMultiEdgeView([('Activity_Factor_or_Equation', 'Activity_Physical_Assessment', 'is_a'), ('Activity_Physical_Assessment', 'ResearchNutritionAssessmentProcedure', 'is_a'), ('Activity_Questionnaire', 'Activity_Physical_Assessment', 'is_a'), ('Adjusted_Body_Weight_Equation_for_Obesity', 'Predicted_Equation', 'is_a'), ('Anthropometrics', 'BodyComposition', 'is_a'), ('Anthropometrics_BMI', 'Anthropometrics', 'is_a'), ('Anthropometrics_Height', 'Anthropometrics', 'is_a'), ('Anthropometrics_Weight', 'Anthropometrics', 'is_a'), ('Assessory_Nutrient', 'Single_Nutrient_Intake', 'is_a'), ('Bike', 'Activity_Physical_Assessment', 'is_a'), ('Bioelectric_Impedence', 'BodyComposition', 'is_a'), ('BodPod', 'BodyComposition', 'is_a'), ('BodyComposition', 'ResearchNutritionAssessmentProcedure', 'is_a'), ('CHO', 'MacronutrientsControlled', 'is_a'), ('DEXA', 'BodyComposition', 'is_a'), ('Day_1_Inpatient', 'RotatingMenuCycle', 'is_a'), ('Day_2_Inpatient', 'RotatingMenuCycle', 'is_a'), ('Day_5_Inpatient', 'RotatingMenuCycle', 'is_a'), ('Day_Rotation_1', 'Menu_Rotation', 'is_a'), ('Day_Rotation_3', 'Menu_Rotation', 'is_a'), ('Day_Rotation_5', 'Menu_Rotation', 'is_a'), ('DesignDiet', 'ProtocolDevelopment', 'is_a'), ('DietMealsServed', 'DietPlan', 'is_a'), ('DietPlan', 'NutritionRoles', 'is_a'), ('Diet_Review', 'Screening', 'is_a'), ('Education', 'Nutrition_Assessment_Care_Plan', 'is_a'), ('Energy_Expediture', 'ResearchNutritionAssessmentProcedure', 'is_a'), ('Enteral', 'Formula', 'is_a'), ('FAT', 'MacronutrientsControlled', 'is_a'), ('Fiber', 'MacronutrientsControlled', 'is_a'), ('Food_Frequency_Questionnaires', 'Nutrient_Analysis', 'is_a'), ('Food_Recall', 'Nutrient_Analysis', 'is_a'), ('Food_Record_3_4_Day', 'Food_Recall', 'is_a'), ('Food_Record_7_Day', 'Food_Recall', 'is_a'), ('Formula', 'Theraputic', 'is_a'), ('Grip_Strength', 'Activity_Physical_Assessment', 'is_a'), ('Group', 'Education', 'is_a'), ('Harris_Benedict_Equation', 'Predicted_Equation', 'is_a'), ('Hip_Waist_Measurement', 'BodyComposition', 'is_a'), ('Hip_Waist_Measurement_Hip_Circumference', 'Hip_Waist_Measurement', 'is_a'), ('Hip_Waist_Measurement_Waist_Circumference', 'Hip_Waist_Measurement', 'is_a'), ('Hip_Waist_Measurement_Waist_To_Hip_Ratio', 'Hip_Waist_Measurement', 'is_a'), ('Hour_24_Diet_Recall', 'Nutrient_Analysis', 'is_a'), ('Individual', 'Education', 'is_a'), ('Inpatient', 'DietMealsServed', 'is_a'), ('Macronutrient', 'Single_Nutrient_Intake', 'is_a'), ('Macronutrient_Prot_Dev_Carbohydrate', 'Macronutrient_Prot_dev', 'is_a'), ('Macronutrient_Prot_Dev_Fat', 'Macronutrient_Prot_dev', 'is_a'), ('Macronutrient_Prot_Dev_Fiber', 'Macronutrient_Prot_dev', 'is_a'), ('Macronutrient_Prot_Dev_Protein', 'Macronutrient_Prot_dev', 'is_a'), ('Macronutrient_Prot_dev', 'Nutrient_Composition', 'is_a'), ('MacronutrientsControlled', 'Metabolic', 'is_a'), ('Menu_Rotation', 'DesignDiet', 'is_a'), ('Metabolic', 'DietPlan', 'is_a'), ('Metabolic_Diet_Protocol', 'Screening', 'is_a'), ('Metabolic_Monitor_Cart', 'Energy_Expediture', 'is_a'), ('Micronutrient', 'Single_Nutrient_Intake', 'is_a'), ('Micronutrient_Prot_dev', 'Nutrient_Composition', 'is_a'), ('MicronutrientsControlled', 'Metabolic', 'is_a'), ('Minute_6_Walk', 'Activity_Physical_Assessment', 'is_a'), ('Mono', 'Unsaturated', 'is_a'), ('Navigation', 'ProtocolDevelopment', 'is_a'), ('Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids', 'Nutraceuticals_Prot_dev', 'is_a'), ('Nutraceuticals_Prot_Dev_Resveratrol', 'Nutraceuticals_Prot_dev', 'is_a'), ('Nutraceuticals_Prot_dev', 'Nutrient_Composition', 'is_a'), ('Nutrient_Analysis', 'Nutrition_Assessment_Care_Plan', 'is_a'), ('Nutrient_Composition', 'DesignDiet', 'is_a'), ('NutritionRoles', 'NutritionCapabilities', 'is_a'), ('Nutrition_Assessment_Care_Plan', 'ResearchNutritionAssessmentProcedure', 'is_a'), ('Outpatient', 'DietMealsServed', 'is_a'), ('PRO', 'MacronutrientsControlled', 'is_a'), ('Parenteral', 'Formula', 'is_a'), ('PctBodyFat', 'BodPod', 'is_a'), ('PctLeanMass', 'BodPod', 'is_a'), ('Poly', 'U ...

# %%
G2.has_node('Activity_Physical_Assessment')
# Out:
# True

# %%
from networkx.algorithms.approximation import all_pairs_node_connectivity
all_pairs_node_connectivity(G2)
# Out:
# {'Activity_Factor_or_Equation': {'Activity_Physical_Assessment': 1,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Activity_Physical_Assessment': {'Activity_Factor_or_Equation': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Activity_Questionnaire': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 1,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Adjusted_Body_Weight_Equation_for_Obesity': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 1,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 1,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Anthropometrics': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Anthropometrics_BMI': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 1,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Anthropometrics_Height': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 1,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Anthropometrics_Weight': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 1,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Assessory_Nutrient': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 1,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 1,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 1,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Bike': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 1,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Bioelectric_Impedence': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'BodPod': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'BodyComposition': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'CHO': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 1,
#   'Menu_Rotation': 0,
#   'Metabolic': 1,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'DEXA': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Day_1_Inpatient': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 1,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 1,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Day_2_Inpatient': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 1,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 1,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Day_5_Inpatient': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 1,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 1,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Day_Rotation_1': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 1,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
# ...
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Underwater_Weighing_PctBodyFat': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 1,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Underwater_Weighing_PctLeanMass': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 1,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 1,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Unsaturated': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 1,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 1,
#   'Menu_Rotation': 0,
#   'Metabolic': 1,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Water': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'Water': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 1,
#   'Menu_Rotation': 0,
#   'Metabolic': 1,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'WholeFood': 0,
#   'Whole_Calorimetry': 0},
#  'WholeFood': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 1,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 0,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 0,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 1,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'Whole_Calorimetry': 0},
#  'Whole_Calorimetry': {'Activity_Factor_or_Equation': 0,
#   'Activity_Physical_Assessment': 0,
#   'Activity_Questionnaire': 0,
#   'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#   'Anthropometrics': 0,
#   'Anthropometrics_BMI': 0,
#   'Anthropometrics_Height': 0,
#   'Anthropometrics_Weight': 0,
#   'Assessory_Nutrient': 0,
#   'Bike': 0,
#   'Bioelectric_Impedence': 0,
#   'BodPod': 0,
#   'BodyComposition': 0,
#   'CHO': 0,
#   'DEXA': 0,
#   'Day_1_Inpatient': 0,
#   'Day_2_Inpatient': 0,
#   'Day_5_Inpatient': 0,
#   'Day_Rotation_1': 0,
#   'Day_Rotation_3': 0,
#   'Day_Rotation_5': 0,
#   'DesignDiet': 0,
#   'DietMealsServed': 0,
#   'DietPlan': 0,
#   'Diet_Review': 0,
#   'Education': 0,
#   'Energy_Expediture': 1,
#   'Enteral': 0,
#   'FAT': 0,
#   'Fiber': 0,
#   'Food_Frequency_Questionnaires': 0,
#   'Food_Recall': 0,
#   'Food_Record_3_4_Day': 0,
#   'Food_Record_7_Day': 0,
#   'Formula': 0,
#   'Grip_Strength': 0,
#   'Group': 0,
#   'Harris_Benedict_Equation': 0,
#   'Hip_Waist_Measurement': 0,
#   'Hip_Waist_Measurement_Hip_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_Circumference': 0,
#   'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0,
#   'Hour_24_Diet_Recall': 0,
#   'Individual': 0,
#   'Inpatient': 0,
#   'Macronutrient': 0,
#   'Macronutrient_Prot_Dev_Carbohydrate': 0,
#   'Macronutrient_Prot_Dev_Fat': 0,
#   'Macronutrient_Prot_Dev_Fiber': 0,
#   'Macronutrient_Prot_Dev_Protein': 0,
#   'Macronutrient_Prot_dev': 0,
#   'MacronutrientsControlled': 0,
#   'Menu_Rotation': 0,
#   'Metabolic': 0,
#   'Metabolic_Diet_Protocol': 0,
#   'Metabolic_Monitor_Cart': 0,
#   'Micronutrient': 0,
#   'Micronutrient_Prot_dev': 0,
#   'MicronutrientsControlled': 0,
#   'Minute_6_Walk': 0,
#   'Mono': 0,
#   'Navigation': 0,
#   'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0,
#   'Nutraceuticals_Prot_Dev_Resveratrol': 0,
#   'Nutraceuticals_Prot_dev': 0,
#   'Nutrient_Analysis': 0,
#   'Nutrient_Composition': 0,
#   'NutritionCapabilities': 1,
#   'NutritionRoles': 1,
#   'Nutrition_Assessment_Care_Plan': 0,
#   'Outpatient': 0,
#   'PRO': 0,
#   'Parenteral': 0,
#   'PctBodyFat': 0,
#   'PctLeanMass': 0,
#   'Poly': 0,
#   'Predicted_Equation': 0,
#   'ProtocolDevelopment': 0,
#   'Regular': 0,
#   'ResearchNutritionAssessmentProcedure': 1,
#   'RotatingMenuCycle': 0,
#   'Saturated': 0,
#   'ScientificLiterature': 0,
#   'Screening': 0,
#   'Single_Nutrient_Intake': 0,
#   'Skinfold': 0,
#   'Skinfold_Subscapular': 0,
#   'Skinfold_Suprailiac': 0,
#   'Snacks': 0,
#   'Spirometry': 0,
#   'Theraputic': 0,
#   'TransFattyAcids': 0,
#   'Treadmill': 0,
#   'Underwater_Weighing': 0,
#   'Underwater_Weighing_PctBodyFat': 0,
#   'Underwater_Weighing_PctLeanMass': 0,
#   'Unsaturated': 0,
#   'Water': 0,
#   'WholeFood': 0}}

# %%
#from networkx.algorithms.approximation import  degree_centrality
nx.degree_centrality(G2)
# Out:
# {'Activity_Factor_or_Equation': 0.010101010101010102,
#  'Activity_Physical_Assessment': 0.07070707070707072,
#  'Activity_Questionnaire': 0.010101010101010102,
#  'Adjusted_Body_Weight_Equation_for_Obesity': 0.010101010101010102,
#  'Anthropometrics': 0.04040404040404041,
#  'Anthropometrics_BMI': 0.010101010101010102,
#  'Anthropometrics_Height': 0.010101010101010102,
#  'Anthropometrics_Weight': 0.010101010101010102,
#  'Assessory_Nutrient': 0.010101010101010102,
#  'Bike': 0.010101010101010102,
#  'Bioelectric_Impedence': 0.010101010101010102,
#  'BodPod': 0.030303030303030304,
#  'BodyComposition': 0.08080808080808081,
#  'CHO': 0.010101010101010102,
#  'DEXA': 0.010101010101010102,
#  'Day_1_Inpatient': 0.010101010101010102,
#  'Day_2_Inpatient': 0.010101010101010102,
#  'Day_5_Inpatient': 0.010101010101010102,
#  'Day_Rotation_1': 0.010101010101010102,
#  'Day_Rotation_3': 0.010101010101010102,
#  'Day_Rotation_5': 0.010101010101010102,
#  'DesignDiet': 0.030303030303030304,
#  'DietMealsServed': 0.030303030303030304,
#  'DietPlan': 0.06060606060606061,
#  'Diet_Review': 0.010101010101010102,
#  'Education': 0.030303030303030304,
#  'Energy_Expediture': 0.04040404040404041,
#  'Enteral': 0.010101010101010102,
#  'FAT': 0.04040404040404041,
#  'Fiber': 0.010101010101010102,
#  'Food_Frequency_Questionnaires': 0.010101010101010102,
#  'Food_Recall': 0.030303030303030304,
#  'Food_Record_3_4_Day': 0.010101010101010102,
#  'Food_Record_7_Day': 0.010101010101010102,
#  'Formula': 0.030303030303030304,
#  'Grip_Strength': 0.010101010101010102,
#  'Group': 0.010101010101010102,
#  'Harris_Benedict_Equation': 0.010101010101010102,
#  'Hip_Waist_Measurement': 0.04040404040404041,
#  'Hip_Waist_Measurement_Hip_Circumference': 0.010101010101010102,
#  'Hip_Waist_Measurement_Waist_Circumference': 0.010101010101010102,
#  'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0.010101010101010102,
#  'Hour_24_Diet_Recall': 0.010101010101010102,
#  'Individual': 0.010101010101010102,
#  'Inpatient': 0.010101010101010102,
#  'Macronutrient': 0.010101010101010102,
#  'Macronutrient_Prot_Dev_Carbohydrate': 0.010101010101010102,
#  'Macronutrient_Prot_Dev_Fat': 0.010101010101010102,
#  'Macronutrient_Prot_Dev_Fiber': 0.010101010101010102,
#  'Macronutrient_Prot_Dev_Protein': 0.010101010101010102,
#  'Macronutrient_Prot_dev': 0.05050505050505051,
#  'MacronutrientsControlled': 0.06060606060606061,
#  'Menu_Rotation': 0.04040404040404041,
#  'Metabolic': 0.04040404040404041,
#  'Metabolic_Diet_Protocol': 0.010101010101010102,
#  'Metabolic_Monitor_Cart': 0.010101010101010102,
#  'Micronutrient': 0.010101010101010102,
#  'Micronutrient_Prot_dev': 0.010101010101010102,
#  'MicronutrientsControlled': 0.010101010101010102,
#  'Minute_6_Walk': 0.010101010101010102,
#  'Mono': 0.010101010101010102,
#  'Navigation': 0.010101010101010102,
#  'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0.010101010101010102,
#  'Nutraceuticals_Prot_Dev_Resveratrol': 0.010101010101010102,
#  'Nutraceuticals_Prot_dev': 0.030303030303030304,
#  'Nutrient_Analysis': 0.05050505050505051,
#  'Nutrient_Composition': 0.04040404040404041,
#  'NutritionCapabilities': 0.010101010101010102,
#  'NutritionRoles': 0.04040404040404041,
#  'Nutrition_Assessment_Care_Plan': 0.04040404040404041,
#  'Outpatient': 0.010101010101010102,
#  'PRO': 0.010101010101010102,
#  'Parenteral': 0.010101010101010102,
#  'PctBodyFat': 0.010101010101010102,
#  'PctLeanMass': 0.010101010101010102,
#  'Poly': 0.010101010101010102,
#  'Predicted_Equation': 0.030303030303030304,
#  'ProtocolDevelopment': 0.04040404040404041,
#  'Regular': 0.020202020202020204,
#  'ResearchNutritionAssessmentProcedure': 0.05050505050505051,
#  'RotatingMenuCycle': 0.04040404040404041,
#  'Saturated': 0.010101010101010102,
#  'ScientificLiterature': 0.010101010101010102,
#  'Screening': 0.030303030303030304,
#  'Single_Nutrient_Intake': 0.04040404040404041,
#  'Skinfold': 0.030303030303030304,
#  'Skinfold_Subscapular': 0.010101010101010102,
#  'Skinfold_Suprailiac': 0.010101010101010102,
#  'Snacks': 0.010101010101010102,
#  'Spirometry': 0.010101010101010102,
#  'Theraputic': 0.04040404040404041,
#  'TransFattyAcids': 0.010101010101010102,
#  'Treadmill': 0.010101010101010102,
#  'Underwater_Weighing': 0.030303030303030304,
#  'Underwater_Weighing_PctBodyFat': 0.010101010101010102,
#  'Underwater_Weighing_PctLeanMass': 0.010101010101010102,
#  'Unsaturated': 0.030303030303030304,
#  'Water': 0.010101010101010102,
#  'WholeFood': 0.010101010101010102,
#  'Whole_Calorimetry': 0.020202020202020204}

# %%
nx.voterank(G2)
# Out:
# ['Regular',
#  'Activity_Factor_or_Equation',
#  'Activity_Physical_Assessment',
#  'Adjusted_Body_Weight_Equation_for_Obesity',
#  'Anthropometrics',
#  'Assessory_Nutrient',
#  'CHO',
#  'Day_1_Inpatient',
#  'Day_Rotation_1',
#  'DesignDiet',
#  'DietPlan',
#  'Diet_Review',
#  'Education',
#  'Enteral',
#  'Food_Frequency_Questionnaires',
#  'Food_Record_3_4_Day',
#  'Hip_Waist_Measurement_Hip_Circumference',
#  'Inpatient',
#  'Macronutrient_Prot_Dev_Carbohydrate',
#  'Macronutrient_Prot_dev',
#  'MacronutrientsControlled',
#  'Metabolic_Monitor_Cart',
#  'Mono',
#  'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids',
#  'NutritionRoles',
#  'PctBodyFat',
#  'Saturated',
#  'Skinfold_Subscapular',
#  'Spirometry',
#  'Underwater_Weighing_PctBodyFat']

# %%
nx.betweenness_centrality(G2)
# Out:
# {'Activity_Factor_or_Equation': 0.0,
#  'Activity_Physical_Assessment': 0.0018552875695732837,
#  'Activity_Questionnaire': 0.0,
#  'Adjusted_Body_Weight_Equation_for_Obesity': 0.0,
#  'Anthropometrics': 0.0012368583797155224,
#  'Anthropometrics_BMI': 0.0,
#  'Anthropometrics_Height': 0.0,
#  'Anthropometrics_Weight': 0.0,
#  'Assessory_Nutrient': 0.0,
#  'Bike': 0.0,
#  'Bioelectric_Impedence': 0.0,
#  'BodPod': 0.0008245722531436817,
#  'BodyComposition': 0.005875077303648732,
#  'CHO': 0.0,
#  'DEXA': 0.0,
#  'Day_1_Inpatient': 0.0,
#  'Day_2_Inpatient': 0.0,
#  'Day_5_Inpatient': 0.0,
#  'Day_Rotation_1': 0.0,
#  'Day_Rotation_3': 0.0,
#  'Day_Rotation_5': 0.0,
#  'DesignDiet': 0.004329004329004329,
#  'DietMealsServed': 0.0006184291898577612,
#  'DietPlan': 0.0055658627087198514,
#  'Diet_Review': 0.0,
#  'Education': 0.0008245722531436817,
#  'Energy_Expediture': 0.0018552875695732837,
#  'Enteral': 0.0,
#  'FAT': 0.002576788291074005,
#  'Fiber': 0.0,
#  'Food_Frequency_Questionnaires': 0.0,
#  'Food_Recall': 0.0010307153164296021,
#  'Food_Record_3_4_Day': 0.0,
#  'Food_Record_7_Day': 0.0,
#  'Formula': 0.0008245722531436817,
#  'Grip_Strength': 0.0,
#  'Group': 0.0,
#  'Harris_Benedict_Equation': 0.0,
#  'Hip_Waist_Measurement': 0.0012368583797155224,
#  'Hip_Waist_Measurement_Hip_Circumference': 0.0,
#  'Hip_Waist_Measurement_Waist_Circumference': 0.0,
#  'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0.0,
#  'Hour_24_Diet_Recall': 0.0,
#  'Individual': 0.0,
#  'Inpatient': 0.0,
#  'Macronutrient': 0.0,
#  'Macronutrient_Prot_Dev_Carbohydrate': 0.0,
#  'Macronutrient_Prot_Dev_Fat': 0.0,
#  'Macronutrient_Prot_Dev_Fiber': 0.0,
#  'Macronutrient_Prot_Dev_Protein': 0.0,
#  'Macronutrient_Prot_dev': 0.0020614306328592042,
#  'MacronutrientsControlled': 0.0041228612657184084,
#  'Menu_Rotation': 0.0012368583797155224,
#  'Metabolic': 0.00494743351886209,
#  'Metabolic_Diet_Protocol': 0.0,
#  'Metabolic_Monitor_Cart': 0.0,
#  'Micronutrient': 0.0,
#  'Micronutrient_Prot_dev': 0.0,
#  'MicronutrientsControlled': 0.0,
#  'Minute_6_Walk': 0.0,
#  'Mono': 0.0,
#  'Navigation': 0.0,
#  'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0.0,
#  'Nutraceuticals_Prot_Dev_Resveratrol': 0.0,
#  'Nutraceuticals_Prot_dev': 0.0010307153164296021,
#  'Nutrient_Analysis': 0.0037105751391465673,
#  'Nutrient_Composition': 0.0037105751391465673,
#  'NutritionCapabilities': 0.0,
#  'NutritionRoles': 0.0101010101010101,
#  'Nutrition_Assessment_Care_Plan': 0.00494743351886209,
#  'Outpatient': 0.0,
#  'PRO': 0.0,
#  'Parenteral': 0.0,
#  'PctBodyFat': 0.0,
#  'PctLeanMass': 0.0,
#  'Poly': 0.0,
#  'Predicted_Equation': 0.0008245722531436817,
#  'ProtocolDevelopment': 0.0035044320758606472,
#  'Regular': 0.0,
#  'ResearchNutritionAssessmentProcedure': 0.010513296227581941,
#  'RotatingMenuCycle': 0.0012368583797155224,
#  'Saturated': 0.0,
#  'ScientificLiterature': 0.0,
#  'Screening': 0.0008245722531436817,
#  'Single_Nutrient_Intake': 0.001546072974644403,
#  'Skinfold': 0.0008245722531436817,
#  'Skinfold_Subscapular': 0.0,
#  'Skinfold_Suprailiac': 0.0,
#  'Snacks': 0.0,
#  'Spirometry': 0.0,
#  'Theraputic': 0.0012368583797155224,
#  'TransFattyAcids': 0.0,
#  'Treadmill': 0.0,
#  'Underwater_Weighing': 0.0008245722531436817,
#  'Underwater_Weighing_PctBodyFat': 0.0,
#  'Underwater_Weighing_PctLeanMass': 0.0,
#  'Unsaturated': 0.0012368583797155224,
#  'Water': 0.0,
#  'WholeFood': 0.0,
#  'Whole_Calorimetry': 0.00041228612657184083}

# %%
nx.pagerank(G2)
# Out:
# {'Activity_Factor_or_Equation': 0.002577776443985851,
#  'Activity_Physical_Assessment': 0.01572311042633236,
#  'Activity_Questionnaire': 0.002577776443985851,
#  'Adjusted_Body_Weight_Equation_for_Obesity': 0.002577776443985851,
#  'Anthropometrics': 0.009150443435159108,
#  'Anthropometrics_BMI': 0.002577776443985851,
#  'Anthropometrics_Height': 0.002577776443985851,
#  'Anthropometrics_Weight': 0.002577776443985851,
#  'Assessory_Nutrient': 0.002577776443985851,
#  'Bike': 0.002577776443985851,
#  'Bioelectric_Impedence': 0.002577776443985851,
#  'BodPod': 0.006959554438101355,
#  'BodyComposition': 0.04025773238741929,
#  'CHO': 0.002577776443985851,
#  'DEXA': 0.002577776443985851,
#  'Day_1_Inpatient': 0.002577776443985851,
#  'Day_2_Inpatient': 0.002577776443985851,
#  'Day_5_Inpatient': 0.002577776443985851,
#  'Day_Rotation_1': 0.002577776443985851,
#  'Day_Rotation_3': 0.002577776443985851,
#  'Day_Rotation_5': 0.002577776443985851,
#  'DesignDiet': 0.027627446721030527,
#  'DietMealsServed': 0.006959554438101355,
#  'DietPlan': 0.048553397258102426,
#  'Diet_Review': 0.002577776443985851,
#  'Education': 0.006959554438101355,
#  'Energy_Expediture': 0.0147363766761664,
#  'Enteral': 0.002577776443985851,
#  'FAT': 0.012874398929163968,
#  'Fiber': 0.002577776443985851,
#  'Food_Frequency_Questionnaires': 0.002577776443985851,
#  'Food_Recall': 0.006959554438101355,
#  'Food_Record_3_4_Day': 0.002577776443985851,
#  'Food_Record_7_Day': 0.002577776443985851,
#  'Formula': 0.006959554438101355,
#  'Grip_Strength': 0.002577776443985851,
#  'Group': 0.002577776443985851,
#  'Harris_Benedict_Equation': 0.002577776443985851,
#  'Hip_Waist_Measurement': 0.009150443435159108,
#  'Hip_Waist_Measurement_Hip_Circumference': 0.002577776443985851,
#  'Hip_Waist_Measurement_Waist_Circumference': 0.002577776443985851,
#  'Hip_Waist_Measurement_Waist_To_Hip_Ratio': 0.002577776443985851,
#  'Hour_24_Diet_Recall': 0.002577776443985851,
#  'Individual': 0.002577776443985851,
#  'Inpatient': 0.002577776443985851,
#  'Macronutrient': 0.002577776443985851,
#  'Macronutrient_Prot_Dev_Carbohydrate': 0.002577776443985851,
#  'Macronutrient_Prot_Dev_Fat': 0.002577776443985851,
#  'Macronutrient_Prot_Dev_Fiber': 0.002577776443985851,
#  'Macronutrient_Prot_Dev_Protein': 0.002577776443985851,
#  'Macronutrient_Prot_dev': 0.011341332432216859,
#  'MacronutrientsControlled': 0.022283496603920098,
#  'Menu_Rotation': 0.009150443435159108,
#  'Metabolic': 0.03148549467052461,
#  'Metabolic_Diet_Protocol': 0.002577776443985851,
#  'Metabolic_Monitor_Cart': 0.002577776443985851,
#  'Micronutrient': 0.002577776443985851,
#  'Micronutrient_Prot_dev': 0.002577776443985851,
#  'MicronutrientsControlled': 0.002577776443985851,
#  'Minute_6_Walk': 0.002577776443985851,
#  'Mono': 0.002577776443985851,
#  'Navigation': 0.002577776443985851,
#  'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': 0.002577776443985851,
#  'Nutraceuticals_Prot_Dev_Resveratrol': 0.002577776443985851,
#  'Nutraceuticals_Prot_dev': 0.006959554438101355,
#  'Nutrient_Analysis': 0.020651221167229013,
#  'Nutrient_Composition': 0.020322309917173695,
#  'NutritionCapabilities': 0.1267927049706015,
#  'NutritionRoles': 0.1461107198591209,
#  'Nutrition_Assessment_Care_Plan': 0.031959620245274045,
#  'Outpatient': 0.002577776443985851,
#  'PRO': 0.002577776443985851,
#  'Parenteral': 0.002577776443985851,
#  'PctBodyFat': 0.002577776443985851,
#  'PctLeanMass': 0.002577776443985851,
#  'Poly': 0.002577776443985851,
#  'Predicted_Equation': 0.006959554438101355,
#  'ProtocolDevelopment': 0.03044407380674484,
#  'Regular': 0.002577776443985851,
#  'ResearchNutritionAssessmentProcedure': 0.08984838275932419,
#  'RotatingMenuCycle': 0.009150443435159108,
#  'Saturated': 0.002577776443985851,
#  'ScientificLiterature': 0.002577776443985851,
#  'Screening': 0.006959554438101355,
#  'Single_Nutrient_Intake': 0.009150443435159108,
#  'Skinfold': 0.006959554438101355,
#  'Skinfold_Subscapular': 0.002577776443985851,
#  'Skinfold_Suprailiac': 0.002577776443985851,
#  'Snacks': 0.002577776443985851,
#  'Spirometry': 0.002577776443985851,
#  'Theraputic': 0.011778954430635095,
#  'TransFattyAcids': 0.002577776443985851,
#  'Treadmill': 0.002577776443985851,
#  'Underwater_Weighing': 0.006959554438101355,
#  'Underwater_Weighing_PctBodyFat': 0.002577776443985851,
#  'Underwater_Weighing_PctLeanMass': 0.002577776443985851,
#  'Unsaturated': 0.006959554438101355,
#  'Water': 0.002577776443985851,
#  'WholeFood': 0.002577776443985851,
#  'Whole_Calorimetry': 0.004768665441043604}

# %%
A = nx.floyd_warshall(G2)
A
# Out:
# {'Activity_Factor_or_Equation': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Activity_Factor_or_Equation': 0,
#               'Activity_Physical_Assessment': 1.0,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 2.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Activity_Physical_Assessment': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Activity_Physical_Assessment': 0,
#               'ResearchNutritionAssessmentProcedure': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 3.0,
#               'NutritionRoles': 2.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Activity_Questionnaire': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Activity_Questionnaire': 0,
#               'Activity_Physical_Assessment': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 2.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Adjusted_Body_Weight_Equation_for_Obesity': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Adjusted_Body_Weight_Equation_for_Obesity': 0,
#               'Predicted_Equation': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': 2.0,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 5.0,
#               'NutritionRoles': 4.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 3.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Anthropometrics': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Anthropometrics': 0,
#               'BodyComposition': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 2.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Anthropometrics_BMI': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Anthropometrics_BMI': 0,
#               'Anthropometrics': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': 2.0,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 5.0,
#               'NutritionRoles': 4.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 3.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Anthropometrics_Height': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Anthropometrics_Height': 0,
#               'Anthropometrics': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': 2.0,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 5.0,
#               'NutritionRoles': 4.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 3.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Anthropometrics_Weight': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Anthropometrics_Weight': 0,
#               'Anthropometrics': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': 2.0,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 5.0,
#               'NutritionRoles': 4.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 3.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Assessory_Nutrient': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Assessory_Nutrient': 0,
#               'Single_Nutrient_Intake': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': 2.0,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 6.0,
#               'NutritionRoles': 5.0,
#               'Nutrition_Assessment_Care_Plan': 3.0,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 4.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Bike': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Bike': 0,
#               'Activity_Physical_Assessment': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 2.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Bioelectric_Impedence': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Bioelectric_Impedence': 0,
#               'BodyComposition': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'BodPod': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 2.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'BodPod': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'BodPod': 0,
#               'BodyComposition': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
# ...
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': 4.0,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': 2.0,
#               'Menu_Rotation': inf,
#               'Metabolic': 3.0,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 6.0,
#               'NutritionRoles': 5.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': inf,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Water': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'Water': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Water': 0,
#               'MacronutrientsControlled': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': 3.0,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': 2.0,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 5.0,
#               'NutritionRoles': 4.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': inf,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'WholeFood': inf,
#               'Whole_Calorimetry': inf}),
#  'WholeFood': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'WholeFood': 0,
#               'Theraputic': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': 2.0,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Energy_Expediture': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': inf,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'Whole_Calorimetry': inf}),
#  'Whole_Calorimetry': defaultdict(<function networkx.algorithms.shortest_paths.dense.floyd_warshall_predecessor_and_distance.<locals>.<lambda>.<locals>.<lambda>()>,
#              {'Whole_Calorimetry': 0,
#               'Energy_Expediture': 1.0,
#               'Activity_Factor_or_Equation': inf,
#               'Activity_Physical_Assessment': inf,
#               'Activity_Questionnaire': inf,
#               'Adjusted_Body_Weight_Equation_for_Obesity': inf,
#               'Anthropometrics': inf,
#               'Anthropometrics_BMI': inf,
#               'Anthropometrics_Height': inf,
#               'Anthropometrics_Weight': inf,
#               'Assessory_Nutrient': inf,
#               'Bike': inf,
#               'Bioelectric_Impedence': inf,
#               'BodPod': inf,
#               'BodyComposition': inf,
#               'CHO': inf,
#               'DEXA': inf,
#               'Day_1_Inpatient': inf,
#               'Day_2_Inpatient': inf,
#               'Day_5_Inpatient': inf,
#               'Day_Rotation_1': inf,
#               'Day_Rotation_3': inf,
#               'Day_Rotation_5': inf,
#               'DesignDiet': inf,
#               'DietMealsServed': inf,
#               'DietPlan': inf,
#               'Diet_Review': inf,
#               'Education': inf,
#               'Enteral': inf,
#               'FAT': inf,
#               'Fiber': inf,
#               'Food_Frequency_Questionnaires': inf,
#               'Food_Recall': inf,
#               'Food_Record_3_4_Day': inf,
#               'Food_Record_7_Day': inf,
#               'Formula': inf,
#               'Grip_Strength': inf,
#               'Group': inf,
#               'Harris_Benedict_Equation': inf,
#               'Hip_Waist_Measurement': inf,
#               'Hip_Waist_Measurement_Hip_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_Circumference': inf,
#               'Hip_Waist_Measurement_Waist_To_Hip_Ratio': inf,
#               'Hour_24_Diet_Recall': inf,
#               'Individual': inf,
#               'Inpatient': inf,
#               'Macronutrient': inf,
#               'Macronutrient_Prot_Dev_Carbohydrate': inf,
#               'Macronutrient_Prot_Dev_Fat': inf,
#               'Macronutrient_Prot_Dev_Fiber': inf,
#               'Macronutrient_Prot_Dev_Protein': inf,
#               'Macronutrient_Prot_dev': inf,
#               'MacronutrientsControlled': inf,
#               'Menu_Rotation': inf,
#               'Metabolic': inf,
#               'Metabolic_Diet_Protocol': inf,
#               'Metabolic_Monitor_Cart': inf,
#               'Micronutrient': inf,
#               'Micronutrient_Prot_dev': inf,
#               'MicronutrientsControlled': inf,
#               'Minute_6_Walk': inf,
#               'Mono': inf,
#               'Navigation': inf,
#               'Nutraceuticals_Prot_Dev_Omega_3_Fatty_Acids': inf,
#               'Nutraceuticals_Prot_Dev_Resveratrol': inf,
#               'Nutraceuticals_Prot_dev': inf,
#               'Nutrient_Analysis': inf,
#               'Nutrient_Composition': inf,
#               'NutritionCapabilities': 4.0,
#               'NutritionRoles': 3.0,
#               'Nutrition_Assessment_Care_Plan': inf,
#               'Outpatient': inf,
#               'PRO': inf,
#               'Parenteral': inf,
#               'PctBodyFat': inf,
#               'PctLeanMass': inf,
#               'Poly': inf,
#               'Predicted_Equation': inf,
#               'ProtocolDevelopment': inf,
#               'Regular': inf,
#               'ResearchNutritionAssessmentProcedure': 2.0,
#               'RotatingMenuCycle': inf,
#               'Saturated': inf,
#               'ScientificLiterature': inf,
#               'Screening': inf,
#               'Single_Nutrient_Intake': inf,
#               'Skinfold': inf,
#               'Skinfold_Subscapular': inf,
#               'Skinfold_Suprailiac': inf,
#               'Snacks': inf,
#               'Spirometry': inf,
#               'Theraputic': inf,
#               'TransFattyAcids': inf,
#               'Treadmill': inf,
#               'Underwater_Weighing': inf,
#               'Underwater_Weighing_PctBodyFat': inf,
#               'Underwater_Weighing_PctLeanMass': inf,
#               'Unsaturated': inf,
#               'Water': inf,
#               'WholeFood': inf})}

# %% [markdown]
# ## Knowledge linker on local KG
# * https://stackoverflow.com/questions/52046394/how-to-perform-entity-linking-to-local-knowledge-graph

# %%
input = 'new york is the big apple'.split()


def spans(lst):
    if len(lst) == 0:
        yield None
    for index in range(1, len(lst)):
        for span in spans(lst[index:]):
            if span is not None:
                yield [lst[0:index]] + span
    yield [lst]

knowledgebase = [
    ['new', 'york'],
    ['big', 'apple'],
]

out = []
scores = []

for span in spans(input):
    score = 0
    for candidate in span:
        for uid, entity in enumerate(knowledgebase):
            if candidate == entity:
                score += 1
    out.append(span)
    scores.append(score)

leaderboard = sorted(zip(out, scores), key=lambda x: x[1])

for winner in leaderboard:
    print(winner[1], ' ~ ', winner[0])
# Out:
# 0  ~  [['new'], ['york'], ['is'], ['the'], ['big'], ['apple']]
# 0  ~  [['new'], ['york'], ['is'], ['the', 'big'], ['apple']]
# 0  ~  [['new'], ['york'], ['is'], ['the', 'big', 'apple']]
# 0  ~  [['new'], ['york'], ['is', 'the'], ['big'], ['apple']]
# 0  ~  [['new'], ['york'], ['is', 'the', 'big'], ['apple']]
# 0  ~  [['new'], ['york'], ['is', 'the', 'big', 'apple']]
# 0  ~  [['new'], ['york', 'is'], ['the'], ['big'], ['apple']]
# 0  ~  [['new'], ['york', 'is'], ['the', 'big'], ['apple']]
# 0  ~  [['new'], ['york', 'is'], ['the', 'big', 'apple']]
# 0  ~  [['new'], ['york', 'is', 'the'], ['big'], ['apple']]
# 0  ~  [['new'], ['york', 'is', 'the', 'big'], ['apple']]
# 0  ~  [['new'], ['york', 'is', 'the', 'big', 'apple']]
# 0  ~  [['new', 'york', 'is'], ['the'], ['big'], ['apple']]
# 0  ~  [['new', 'york', 'is'], ['the', 'big'], ['apple']]
# 0  ~  [['new', 'york', 'is'], ['the', 'big', 'apple']]
# 0  ~  [['new', 'york', 'is', 'the'], ['big'], ['apple']]
# 0  ~  [['new', 'york', 'is', 'the', 'big'], ['apple']]
# 0  ~  [['new', 'york', 'is', 'the', 'big', 'apple']]
# 1  ~  [['new'], ['york'], ['is'], ['the'], ['big', 'apple']]
# 1  ~  [['new'], ['york'], ['is', 'the'], ['big', 'apple']]
# 1  ~  [['new'], ['york', 'is'], ['the'], ['big', 'apple']]
# 1  ~  [['new'], ['york', 'is', 'the'], ['big', 'apple']]
# 1  ~  [['new', 'york'], ['is'], ['the'], ['big'], ['apple']]
# 1  ~  [['new', 'york'], ['is'], ['the', 'big'], ['apple']]
# 1  ~  [['new', 'york'], ['is'], ['the', 'big', 'apple']]
# 1  ~  [['new', 'york'], ['is', 'the'], ['big'], ['apple']]
# 1  ~  [['new', 'york'], ['is', 'the', 'big'], ['apple']]
# 1  ~  [['new', 'york'], ['is', 'the', 'big', 'apple']]
# 1  ~  [['new', 'york', 'is'], ['the'], ['big', 'apple']]
# 1  ~  [['new', 'york', 'is', 'the'], ['big', 'apple']]
# 2  ~  [['new', 'york'], ['is'], ['the'], ['big', 'apple']]
# 2  ~  [['new', 'york'], ['is', 'the'], ['big', 'apple']]

# %% [markdown]
# # Algoritmi graph embedding
# * https://towardsdatascience.com/how-to-generate-and-evaluate-the-performance-of-knowledge-graph-embeddings-95789abcb0c1

# %% [markdown]
# # Build KG
#
# * https://towardsdatascience.com/nlp-with-python-knowledge-graph-12b93146a458
# * https://www.kaggle.com/code/nageshsingh/build-knowledge-graph-using-python
